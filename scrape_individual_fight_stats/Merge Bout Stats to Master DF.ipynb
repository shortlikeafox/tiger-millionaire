# %%
import pandas as pd

# %%
#load both dataframes

bout_df = pd.read_csv('bout_info.csv')
master_df = pd.read_csv('../data/ufc-master.csv')

# %%
display(bout_df)
display(master_df)
# Out:
#              R_fighter          B_fighter        date  R_kd_bout  B_kd_bout  \
# 0           Tito Ortiz       Ken Shamrock  10/10/2006          0          0
# 1        Carla Esparza     Rose Namajunas  12/12/2014          0          0
# 2        Nicco Montano  Roxanne Modafferi  12/ 1/2017          0          0
# 3     Jake Ellenberger   Stephen Thompson   7/12/2015          1          2
# 4     Rafael Dos Anjos       Kamaru Usman  11/30/2018          0          0
# ...                ...                ...         ...        ...        ...
# 5564  Darren Uyenoyama        Phil Harris  10/ 5/2012          0          0
# 5565   Joseph Sandoval         Nick Denis   1/20/2012          0          1
# 5566     Buddy Roberts     Caio Magalhaes   6/ 8/2012          0          0
# 5567        Matt Brown         Luis Ramos   6/22/2012          0          0
# 5568    Brad Blackburn        James Giboo   7/19/2008          4          0
#
# ...

# %%
merge_df = pd.merge(master_df, bout_df, how='left')

# %%
display(merge_df)
# Out:
#              R_fighter              B_fighter  R_odds  B_odds        R_ev  \
# 0     Robert Whittaker            Darren Till    -130     107   76.923077
# 1         Mauricio Rua       Rogerio Nogueira    -190     150   52.631579
# 2      Fabricio Werdum   Alexander Gustafsson     260    -335  260.000000
# 3        Carla Esparza       Marina Rodriguez     145    -182  145.000000
# 4           Paul Craig  Gadzhimurad Antigulov    -137     110   72.992701
# ...                ...                    ...     ...     ...         ...
# 4302      Duane Ludwig          Darren Elkins    -155     135   64.516129
# 4303       John Howard         Daniel Roberts    -210     175   47.619048
# 4304    Brendan Schaub          Chase Gormley    -260     220   38.461538
# 4305       Mike Pierce          Julio Paulino    -420     335   23.809524
# 4306      Eric Schafer            Jason Brilz     140    -160  140.000000
#
#             B_ev       date                                    location  \
# ...

# %%
merge_df.to_csv('temp.csv', index=False)
