# %% [markdown]
# # 1. Let's merge the finishes to the main dataframe.  I think this will be easy????

# %%
import pandas as pd

# %%
#load both dataframes

finish_df = pd.read_csv('fight_finishes.csv')
master_df = pd.read_csv('../data/ufc-master.csv')

# %%
display(finish_df)
display(master_df)
# Out:
#                   R_fighter       B_fighter  finish finish_details        date
# 0             Calvin Kattar         Dan Ige     NaN            NaN   7/15/2020
# 1               Tim Elliott     Ryan Benoit     NaN            NaN   7/15/2020
# 2             Jimmie Rivera    Cody Stamann     NaN            NaN   7/15/2020
# 3              Molly McCann    Taila Santos     NaN            NaN   7/15/2020
# 4      Abdul Razak Alhassan   Mounir Lazzez     NaN            NaN   7/15/2020
# ...                     ...             ...     ...            ...         ...
# 11347          Kevin Rosier  Gerard Gordeau  KO/TKO            NaN  11/12/1993
# 11348         Patrick Smith    Ken Shamrock     SUB      Heel Hook  11/12/1993
# 11349         Art Jimmerson    Royce Gracie     SUB          Other  11/12/1993
# 11350          Zane Frazier    Kevin Rosier  KO/TKO            NaN  11/12/1993
# 11351            Teila Tuli  Gerard Gordeau  KO/TKO           Kick  11/12/1993
#
# ...

# %%
merge_df = pd.merge(master_df, finish_df, how='left') #Does this really work??? Seems like magic.

# %%
display(merge_df)
# Out:
#                   R_fighter       B_fighter  R_odds  B_odds        R_ev  \
# 0              Kamaru Usman  Jorge Masvidal    -240     190   41.666667
# 1     Alexander Volkanovski    Max Holloway    -210     170   47.619048
# 2                  Petr Yan       Jose Aldo    -215     175   46.511628
# 3           Jessica Andrade  Rose Namajunas     175    -215  175.000000
# 4              Amanda Ribas   Paige VanZant    -770     500   12.987013
# ...                     ...             ...     ...     ...         ...
# 4264           Duane Ludwig   Darren Elkins    -155     135   64.516129
# 4265            John Howard  Daniel Roberts    -210     175   47.619048
# 4266         Brendan Schaub   Chase Gormley    -260     220   38.461538
# 4267            Mike Pierce   Julio Paulino    -420     335   23.809524
# 4268           Eric Schafer     Jason Brilz     140    -160  140.000000
#
#             B_ev       date                                    location  \
# ...

# %%
merge_df.to_csv('temp.csv', index=False)
