# %%
import pandas as pd

# %%
models= pd.read_csv('../data/models.csv').columns

# %%
number_of_models = len(models)

# %%
for n in range(number_of_models):
    model_num = n
    print()
    print()
    print("OPTIMIZING MODEL " + str(model_num))
    print()
    print()
    # %run TM-Optimize-Models.ipynb
# Out:
# OPTIMIZING MODEL 0
#
#
# 5
# 250
# 250
# 250
# 4554
# 4554
# 4554
# 250
# 4554
#                 R_fighter              B_fighter  R_odds  B_odds        R_ev  \
# 250      Marina Rodriguez           Amanda Ribas     250    -335  250.000000
# 251          Brad Tavares  Antonio Carlos Junior    -134     105   74.626866
# 252         Julianna Pena            Sara McMann     105    -130  105.000000
# 253   Khalil Rountree Jr.        Marcin Prachnio    -335     250   29.850746
# 254             Nik Lentz          Movsar Evloev     390    -560  390.000000
# ...                   ...                    ...     ...     ...         ...
# 4799         Duane Ludwig          Darren Elkins    -155     135   64.516129
# 4800          John Howard         Daniel Roberts    -210     175   47.619048
# 4801       Brendan Schaub          Chase Gormley    -260     220   38.461538
# 4802          Mike Pierce          Julio Paulino    -420     335   23.809524
# 4803         Eric Schafer            Jason Brilz     140    -160  140.000000
#
#             B_ev       date                                    location  \
# 250    29.850746 2021-01-23  Abu Dhabi, Abu Dhabi, United Arab Emirates
# 251   105.000000 2021-01-23  Abu Dhabi, Abu Dhabi, United Arab Emirates
# 252    76.923077 2021-01-23  Abu Dhabi, Abu Dhabi, United Arab Emirates
# 253   250.000000 2021-01-23  Abu Dhabi, Abu Dhabi, United Arab Emirates
# 254    17.857143 2021-01-23  Abu Dhabi, Abu Dhabi, United Arab Emirates
# ...          ...        ...                                         ...
# 4799  135.000000 2010-03-21                   Broomfield, Colorado, USA
# 4800  175.000000 2010-03-21                   Broomfield, Colorado, USA
# 4801  220.000000 2010-03-21                   Broomfield, Colorado, USA
# 4802  335.000000 2010-03-21                   Broomfield, Colorado, USA
# 4803   62.500000 2010-03-21                   Broomfield, Colorado, USA
#
#                    country Winner  ...  finish_round finish_round_time  \
# 250   United Arab Emirates    Red  ...           NaN               NaN
# 251   United Arab Emirates    Red  ...           NaN               NaN
# 252   United Arab Emirates    Red  ...           NaN               NaN
# 253   United Arab Emirates   Blue  ...           NaN               NaN
# 254   United Arab Emirates   Blue  ...           NaN               NaN
# ...                    ...    ...  ...           ...               ...
# 4799                   USA   Blue  ...           1.0              0:44
# 4800                   USA    Red  ...           1.0              2:01
# 4801                   USA    Red  ...           1.0              0:47
# 4802                   USA    Red  ...           3.0              5:00
# 4803                   USA   Blue  ...           3.0              5:00
#
#      total_fight_time_secs  r_dec_odds  b_dec_odds  r_sub_odds  b_sub_odds  \
# 250                    NaN       375.0       125.0      1800.0       165.0
# 251                    NaN       175.0       250.0      1400.0       275.0
# 252                    NaN       250.0       150.0       475.0       375.0
# 253                    NaN         NaN       650.0         NaN      2200.0
# 254                    NaN       700.0      -175.0       950.0       550.0
# ...                    ...         ...         ...         ...         ...
# 4799                  44.0         NaN         NaN         NaN         NaN
# 4800                 121.0         NaN         NaN         NaN         NaN
# 4801                  47.0         NaN         NaN         NaN         NaN
# 4802                 900.0         NaN         NaN         NaN         NaN
# 4803                 900.0         NaN         NaN         NaN         NaN
#
#       r_ko_odds  b_ko_odds  label
# 250      1000.0     1000.0      0
# 251       550.0      800.0      0
# 252       900.0     1000.0      0
# 253         NaN      400.0      1
# 254      1400.0      500.0      1
# ...         ...        ...    ...
# 4799        NaN        NaN      1
# 4800        NaN        NaN      0
# 4801        NaN        NaN      0
# 4802        NaN        NaN      0
# 4803        NaN        NaN      1
#
# [4554 rows x 120 columns]
#             R_fighter          B_fighter  R_odds  B_odds        R_ev  \
# 0      Cory Sandhagen       TJ Dillashaw    -210     175   47.619048
# 1      Kyler Phillips      Raulian Paiva    -320     250   31.250000
# 2       Darren Elkins     Darrick Minner     130    -155  130.000000
# 3    Miranda Maverick      Maycee Barber    -155     135   64.516129
# 4        Adrian Yanez        Randy Costa    -240     195   41.666667
# ..                ...                ...     ...     ...         ...
# 245     SeungWoo Choi      Youssef Zalal     175    -230  175.000000
# 246    Dustin Poirier     Conor McGregor     250    -305  250.000000
# 247        Dan Hooker   Michael Chandler    -134     105   74.626866
# 248       Jessica Eye  Joanne Calderwood    -105    -117   95.238095
# 249    Andrew Sanchez    Makhmud Muradov     115    -143  115.000000
#
#            B_ev       date                                    location  \
# 0    175.000000 2021-07-24                      Las Vegas, Nevada, USA
# 1    250.000000 2021-07-24                      Las Vegas, Nevada, USA
# 2     64.516129 2021-07-24                      Las Vegas, Nevada, USA
# 3    135.000000 2021-07-24                      Las Vegas, Nevada, USA
# 4    195.000000 2021-07-24                      Las Vegas, Nevada, USA
# ..          ...        ...                                         ...
# 245   43.478261 2021-02-06                      Las Vegas, Nevada, USA
# 246   32.786885 2021-01-23  Abu Dhabi, Abu Dhabi, United Arab Emirates
# 247  105.000000 2021-01-23  Abu Dhabi, Abu Dhabi, United Arab Emirates
# 248   85.470085 2021-01-23  Abu Dhabi, Abu Dhabi, United Arab Emirates
# 249   69.930070 2021-01-23  Abu Dhabi, Abu Dhabi, United Arab Emirates
#
#                   country Winner  ...  finish_round finish_round_time  \
# 0                     USA   Blue  ...           5.0              5:00
# 1                     USA   Blue  ...           3.0              5:00
# 2                     USA    Red  ...           2.0              3:48
# 3                     USA   Blue  ...           3.0              5:00
# 4                     USA    Red  ...           2.0              2:11
# ..                    ...    ...  ...           ...               ...
# 245                   USA    Red  ...           NaN               NaN
# 246  United Arab Emirates    Red  ...           NaN               NaN
# 247  United Arab Emirates   Blue  ...           NaN               NaN
# 248  United Arab Emirates   Blue  ...           NaN               NaN
# 249  United Arab Emirates   Blue  ...           NaN               NaN
#
#     total_fight_time_secs  r_dec_odds  b_dec_odds  r_sub_odds  b_sub_odds  \
# 0                  1500.0       500.0       500.0       600.0      1100.0
# 1                   900.0      -125.0       500.0      1000.0      1000.0
# 2                   528.0       275.0       250.0       600.0       240.0
# 3                   900.0       120.0       275.0       650.0      1400.0
# 4                   431.0       380.0       500.0      1100.0      1600.0
# ..                    ...         ...         ...         ...         ...
# 245                   NaN       350.0       125.0      1400.0       450.0
# 246                   NaN       650.0       750.0       750.0      1600.0
# 247                   NaN       325.0       300.0       850.0       675.0
# 248                   NaN       125.0       140.0      1200.0      1000.0
# 249                   NaN       260.0       200.0      1000.0      1800.0
#
#      r_ko_odds  b_ko_odds  label
# 0        110.0      400.0      1
# 1        400.0      900.0      1
# 2        800.0      600.0      0
# 3        750.0      450.0      1
# 4       -110.0      450.0      0
# ..         ...        ...    ...
# 245      600.0      425.0      0
# 246      675.0     -220.0      0
# 247      150.0      500.0      1
# 248      900.0      600.0      1
# 249      800.0      175.0      1
#
# [250 rows x 120 columns]
# ['R_fighter', 'B_fighter', 'R_odds', 'B_odds', 'R_ev', 'B_ev', 'date', 'location', 'country', 'Winner', 'title_bout', 'weight_class', 'gender', 'no_of_rounds', 'B_current_lose_streak', 'B_current_win_streak', 'B_draw', 'B_avg_SIG_STR_landed', 'B_avg_SIG_STR_pct', 'B_avg_SUB_ATT', 'B_avg_TD_landed', 'B_avg_TD_pct', 'B_longest_win_streak', 'B_losses', 'B_total_rounds_fought', 'B_total_title_bouts', 'B_win_by_Decision_Majority', 'B_win_by_Decision_Split', 'B_win_by_Decision_Unanimous', 'B_win_by_KO/TKO', 'B_win_by_Submission', 'B_win_by_TKO_Doctor_Stoppage', 'B_wins', 'B_Stance', 'B_Height_cms', 'B_Reach_cms', 'B_Weight_lbs', 'R_current_lose_streak', 'R_current_win_streak', 'R_draw', 'R_avg_SIG_STR_landed', 'R_avg_SIG_STR_pct', 'R_avg_SUB_ATT', 'R_avg_TD_landed', 'R_avg_TD_pct', 'R_longest_win_streak', 'R_losses', 'R_total_rounds_fought', 'R_total_title_bouts', 'R_win_by_Decision_Majority', 'R_win_by_Decision_Split', 'R_win_by_Decision_Unanimous', 'R_win_by_KO/TKO', 'R_win_by_Submission', 'R_win_by_TKO_Doctor_Stoppage', 'R_wins', 'R_Stance', 'R_Height_cms', 'R_Reach_cms', 'R_Weight_lbs', 'R_age', 'B_age', 'lose_streak_dif', 'win_streak_dif', 'longest_win_streak_dif', 'win_dif', 'loss_dif', 'total_round_dif', 'total_title_bout_dif', 'ko_dif', 'sub_dif', 'height_dif', 'reach_dif', 'age_dif', 'sig_str_dif', 'avg_sub_att_dif', 'avg_td_dif', 'empty_arena', 'constant_1', 'B_match_weightclass_rank', 'R_match_weightclass_rank', "R_Women's Flyweight_rank", "R_Women's Featherweight_rank", "R_Women's Strawweight_rank", "R_Women's Bantamweight_rank", 'R_Heavyweight_rank', 'R_Light Heavyweight_rank', 'R_Middleweight_rank', 'R_Welterweight_rank', 'R_Lightweight_rank', 'R_Featherweight_rank', 'R_Bantamweight_rank', 'R_Flyweight_rank', 'R_Pound-for-Pound_rank', "B_Women's Flyweight_rank", "B_Women's Featherweight_rank", "B_Women's Strawweight_rank", "B_Women's Bantamweight_rank", 'B_Heavyweight_rank', 'B_Light Heavyweight_rank', 'B_Middleweight_rank', 'B_Welterweight_rank', 'B_Lightweight_rank', 'B_Featherweight_rank', 'B_Bantamweight_rank', 'B_Flyweight_rank', 'B_Pound-for-Pound_rank', 'better_rank', 'finish', 'finish_details', 'finish_round', 'finish_round_time', 'total_fight_time_secs', 'r_dec_odds', 'b_dec_odds', 'r_sub_odds', 'b_sub_odds', 'r_ko_odds', 'b_ko_odds', 'label']
# model_0
# LogisticRegression(max_iter=50000, random_state=75, solver='newton-cg',
#                    tol=9.6e-05)
# ['R_total_title_bouts', "R_Women's Strawweight_rank", 'R_current_win_streak', 'B_Featherweight_rank', 'B_age', 'R_Flyweight_rank', 'B_Pound-for-Pound_rank', 'longest_win_streak_dif', 'B_win_by_Decision_Majority', 'R_odds', 'lose_streak_dif', 'R_ev', 'avg_td_dif', 'win_dif', 'reach_dif', "B_Women's Strawweight_rank", 'B_Flyweight_rank', 'B_current_lose_streak', 'R_Bantamweight_rank', "R_Women's Flyweight_rank", 'R_win_by_Decision_Split', 'R_age', 'R_draw', 'B_Bantamweight_rank', 'B_Lightweight_rank', 'B_Reach_cms', 'B_draw', 'R_Welterweight_rank', 'B_win_by_TKO_Doctor_Stoppage', 'loss_dif', 'B_ev', 'empty_arena']
# 0
# Current best score is: 20831.638148474805
# Feature: B_odds Score: 20967.43793880679
# Feature: title_bout Score: 22260.536664951116
# Feature: B_longest_win_streak Score: 22729.162115488394
# Feature: R_longest_win_streak Score: 22929.162115488394
# The best feature was R_longest_win_streak.  It scored 22929.162115488394
# Current best score is: 22929.162115488394
# Feature: title_bout Score: 23786.699022943794
# Feature: avg_sub_att_dif Score: 23979.984956077267
# The best feature was avg_sub_att_dif.  It scored 23979.984956077267
# Current best score is: 23979.984956077267
# Feature: R_Reach_cms Score: 24223.528965849466
# The best feature was R_Reach_cms.  It scored 24223.528965849466
# Current best score is: 24223.528965849466
# Feature: title_bout Score: 24370.18376023705
# Feature: B_longest_win_streak Score: 24433.52896584947
# The best feature was B_longest_win_streak.  It scored 24433.52896584947
# Current best score is: 24433.52896584947
# NO IMPROVEMENT
# FINAL BEST SCORE: 24433.52896584947
#
# model_0
# LogisticRegression(max_iter=50000, random_state=75, solver='newton-cg',
#                    tol=9.6e-05)
# ['B_longest_win_streak', 'R_Reach_cms', 'avg_sub_att_dif', 'R_longest_win_streak', 'R_total_title_bouts', "R_Women's Strawweight_rank", 'R_current_win_streak', 'B_Featherweight_rank', 'B_age', 'R_Flyweight_rank', 'B_Pound-for-Pound_rank', 'longest_win_streak_dif', 'B_win_by_Decision_Majority', 'R_odds', 'lose_streak_dif', 'R_ev', 'avg_td_dif', 'win_dif', 'reach_dif', "B_Women's Strawweight_rank", 'B_Flyweight_rank', 'B_current_lose_streak', 'R_Bantamweight_rank', "R_Women's Flyweight_rank", 'R_win_by_Decision_Split', 'R_age', 'R_draw', 'B_Bantamweight_rank', 'B_Lightweight_rank', 'B_Reach_cms', 'B_draw', 'R_Welterweight_rank', 'B_win_by_TKO_Doctor_Stoppage', 'loss_dif', 'B_ev', 'empty_arena']
# 0
# (4554, 36)
# (4554,)
# (4554, 2)
# (250, 36)
# (250,)
# (250, 2)
#      t1_odds  t2_odds   t1_prob   t2_prob  winner
# 0       -210      175  0.623551  0.376449       1
# 1       -320      250  0.682419  0.317581       1
# 2        130     -155  0.445105  0.554895       0
# 3       -155      135  0.648168  0.351832       1
# 4       -240      195  0.688174  0.311826       0
# ..       ...      ...       ...       ...     ...
# 245      175     -230  0.399123  0.600877       0
# 246      250     -305  0.322568  0.677432       0
# 247     -134      105  0.568085  0.431915       1
# 248     -105     -117  0.588912  0.411088       1
# 249      115     -143  0.530229  0.469771       1
#
# [250 rows x 5 columns]
#           Number of matches: 250
#           Number of bets: 185
#           Number of winning bets: 99
#           Number of losing bets: 86
#           Number of underdog bets: 106
#           Number of underdog wins: 43
#           Number of underdog losses: 63
#           Number of Favorite bets: 78
#           Number of favorite wins: 56
#           Number of favorite losses: 22
#           Number of even bets: 1
#           Number of even wins: 0
#           Number of even losses: 1
#           Profit:
_Reach_cms', 'avg_sub_att_dif', 'R_longest_win_streak', 'R_total_title_bouts', "R_Women's Strawweight_rank", 'R_current_win_streak', 'B_Featherweight_rank', 'B_age', 'R_Flyweight_rank', 'longest_win_streak_dif', 'B_win_by_Decision_Majority', 'R_odds', 'R_ev', 'avg_td_dif', 'win_dif', 'reach_dif', "B_Women's Strawweight_rank", 'B_Flyweight_rank', 'B_current_lose_streak', 'R_Bantamweight_rank', "R_Women's Flyweight_rank", 'R_win_by_Decision_Split', 'R_age', 'R_draw', 'B_Bantamweight_rank', 'B_Lightweight_rank', 'B_Reach_cms', 'B_draw', 'R_Welterweight_rank', 'loss_dif', 'B_ev', 'empty_arena']
#
# model_0
# LogisticRegression(max_iter=50000, random_state=75, solver='newton-cg',
#                    tol=9.6e-05)
# ['R_Reach_cms', 'avg_sub_att_dif', 'R_longest_win_streak', 'R_total_title_bouts', "R_Women's Strawweight_rank", 'R_current_win_streak', 'B_Featherweight_rank', 'B_age', 'R_Flyweight_rank', 'longest_win_streak_dif', 'B_win_by_Decision_Majority', 'R_odds', 'R_ev', 'avg_td_dif', 'win_dif', 'reach_dif', "B_Women's Strawweight_rank", 'B_Flyweight_rank', 'B_current_lose_streak', 'R_Bantamweight_rank', "R_Women's Flyweight_rank", 'R_win_by_Decision_Split', 'R_age', 'R_draw', 'B_Bantamweight_rank', 'B_Lightweight_rank', 'B_Reach_cms', 'B_draw', 'R_Welterweight_rank', 'loss_dif', 'B_ev', 'empty_arena']
# 0
# (4554, 32)
# (4554,)
# (4554, 2)
# (250, 32)
# (250,)
# (250, 2)
#      t1_odds  t2_odds   t1_prob   t2_prob  winner
# 0       -210      175  0.623605  0.376395       1
# 1       -320      250  0.679642  0.320358       1
# 2        130     -155  0.452538  0.547462       0
# 3       -155      135  0.664645  0.335355       1
# 4       -240      195  0.686090  0.313910       0
# ..       ...      ...       ...       ...     ...
# 245      175     -230  0.408885  0.591115       0
# 246      250     -305  0.328494  0.671506       0
# 247     -134      105  0.567083  0.432917       1
# 248     -105     -117  0.590489  0.409511       1
# 249      115     -143  0.534190  0.465810       1
#
# [250 rows x 5 columns]
#           Number of matches: 250
#           Number of bets: 187
#           Number of winning bets: 102
#           Number of losing bets: 85
#           Number of underdog bets: 106
#           Number of underdog wins: 43
#           Number of underdog losses: 63
#           Number of Favorite bets: 80
#           Number of favorite wins: 59
#           Number of favorite losses: 21
#           Number of even bets: 1
#           Number of even wins: 0
#           Number of even losses: 1
#           Profit: 951.746246306082
#           Profit per bet: 5.08955211928386
#           Profit per match: 3.806984985224328
#
#
# HI
# HI
# HI
# HI
# HI
# Current best score is: 26610.054736650498
# Feature: B_Light Heavyweight_rank Score: 26618.124103582068
# Feature: B_Welterweight_rank Score: 26950.25955289586
# The best feature was B_Welterweight_rank.  It scored 26950.25955289586
# Current best score is: 26950.25955289586
# Feature: R_Women's Featherweight_rank Score: 27515.125667457633
# The best feature was R_Women's Featherweight_rank.  It scored 27515.125667457633
# Current best score is: 27515.125667457633
# Feature: B_longest_win_streak Score: 27586.554238886198
# The best feature was B_longest_win_streak.  It scored 27586.554238886198
# Current best score is: 27586.554238886198
# NO IMPROVEMENT
# FINAL BEST SCORE: 27586.554238886198
#
# model_0
# LogisticRegression(max_iter=50000, random_state=75, solver='newton-cg',
#                    tol=9.6e-05)
# ['B_longest_win_streak', "R_Women's Featherweight_rank", 'B_Welterweight_rank', 'R_Reach_cms', 'avg_sub_att_dif', 'R_longest_win_streak', 'R_total_title_bouts', "R_Women's Strawweight_rank", 'R_current_win_streak', 'B_Featherweight_rank', 'B_age', 'R_Flyweight_rank', 'longest_win_streak_dif', 'B_win_by_Decision_Majority', 'R_odds', 'R_ev', 'avg_td_dif', 'win_dif', 'reach_dif', "B_Women's Strawweight_rank", 'B_Flyweight_rank', 'B_current_lose_streak', 'R_Bantamweight_rank', "R_Women's Flyweight_rank", 'R_win_by_Decision_Split', 'R_age', 'R_draw', 'B_Bantamweight_rank', 'B_Lightweight_rank', 'B_Reach_cms', 'B_draw', 'R_Welterweight_rank', 'loss_dif', 'B_ev', 'empty_arena']
# 0
# (4554, 35)
# (4554,)
# (4554, 2)
# (250, 35)
# (250,)
# (250, 2)
#      t1_odds  t2_odds   t1_prob   t2_prob  winner
# 0       -210      175  0.622438  0.377562       1
# 1       -320      250  0.679703  0.320297       1
# 2        130     -155  0.454447  0.545553       0
# 3       -155      135  0.663487  0.336513       1
# 4       -240      195  0.685772  0.314228       0
# ..       ...      ...       ...       ...     ...
# 245      175     -230  0.407810  0.592190       0
# 246      250     -305  0.331161  0.668839       0
# 247     -134      105  0.568877  0.431123       1
# 248     -105     -117  0.590396  0.409604       1
# 249      115     -143  0.534511  0.465489       1
#
# [250 rows x 5 columns]
#           Number of matches: 250
#           Number of bets: 189
#           Number of winning bets: 104
#           Number of losing bets: 85
#           Number of underdog bets: 106
#           Number of underdog wins: 43
#           Number of underdog losses: 63
#           Number of Favorite bets: 82
#           Number of favorite wins: 61
#           Number of favorite losses: 21
#           Number of even bets: 1
#           Number of even wins: 0
#           Number of even losses: 1
#           Profit: 1002.003183613379
#           Profit per bet: 5.301604146102534
#           Profit per match: 4.008012734453516
#
#
# HI
# HI
# HI
# HI
# HI
#
#
# Starting New Run for LogisticRegression
#
#
# Previous Best Score: 27586.554238886198
# solver: newton-cg penalty: l2 tol: 9.6e-05 Score: 27586.554238886198
# solver: newton-cg penalty: l2 tol: 0.0001152 Score: 27586.554238886198
# solver: newton-cg penalty: l2 tol: 7.680000000000001e-05 Score: 27586.554238886198
# solver: newton-cg penalty: l2 tol: 7.6140098254243345 Score: 20834.98814162445
# solver: newton-cg penalty: none tol: 9.6e-05 Score: 26243.35001591675
# solver: newton-cg penalty: none tol: 0.0001152 Score: 26243.35001591675
# solver: newton-cg penalty: none tol: 7.680000000000001e-05 Score: 26243.35001591675
# solver: newton-cg penalty: none tol: 7.6140098254243345 Score: 20678.003554219405
# solver: lbfgs penalty: l2 tol: 9.6e-05 Score: 27486.554238886198
# solver: lbfgs penalty: l2 tol: 0.0001152 Score: 27486.554238886198
# solver: lbfgs penalty: l2 tol: 7.680000000000001e-05 Score: 27486.554238886198
# solver: lbfgs penalty: l2 tol: 7.6140098254243345 Score: 18455.9663665197
# ['B_longest_win_streak', "R_Women's Featherweight_rank", 'B_Welterweight_rank', 'R_Reach_cms', 'avg_sub_att_dif', 'R_longest_win_streak', 'R_total_title_bouts', "R_Women's Strawweight_rank", 'R_current_win_streak', 'B_Featherweight_rank', 'B_age', 'R_Flyweight_rank', 'longest_win_streak_dif', 'B_win_by_Decision_Majority', 'R_odds', 'R_ev', 'avg_td_dif', 'win_dif', 'reach_dif', "B_Women's Strawweight_rank", 'B_Flyweight_rank', 'B_current_lose_streak', 'R_Bantamweight_rank', "R_Women's Flyweight_rank", 'R_win_by_Decision_Split', 'R_age', 'R_draw', 'B_Bantamweight_rank', 'B_Lightweight_rank', 'B_Reach_cms', 'B_draw', 'R_Welterweight_rank', 'loss_dif', 'B_ev', 'empty_arena']
# 0
# (4554, 35)
# (4554,)
# (4554, 2)
# (250, 35)
# (250,)
# (250, 2)
#      t1_odds  t2_odds   t1_prob   t2_prob  winner
# 0       -210      175  0.622438  0.377562       1
# 1       -320      250  0.679703  0.320297       1
# 2        130     -155  0.454447  0.545553       0
# 3       -155      135  0.663487  0.336513       1
# 4       -240      195  0.685772  0.314228       0
# ..       ...      ...       ...       ...     ...
# 245      175     -230  0.407810  0.592190       0
# 246      250     -305  0.331161  0.668839       0
# 247     -134      105  0.568877  0.431123       1
# 248     -105     -117  0.590396  0.409604       1
# 249      115     -143  0.534511  0.465489       1
#
# [250 rows x 5 columns]
#           Number of matches: 250
#           Number of bets: 189
#           Number of winning bets: 104
#           Number of losing bets: 85
#           Number of underdog bets: 106
#           Number of underdog wins: 43
#           Number of underdog losses: 63
#           Number of Favorite bets: 82
#           Number of favorite wins: 61
#           Number of favorite losses: 21
#           Number of even bets: 1
#           Number of even wins: 0
#           Number of even losses: 1
#           Profit: 1002.003183613379
#           Profit per bet: 5.301604146102534
#           Profit per match: 4.008012734453516
#
#
# HI
# HI
# HI
# HI
# HI
# The original score is 27586.554238886198
# Score:  27515.125667457633
# Score:  26950.25955289586
# Score:  26527.716248797136
# Score:  25377.02819933954
# Score:  24880.480825854804
# Score:  27586.554238886198
# Score:  25479.540981210936
# Score:  25077.792913586763
# Score:  26352.14247031903
# Score:  25915.96023929859
# Score:  13810.944254617127
# Score:  22510.805590462354
# Score:  27586.554238886198
# Score:  25528.18156429777
# Score:  21646.083929122797
# Score:  11245.882763517551
# Score:  20640.952904155463
# Score:  21008.51678309616
# ...
# 2                     USA    Red  ...           2.0              3:48
# 3                     USA   Blue  ...           3.0              5:00
# 4                     USA    Red  ...           2.0              2:11
# ..                    ...    ...  ...           ...               ...
# 245                   USA    Red  ...           NaN               NaN
# 246  United Arab Emirates    Red  ...           NaN               NaN
# 247  United Arab Emirates   Blue  ...           NaN               NaN
# 248  United Arab Emirates   Blue  ...           NaN               NaN
# 249  United Arab Emirates   Blue  ...           NaN               NaN
#
#     total_fight_time_secs  r_dec_odds  b_dec_odds  r_sub_odds  b_sub_odds  \
# 0                  1500.0       500.0       500.0       600.0      1100.0
# 1                   900.0      -125.0       500.0      1000.0      1000.0
# 2                   528.0       275.0       250.0       600.0       240.0
# 3                   900.0       120.0       275.0       650.0      1400.0
# 4                   431.0       380.0       500.0      1100.0      1600.0
# ..                    ...         ...         ...         ...         ...
# 245                   NaN       350.0       125.0      1400.0       450.0
# 246                   NaN       650.0       750.0       750.0      1600.0
# 247                   NaN       325.0       300.0       850.0       675.0
# 248                   NaN       125.0       140.0      1200.0      1000.0
# 249                   NaN       260.0       200.0      1000.0      1800.0
#
#      r_ko_odds  b_ko_odds  label
# 0        110.0      400.0      1
# 1        400.0      900.0      1
# 2        800.0      600.0      0
# 3        750.0      450.0      1
# 4       -110.0      450.0      0
# ..         ...        ...    ...
# 245      600.0      425.0      0
# 246      675.0     -220.0      0
# 247      150.0      500.0      1
# 248      900.0      600.0      1
# 249      800.0      175.0      1
#
# [250 rows x 120 columns]
# ['R_fighter', 'B_fighter', 'R_odds', 'B_odds', 'R_ev', 'B_ev', 'date', 'location', 'country', 'Winner', 'title_bout', 'weight_class', 'gender', 'no_of_rounds', 'B_current_lose_streak', 'B_current_win_streak', 'B_draw', 'B_avg_SIG_STR_landed', 'B_avg_SIG_STR_pct', 'B_avg_SUB_ATT', 'B_avg_TD_landed', 'B_avg_TD_pct', 'B_longest_win_streak', 'B_losses', 'B_total_rounds_fought', 'B_total_title_bouts', 'B_win_by_Decision_Majority', 'B_win_by_Decision_Split', 'B_win_by_Decision_Unanimous', 'B_win_by_KO/TKO', 'B_win_by_Submission', 'B_win_by_TKO_Doctor_Stoppage', 'B_wins', 'B_Stance', 'B_Height_cms', 'B_Reach_cms', 'B_Weight_lbs', 'R_current_lose_streak', 'R_current_win_streak', 'R_draw', 'R_avg_SIG_STR_landed', 'R_avg_SIG_STR_pct', 'R_avg_SUB_ATT', 'R_avg_TD_landed', 'R_avg_TD_pct', 'R_longest_win_streak', 'R_losses', 'R_total_rounds_fought', 'R_total_title_bouts', 'R_win_by_Decision_Majority', 'R_win_by_Decision_Split', 'R_win_by_Decision_Unanimous', 'R_win_by_KO/TKO', 'R_win_by_Submission', 'R_win_by_TKO_Doctor_Stoppage', 'R_wins', 'R_Stance', 'R_Height_cms', 'R_Reach_cms', 'R_Weight_lbs', 'R_age', 'B_age', 'lose_streak_dif', 'win_streak_dif', 'longest_win_streak_dif', 'win_dif', 'loss_dif', 'total_round_dif', 'total_title_bout_dif', 'ko_dif', 'sub_dif', 'height_dif', 'reach_dif', 'age_dif', 'sig_str_dif', 'avg_sub_att_dif', 'avg_td_dif', 'empty_arena', 'constant_1', 'B_match_weightclass_rank', 'R_match_weightclass_rank', "R_Women's Flyweight_rank", "R_Women's Featherweight_rank", "R_Women's Strawweight_rank", "R_Women's Bantamweight_rank", 'R_Heavyweight_rank', 'R_Light Heavyweight_rank', 'R_Middleweight_rank', 'R_Welterweight_rank', 'R_Lightweight_rank', 'R_Featherweight_rank', 'R_Bantamweight_rank', 'R_Flyweight_rank', 'R_Pound-for-Pound_rank', "B_Women's Flyweight_rank", "B_Women's Featherweight_rank", "B_Women's Strawweight_rank", "B_Women's Bantamweight_rank", 'B_Heavyweight_rank', 'B_Light Heavyweight_rank', 'B_Middleweight_rank', 'B_Welterweight_rank', 'B_Lightweight_rank', 'B_Featherweight_rank', 'B_Bantamweight_rank', 'B_Flyweight_rank', 'B_Pound-for-Pound_rank', 'better_rank', 'finish', 'finish_details', 'finish_round', 'finish_round_time', 'total_fight_time_secs', 'r_dec_odds', 'b_dec_odds', 'r_sub_odds', 'b_sub_odds', 'r_ko_odds', 'b_ko_odds', 'label']
# model_17
# NuSVC(probability=True, random_state=75)
# ['R_Lightweight_rank', 'R_Flyweight_rank', 'B_win_by_KO/TKO', 'B_Lightweight_rank', 'B_win_by_Decision_Unanimous', 'B_ev', 'win_streak_dif', 'R_ev', 'R_Welterweight_rank', 'B_Flyweight_rank', 'B_losses', 'R_total_title_bouts', 'B_avg_SUB_ATT', 'height_dif', "R_Women's Featherweight_rank", 'empty_arena', 'country', 'R_odds', 'location', 'R_avg_SIG_STR_landed', 'B_avg_TD_landed']
# 182
# Current best score is: 4595.0
# Feature: B_win_by_Decision_Split Score: 4895.0
# Feature: B_win_by_Submission Score: 5070.0
# The best feature was B_win_by_Submission.  It scored 5070.0
# Current best score is: 5070.0
# Feature: B_total_title_bouts Score: 5393.0
# The best feature was B_total_title_bouts.  It scored 5393.0
# Current best score is: 5393.0
# NO IMPROVEMENT
# FINAL BEST SCORE: 5393.0
#
# model_17
# NuSVC(probability=True, random_state=75)
# ['B_total_title_bouts', 'B_win_by_Submission', 'R_Lightweight_rank', 'R_Flyweight_rank', 'B_win_by_KO/TKO', 'B_Lightweight_rank', 'B_win_by_Decision_Unanimous', 'B_ev', 'win_streak_dif', 'R_ev', 'R_Welterweight_rank', 'B_Flyweight_rank', 'B_losses', 'R_total_title_bouts', 'B_avg_SUB_ATT', 'height_dif', "R_Women's Featherweight_rank", 'empty_arena', 'country', 'R_odds', 'location', 'R_avg_SIG_STR_landed', 'B_avg_TD_landed']
# 182
# (3513, 191)
# (3513,)
# (3513, 2)
# (250, 191)
# (250,)
# (250, 2)
#      t1_odds  t2_odds   t1_prob   t2_prob  winner
# 0       -210      175  0.449039  0.550961       1
# 1       -320      250  0.467403  0.532597       1
# 2        130     -155  0.526260  0.473740       0
# 3       -155      135  0.633903  0.366097       1
# 4       -240      195  0.653040  0.346960       0
# ..       ...      ...       ...       ...     ...
# 245      175     -230  0.509853  0.490147       0
# 246      250     -305  0.460372  0.539628       0
# 247     -134      105  0.742775  0.257225       1
# 248     -105     -117  0.629299  0.370701       1
# 249      115     -143  0.588253  0.411747       1
#
# [250 rows x 5 columns]
#           Number of matches: 250
#           Number of bets: 0
#           Number of winning bets: 0
#           Number of losing bets: 0
#           Number of underdog bets: 0
#           Number of underdog wins: 0
#           Number of underdog losses: 0
#           Number of Favorite bets: 0
#           Number of favorite wins: 0
#           Number of favorite losses: 0
#           Number of even bets: 0
#           Number of even wins: 0
#           Number of even losses: 0
#           Profit: 0
#           Profit per bet: 0
#           Profit per match: 0.0
#
#
# HI
# HI
# HI
# HI
# HI
#
#
# Starting New Run for NuSVC
#
#
# Previous Best Score: 5393.0
# nu:  0.5 tol:  0.001 Score:  5393.0
# nu:  0.5 tol:  0.0011 Score:  5393.0
# nu:  0.5 tol:  0.0009000000000000001 Score:  5393.0
# nu:  0.5 tol:  0.20701385600043498 Score:  1580.0
# nu:  0.55 tol:  0.001 Score:  1913.0
# nu:  0.55 tol:  0.0011 Score:  1913.0
# nu:  0.55 tol:  0.0009000000000000001 Score:  1913.0
# nu:  0.55 tol:  0.20701385600043498 Score:  1155.0
# nu:  0.45 tol:  0.001 Score:  3318.0
# nu:  0.45 tol:  0.0011 Score:  3318.0
# nu:  0.45 tol:  0.0009000000000000001 Score:  3418.0
# nu:  0.45 tol:  0.20701385600043498 Score:  1325.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\OneDrive\github\tiger-millionaire\automated_model_creation\TM-Optimize-Models.ipynb in <module>
#      10     #2 Set hyperparameters
#      11     #def tune_hyperparameters(input_model, input_features, input_df, input_labels, odds_input):
# ---> 12     test_model = tune_hyperparameters(test_model, test_model_features, df_train, label_train, odds_train,
#      13                                       min_ev=test_model_ev)
#      14     print_model()
#
# ~\OneDrive\github\tiger-millionaire\automated_model_creation\functions.py in tune_hyperparameters(input_model, input_features, input_df, input_labels, odds_input, min_ev)
#    1339     elif isinstance(input_model, NuSVC):
#    1340         while(keep_going):
# -> 1341             pos_model = (tune_NuSVC(best_model, input_features, input_df, input_labels, odds_input, min_ev=min_ev))
#    1342
#    1343             if str(pos_model) == str(best_model):  #Direct comparisons don't seem to work....
#
# ~\OneDrive\github\tiger-millionaire\automated_model_creation\functions.py in tune_NuSVC(input_model, input_features, input_df, input_labels, odds_input, min_ev)
#    1190         for t in tol:
#    1191             test_model = NuSVC(nu=n, tol=t, probability=True, random_state=75)
# -> 1192             score = get_ev(input_df, test_model, input_features, input_labels, odds_input, min_ev=min_ev)
#    1193             if score > best_score:
#    1194                 best_score = score
#
# ~\OneDrive\github\tiger-millionaire\automated_model_creation\functions.py in get_ev(input_df, input_model, input_features, input_labels, odds_input, min_ev, verbose, get_total)
#      39                                 get_total=get_total)
#      40     else:
# ---> 41         best_score = custom_cv_eval(df_sel, input_model, labels_sel, odds_sel, min_ev = min_ev, verbose=verbose,
#      42                                 get_total=get_total)
#      43
#
# ~\OneDrive\github\tiger-millionaire\automated_model_creation\functions.py in custom_cv_eval(df, m, labels, odds, min_ev, verbose, get_total)
#     258         scaled_test = scaler.transform(X_test)
#     259
# --> 260         m.fit(scaled_train, y_train)
#     261         probs=m.predict_proba(scaled_test)
#     262         #print(probs)
#
# ~\anaconda3\lib\site-packages\sklearn\svm\_base.py in fit(self, X, y, sample_weight)
#     224
#     225         seed = rnd.randint(np.iinfo('i').max)
# --> 226         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     227         # see comment on the other call to np.iinfo in this file
#     228
#
# ~\anaconda3\lib\site-packages\sklearn\svm\_base.py in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     275         self.support_, self.support_vectors_, self._n_support, \
#     276             self.dual_coef_, self.intercept_, self._probA, \
# --> 277             self._probB, self.fit_status_ = libsvm.fit(
#     278                 X, y,
#     279                 svm_type=solver_type, sample_weight=sample_weight,
#
# sklearn\svm\_libsvm.pyx in sklearn.svm._libsvm.fit()
#
# ValueError: specified nu is infeasible
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-6d7aabfb3f55> in <module>
#       6     print()
#       7     print()
# ----> 8     get_ipython().run_line_magic('run', 'TM-Optimize-Models.ipynb')
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2342                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2343             with self.builtin_trap:
# -> 2344                 result = fn(*args, **kwargs)
#    2345             return result
#    2346
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~\anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\lib\site-packages\IPython\core\magics\execution.py in run(self, parameter_s, runner, file_finder)
#     722             with preserve_keys(self.shell.user_ns, '__file__'):
#     723                 self.shell.user_ns['__file__'] = filename
# --> 724                 self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     725             return
#     726
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2829                     result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2830                     if raise_exceptions:
# -> 2831                         result.raise_error()
#    2832                     elif not result.success:
#    2833                         break
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in raise_error(self)
#     329             raise self.error_before_exec
#     330         if self.error_in_exec is not None:
# --> 331             raise self.error_in_exec
#     332
#     333     def __repr__(self):
#
#     [... skipping hidden 1 frame]
#
# <ipython-input-4-3106e3e4a3a0> in <module>
#      10     #2 Set hyperparameters
#      11     #def tune_hyperparameters(input_model, input_features, input_df, input_labels, odds_input):
# ---> 12     test_model = tune_hyperparameters(test_model, test_model_features, df_train, label_train, odds_train,
#      13                                       min_ev=test_model_ev)
#      14     print_model()
#
# ~\OneDrive\github\tiger-millionaire\automated_model_creation\functions.py in tune_hyperparameters(input_model, input_features, input_df, input_labels, odds_input, min_ev)
#    1339     elif isinstance(input_model, NuSVC):
#    1340         while(keep_going):
# -> 1341             pos_model = (tune_NuSVC(best_model, input_features, input_df, input_labels, odds_input, min_ev=min_ev))
#    1342
#    1343             if str(pos_model) == str(best_model):  #Direct comparisons don't seem to work....
#
# ~\OneDrive\github\tiger-millionaire\automated_model_creation\functions.py in tune_NuSVC(input_model, input_features, input_df, input_labels, odds_input, min_ev)
#    1190         for t in tol:
#    1191             test_model = NuSVC(nu=n, tol=t, probability=True, random_state=75)
# -> 1192             score = get_ev(input_df, test_model, input_features, input_labels, odds_input, min_ev=min_ev)
#    1193             if score > best_score:
#    1194                 best_score = score
#
# ~\OneDrive\github\tiger-millionaire\automated_model_creation\functions.py in get_ev(input_df, input_model, input_features, input_labels, odds_input, min_ev, verbose, get_total)
#      39                                 get_total=get_total)
#      40     else:
# ---> 41         best_score = custom_cv_eval(df_sel, input_model, labels_sel, odds_sel, min_ev = min_ev, verbose=verbose,
#      42                                 get_total=get_total)
#      43
#
# ~\OneDrive\github\tiger-millionaire\automated_model_creation\functions.py in custom_cv_eval(df, m, labels, odds, min_ev, verbose, get_total)
#     258         scaled_test = scaler.transform(X_test)
#     259
# --> 260         m.fit(scaled_train, y_train)
#     261         probs=m.predict_proba(scaled_test)
#     262         #print(probs)
#
# ~\anaconda3\lib\site-packages\sklearn\svm\_base.py in fit(self, X, y, sample_weight)
#     224
#     225         seed = rnd.randint(np.iinfo('i').max)
# --> 226         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     227         # see comment on the other call to np.iinfo in this file
#     228
#
# ~\anaconda3\lib\site-packages\sklearn\svm\_base.py in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     275         self.support_, self.support_vectors_, self._n_support, \
#     276             self.dual_coef_, self.intercept_, self._probA, \
# --> 277             self._probB, self.fit_status_ = libsvm.fit(
#     278                 X, y,
#     279                 svm_type=solver_type, sample_weight=sample_weight,
#
# sklearn\svm\_libsvm.pyx in sklearn.svm._libsvm.fit()
#
# ValueError: specified nu is infeasible

# %%
#model_num = 15

# %%
#%run TM-Optimize-Models.ipynb
