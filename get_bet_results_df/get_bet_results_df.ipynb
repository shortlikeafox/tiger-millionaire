# %% [markdown]
# # What we want to do is create a dataframe for all the fights in ufc-master.csv
#
#
# * r_fighter
# * b_fighter
# * r_prob
# * b_prob
# * r_ev
# * b_ev
# * bet
# * winner
# * profit
#
# We are training and testing on the same set.  So this shouldn't be used in production.  I'm making this for a Coursera Tableau course

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# %%
import sys
sys.path.append('../automated_model_creation') #We need to access the function file

# %%
import pandas as pd
import numpy as np
from functions import custom_cv_eval, get_ev_from_df, get_bet_ev, get_bet_return
import random
import csv

# %%
df = pd.read_csv("../data/kaggle_data/ufc-master.csv")
df_upcoming = pd.read_csv('../data/kaggle_data/upcoming-event.csv')
len(df)
# Out:
# 4747

# %%
#Let's put all the labels in a dataframe
df['label'] = ''
#If the winner is not Red or Blue we can remove it.
mask = df['Winner'] == 'Red'
df['label'][mask] = 0
mask = df['Winner'] == 'Blue'
df['label'][mask] = 1

#df["Winner"] = df["Winner"].astype('category')
#df = df[(df['Winner'] != 'Blue') | (df['Winner'] == 'Red') ]


#Make sure lable is numeric
df['label'] = pd.to_numeric(df['label'], errors='coerce')
# Out:
# <ipython-input-5-e6abcb5e0e70>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['label'][mask] = 0
# <ipython-input-5-e6abcb5e0e70>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['label'][mask] = 1

# %%
#Let's fix the date
df['date'] = pd.to_datetime(df['date'])

# %%
#Create a label df:
label_df = df['label']

#Let's create an odds df too:
odds_df = df[['R_odds', 'B_odds']]

# %%
df_train = df.copy()
odds_train = odds_df.copy()
label_train = label_df.copy()

df_test = df.copy()
odds_test = odds_df.copy()
label_test = label_df.copy()

# %%
#Unranked fighters fix
weightclass_list = ['B_match_weightclass_rank', 'R_match_weightclass_rank', "R_Women's Flyweight_rank", "R_Women's Featherweight_rank", "R_Women's Strawweight_rank", "R_Women's Bantamweight_rank", 'R_Heavyweight_rank', 'R_Light Heavyweight_rank', 'R_Middleweight_rank', 'R_Welterweight_rank', 'R_Lightweight_rank', 'R_Featherweight_rank', 'R_Bantamweight_rank', 'R_Flyweight_rank', 'R_Pound-for-Pound_rank', "B_Women's Flyweight_rank", "B_Women's Featherweight_rank", "B_Women's Strawweight_rank", "B_Women's Bantamweight_rank", 'B_Heavyweight_rank', 'B_Light Heavyweight_rank', 'B_Middleweight_rank', 'B_Welterweight_rank', 'B_Lightweight_rank', 'B_Featherweight_rank', 'B_Bantamweight_rank', 'B_Flyweight_rank', 'B_Pound-for-Pound_rank']
df_train[weightclass_list] = df_train[weightclass_list].fillna(17)
df_test[weightclass_list] = df_test[weightclass_list].fillna(17)

# %%
def get_bets(input_model, input_features, input_ev, train_df, train_labels, train_odds, test_df, test_labels,
             test_odds, verbose=True):
    fighters_test = df[['R_ev', 'B_ev','date', 'R_fighter', 'B_fighter']]
    #Train model.  
    df_train = train_df[input_features].copy()
    df_test = test_df[input_features].copy()
    df_train = df_train.dropna()
    df_test = df_test.dropna()
        
    df_train = pd.get_dummies(df_train)
    df_test = pd.get_dummies(df_test)
    df_train, df_test = df_train.align(df_test, join='left', axis=1)    #Ensures both sets are dummified the same
    df_test = df_test.fillna(0)

    #LOOK AT get_ev and prepare the labels and odds
    
    labels_train = train_labels[train_labels.index.isin(df_train.index)]
    odds_train = train_odds[train_odds.index.isin(df_train.index)] 
    labels_test = test_labels[test_labels.index.isin(df_test.index)]
    odds_test = test_odds[test_odds.index.isin(df_test.index)] 
    fighters_test = fighters_test[fighters_test.index.isin(df_test.index)]

    input_model.fit(df_train, labels_train)
    
    probs = input_model.predict_proba(df_test)
    odds_test = np.array(odds_test)  
    fighters_test = np.array(fighters_test)
    #display(fighters_test)
    prepped_test = list(zip(fighters_test[:, -2], fighters_test[:, -1], fighters_test[:, -3], odds_test[:, -2], odds_test[:, -1], 
                            fighters_test[:, -5], fighters_test[:, -4], probs[:, 0], probs[:, 1], labels_test))
    ev_df = pd.DataFrame(prepped_test, columns=['t1_name', 't2_name', 'date', 't1_odds', 't2_odds',
                                                        'R_ev', 'B_ev','t1_prob', 't2_prob', 
                                                         'winner'])
    
    #display(ev_prepped_df)
    min_ev = input_ev
    #display_bets(ev_prepped_df, input_ev)
    bet_list = []
    for index, row in ev_df.iterrows():
        t1_bet_ev = get_bet_ev(row['t1_odds'], row['t1_prob'])
        t2_bet_ev = get_bet_ev(row['t2_odds'], row['t2_prob'])
        #print(f"ODDS:{row['t2_odds']} PROB: {row['t2_prob']} EV: {t2_bet_ev}")
        t1_bet_return = get_bet_return(row['t1_odds'])
        t2_bet_return = get_bet_return(row['t2_odds'])
        print(f"{row['t1_name']} vs. {row['t2_name']}")
        if t1_bet_ev > min_ev:
            print(f"{row['t1_name']} has an EV of {round(t1_bet_ev, 2)} on odds of {round(row['t1_odds'],2)}.  They have {round(row['t1_prob']*100,2)}", 
                  "% chance of winning.")
            bet_list.append('Red')
        elif t2_bet_ev > min_ev:
            print(f"{row['t2_name']} has an EV of {round(t2_bet_ev, 2)} on odds of {round(row['t2_odds'],2)}.  They have {round(row['t2_prob']*100,2)}", 
                  "% chance of winning.")
            bet_list.append('Blue')
        else:
            print(f"No bets.  EV1:{t1_bet_ev}. EV2: {t2_bet_ev}")
            print(f"{row['t1_name']} has an EV of {round(t1_bet_ev, 2)} on odds of {round(row['t1_odds'],2)}.  They have {round(row['t1_prob']*100,2)}", 
                  "% chance of winning.")
            bet_list.append(None)
        print()    
    ev_df['bet'] = bet_list
    return(ev_df)

# %%
with open('../automated_model_creation/models.csv', newline='') as f:
    reader = csv.reader(f)
    models = list(reader)
    
#print(len(models))

#set the model choice:
model_choice = 7

#print(models)



model = eval(models[1][model_choice])
features = eval(models[2][model_choice])
ev = eval(models[3][model_choice])
#print()
#print(model, features, ev)

# %%
output_df = get_bets(model, features, ev, df_train, label_train, odds_train, df_test, label_test,
                         odds_test, verbose = True)
# Out:
# Israel Adesanya vs. Marvin Vettori
# Marvin Vettori has an EV of 185.0 on odds of 185.  They have 100.0 % chance of winning.
#
# Deiveson Figueiredo vs. Brandon Moreno
# Brandon Moreno has an EV of 150.0 on odds of 150.  They have 100.0 % chance of winning.
#
# Leon Edwards vs. Nate Diaz
# Leon Edwards has an EV of 8.26 on odds of -500.  They have 90.22 % chance of winning.
#
# Demian Maia vs. Belal Muhammad
# Demian Maia has an EV of 50.11 on odds of 170.  They have 55.6 % chance of winning.
#
# Paul Craig vs. Jamahal Hill
# Paul Craig has an EV of 67.62 on odds of 210.  They have 54.07 % chance of winning.
#
# Drew Dober vs. Brad Riddell
# Brad Riddell has an EV of 1.06 on odds of 120.  They have 45.94 % chance of winning.
#
# Eryk Anders vs. Darren Stewart
# Eryk Anders has an EV of 0.09 on odds of -150.  They have 60.06 % chance of winning.
#
# Lauren Murphy vs. Joanne Calderwood
# Joanne Calderwood has an EV of 19.05 on odds of -148.  They have 71.04 % chance of winning.
#
# Movsar Evloev vs. Hakeem Dawodu
# Hakeem Dawodu has an EV of 71.88 on odds of 188.  They have 59.68 % chance of winning.
#
# Pannie Kianzad vs. Alexis Davis
# Alexis Davis has an EV of 23.43 on odds of 187.  They have 43.01 % chance of winning.
#
# Matt Frevola vs. Terrance McKinney
# No bets.  EV1:-2.9333890765100534. EV2: -10.962482465244221
# Matt Frevola has an EV of -2.93 on odds of -210.  They have 65.75 % chance of winning.
#
# Chase Hooper vs. Steven Peterson
# Chase Hooper has an EV of 28.45 on odds of -108.  They have 66.69 % chance of winning.
#
# Fares Ziam vs. Luigi Vendramini
# Fares Ziam has an EV of 33.74 on odds of -125.  They have 74.3 % chance of winning.
#
# Carlos Felipe vs. Jake Collier
# Jake Collier has an EV of 25.4 on odds of 130.  They have 54.52 % chance of winning.
#
# Jairzinho Rozenstruik vs. Augusto Sakai
# Jairzinho Rozenstruik has an EV of 15.94 on odds of -118.  They have 62.76 % chance of winning.
#
# Walt Harris vs. Marcin Tybura
# Marcin Tybura has an EV of 12.15 on odds of -177.  They have 71.66 % chance of winning.
#
# Roman Dolidze vs. Laureano Staropoli
# Roman Dolidze has an EV of 38.48 on odds of -150.  They have 83.09 % chance of winning.
#
# Santiago Ponzinibbio vs. Miguel Baeza
# Santiago Ponzinibbio has an EV of 3.22 on odds of 105.  They have 50.35 % chance of winning.
#
# Dusko Todorovic vs. Gregory Rodrigues
# Gregory Rodrigues has an EV of 17.19 on odds of 140.  They have 48.83 % chance of winning.
#
# Montana De La Rosa vs. Ariane Lipski
# Montana De La Rosa has an EV of 26.67 on odds of -114.  They have 67.48 % chance of winning.
#
# Tanner Boser vs. Ilir Latifi
# Ilir Latifi has an EV of 2.21 on odds of 160.  They have 39.31 % chance of winning.
#
# Francisco Trinaldo vs. Muslim Salikhov
# Francisco Trinaldo has an EV of 26.19 on odds of 180.  They have 45.07 % chance of winning.
#
# Makwan Amirkhani vs. Kamuela Kirk
# Makwan Amirkhani has an EV of 12.21 on odds of -230.  They have 78.21 % chance of winning.
#
# Manon Fiorot vs. Tabatha Ricci
# Manon Fiorot has an EV of 48.71 on odds of -165.  They have 92.59 % chance of winning.
#
# Sean Woodson vs. Youssef Zalal
# Sean Woodson has an EV of 29.92 on odds of -200.  They have 86.61 % chance of winning.
#
# Claudio Puelles vs. Jordan Leavitt
# Claudio Puelles has an EV of 7.72 on odds of 165.  They have 40.65 % chance of winning.
#
# Rob Font vs. Cody Garbrandt
# Rob Font has an EV of 55.31 on odds of -130.  They have 87.78 % chance of winning.
#
# Yan Xiaonan vs. Carla Esparza
# No bets.  EV1:-0.09648690771534518. EV2: -8.317786528292288
# Yan Xiaonan has an EV of -0.1 on odds of -137.  They have 57.75 % chance of winning.
#
# Justin Tafa vs. Jared Vanderaa
# Justin Tafa has an EV of 11.0 on odds of -178.  They have 71.07 % chance of winning.
#
# Felicia Spencer vs. Norma Dumont
# Norma Dumont has an EV of 2.89 on odds of 157.  They have 40.04 % chance of winning.
#
# Ricardo Ramos vs. Bill Algeo
# Bill Algeo has an EV of 1.15 on odds of -145.  They have 59.87 % chance of winning.
#
# Jack Hermansson vs. Edmen Shahbazyan
# Jack Hermansson has an EV of 24.96 on odds of -132.  They have 71.1 % chance of winning.
#
# Ben Rothwell vs. Chris Barnett
# Ben Rothwell has an EV of 24.33 on odds of -345.  They have 96.39 % chance of winning.
#
# Court McGee vs. Claudio Silva
# Court McGee has an EV of 4.56 on odds of 105.  They have 51.0 % chance of winning.
#
# Bruno Silva vs. Victor Rodriguez
# Bruno Silva has an EV of 6.43 on odds of -355.  They have 83.04 % chance of winning.
#
# Josh Culibao vs. Shayilan Nuerdanbieke
# Josh Culibao has an EV of 6.31 on odds of -235.  They have 74.58 % chance of winning.
#
# David Dvorak vs. Juancamilo Ronderos
# David Dvorak has an EV of 12.09 on odds of -490.  They have 93.09 % chance of winning.
#
# Rafael Alves vs. Damir Ismagulov
# Rafael Alves has an EV of 116.36 on odds of 400.  They have 43.27 % chance of winning.
#
# Charles Oliveira vs. Michael Chandler
# Charles Oliveira has an EV of 54.86 on odds of -130.  They have 87.53 % chance of winning.
#
# Tony Ferguson vs. Beneil Dariush
# Beneil Dariush has an EV of 68.03 on odds of -147.  They have 100.0 % chance of winning.
#
# Matt Schnell vs. Rogerio Bontorin
# Rogerio Bontorin has an EV of 17.17 on odds of 145.  They have 47.82 % chance of winning.
#
# Katlyn Chookagian vs. Viviane Araujo
# Katlyn Chookagian has an EV of 10.95 on odds of -127.  They have 62.07 % chance of winning.
#
# Shane Burgos vs. Edson Barboza
# Edson Barboza has an EV of 21.35 on odds of 127.  They have 53.46 % chance of winning.
#
# Jacare Souza vs. Andre Muniz
# Jacare Souza has an EV of 58.63 on odds of -117.  They have 85.53 % chance of winning.
#
# Lando Vannata vs. Mike Grundy
# Mike Grundy has an EV of 22.34 on odds of -125.  They have 67.97 % chance of winning.
#
# Jordan Wright vs. Jamie Pickett
# Jamie Pickett has an EV of 1.44 on odds of -112.  They have 53.59 % chance of winning.
#
# Andrea Lee vs. Antonina Shevchenko
# No bets.  EV1:-0.42436370543738633. EV2: -7.944333270015257
# Andrea Lee has an EV of -0.42 on odds of 100.  They have 49.79 % chance of winning.
#
# Gina Mazany vs. Priscila Cachoeira
# Gina Mazany has an EV of 12.44 on odds of -235.  They have 78.87 % chance of winning.
#
# Kevin Aguilar vs. Tucker Lutz
# Tucker Lutz has an EV of 8.75 on odds of -140.  They have 63.44 % chance of winning.
#
# Christos Giagos vs. Sean Soriano
# Christos Giagos has an EV of 9.18 on odds of -225.  They have 75.58 % chance of winning.
#
# Marina Rodriguez vs. Michelle Waterson
# Marina Rodriguez has an EV of 14.19 on odds of -235.  They have 80.1 % chance of winning.
#
# Donald Cerrone vs. Alex Morono
# Donald Cerrone has an EV of 54.42 on odds of -150.  They have 92.65 % chance of winning.
#
# Neil Magny vs. Geoff Neal
# Neil Magny has an EV of 104.73 on odds of 155.  They have 80.28 % chance of winning.
#
# Maurice Greene vs. Marcos Rogerio de Lima
# Maurice Greene has an EV of 80.47 on odds of 157.  They have 70.22 % chance of winning.
#
# Diego Ferreira vs. Gregor Gillespie
# Gregor Gillespie has an EV of 6.19 on odds of -142.  They have 62.31 % chance of winning.
#
# Phil Hawes vs. Kyle Daukaus
# Phil Hawes has an EV of 29.01 on odds of 132.  They have 55.61 % chance of winning.
#
# Ludovit Klein vs. Michael Trizano
# Ludovit Klein has an EV of 4.26 on odds of -250.  They have 74.47 % chance of winning.
#
# Junyong Park vs. Tafon Nchukwi
# Junyong Park has an EV of 28.73 on odds of 135.  They have 54.78 % chance of winning.
#
# Christian Aguilera vs. Carlston Harris
# Christian Aguilera has an EV of 173.83 on odds of 175.  They have 99.58 % chance of winning.
#
# Dominick Reyes vs. Jiri Prochazka
# Dominick Reyes has an EV of 40.69 on odds of -120.  They have 76.74 % chance of winning.
#
# Giga Chikadze vs. Cub Swanson
# Cub Swanson has an EV of 30.01 on odds of 180.  They have 46.43 % chance of winning.
#
# Sean Strickland vs. Krzysztof Jotko
# Krzysztof Jotko has an EV of 104.11 on odds of 205.  They have 66.92 % chance of winning.
#
# Merab Dvalishvili vs. Cody Stamann
# Cody Stamann has an EV of 245.0 on odds of 245.  They have 100.0 % chance of winning.
#
# Randa Markos vs. Luana Pinheiro
# Luana Pinheiro has an EV of 54.26 on odds of -155.  They have 93.77 % chance of winning.
#
# Kai Kamaka vs. TJ Brown
# TJ Brown has an EV of 17.91 on odds of 142.  They have 48.72 % chance of winning.
#
# Poliana Botelho vs. Luana Carolina
# Poliana Botelho has an EV of 17.47 on odds of -245.  They have 83.42 % chance of winning.
#
# Loma Lookboonmee vs. Sam Hughes
# Loma Lookboonmee has an EV of 0.84 on odds of -420.  They have 81.45 % chance of winning.
#
# Andreas Michailidis vs. KB Bhullar
# Andreas Michailidis has an EV of 6.74 on odds of -190.  They have 69.94 % chance of winning.
#
# Luke Sanders vs. Felipe Colares
# Luke Sanders has an EV of 14.96 on odds of -127.  They have 64.32 % chance of winning.
#
# Kamaru Usman vs. Jorge Masvidal
# Kamaru Usman has an EV of 30.78 on odds of -320.  They have 99.64 % chance of winning.
#
# Zhang Weili vs. Rose Namajunas
# Zhang Weili has an EV of 1.8 on odds of -200.  They have 67.87 % chance of winning.
#
# Valentina Shevchenko vs. Jessica Andrade
# Valentina Shevchenko has an EV of 15.84 on odds of -450.  They have 94.78 % chance of winning.
#
# Uriah Hall vs. Chris Weidman
# Uriah Hall has an EV of 29.98 on odds of 140.  They have 54.16 % chance of winning.
#
# Anthony Smith vs. Jimmy Crute
# Anthony Smith has an EV of 31.03 on odds of 210.  They have 42.27 % chance of winning.
#
# Alex Oliveira vs. Randy Brown
# Alex Oliveira has an EV of 5.98 on odds of 105.  They have 51.7 % chance of winning.
#
# Dwight Grant vs. Stefan Sekulic
# No bets.  EV1:-3.383708433906129. EV2: -1.7818913140704282
# Dwight Grant has an EV of -3.38 on odds of -175.  They have 61.48 % chance of winning.
#
# Karl Roberson vs. Brendan Allen
# Karl Roberson has an EV of 10.92 on odds of 115.  They have 51.59 % chance of winning.
#
# Pat Sabatini vs. Tristan Connelly
# Tristan Connelly has an EV of 0.74 on odds of 200.  They have 33.58 % chance of winning.
#
# Danaa Batgerel vs. Kevin Natividad
# Danaa Batgerel has an EV of 3.98 on odds of -230.  They have 72.47 % chance of winning.
#
# Kazula Vargas vs. Rong Zhu
# Kazula Vargas has an EV of 29.99 on odds of 175.  They have 47.27 % chance of winning.
#
# Aori Qileng vs. Jeff Molina
# Aori Qileng has an EV of 21.57 on odds of 100.  They have 60.79 % chance of winning.
#
# Na Liang vs. Ariane Carnelossi
# Na Liang has an EV of 145.71 on odds of 178.  They have 88.39 % chance of winning.
#
# Robert Whittaker vs. Kelvin Gastelum
# Robert Whittaker has an EV of 26.85 on odds of -245.  They have 90.08 % chance of winning.
#
# Andrei Arlovski vs. Chase Sherman
# Andrei Arlovski has an EV of 41.78 on odds of 110.  They have 67.52 % chance of winning.
#
# Abdul Razak Alhassan vs. Jacob Malkoun
# Jacob Malkoun has an EV of 10.21 on odds of 250.  They have 31.49 % chance of winning.
#
# Tracy Cortez vs. Justine Kish
# No bets.  EV1:-3.9213870014379744. EV2: -3.17236392833847
# Tracy Cortez has an EV of -3.92 on odds of -325.  They have 73.47 % chance of winning.
#
# Luis Pena vs. Alexander Munoz
# Luis Pena has an EV of 33.61 on odds of -155.  They have 81.22 % chance of winning.
#
# Alexandr Romanov vs. Juan Espino
# Juan Espino has an EV of 49.48 on odds of 140.  They have 62.28 % chance of winning.
#
# Jessica Penne vs. Loopy Godinez
# Jessica Penne has an EV of 141.58 on odds of 210.  They have 77.93 % chance of winning.
#
# Bartosz Fabinski vs. Gerald Meerschaert
# Bartosz Fabinski has an EV of 34.98 on odds of -125.  They have 74.99 % chance of winning.
#
# Austin Hubbard vs. Dakota Bush
# No bets.  EV1:-1.7204845092240575. EV2: -8.643747976810445
# Austin Hubbard has an EV of -1.72 on odds of -230.  They have 68.5 % chance of winning.
#
# Tony Gravely vs. Anthony Birchak
# Anthony Birchak has an EV of 12.07 on odds of 320.  They have 26.68 % chance of winning.
#
# Marvin Vettori vs. Kevin Holland
# Marvin Vettori has an EV of 13.05 on odds of -290.  They have 84.07 % chance of winning.
#
# Arnold Allen vs. Sodiq Yusuff
# Sodiq Yusuff has an EV of 21.07 on odds of -155.  They have 73.59 % chance of winning.
#
# Sam Alvey vs. Julian Marquez
# Sam Alvey has an EV of 71.08 on odds of 125.  They have 76.04 % chance of winning.
#
# Nina Nunes vs. Mackenzie Dern
# Nina Nunes has an EV of 42.24 on odds of -120.  They have 77.59 % chance of winning.
#
# Mike Perry vs. Daniel Rodriguez
# Daniel Rodriguez has an EV of 19.09 on odds of -120.  They have 64.96 % chance of winning.
#
# Jim Miller vs. Joe Solecki
# Jim Miller has an EV of 28.49 on odds of 205.  They have 42.13 % chance of winning.
#
# Scott Holtzman vs. Mateusz Gamrot
# Scott Holtzman has an EV of 30.69 on odds of 185.  They have 45.86 % chance of winning.
#
# John Makdessi vs. Ignacio Bahamondes
# John Makdessi has an EV of 115.37 on odds of 170.  They have 79.77 % chance of winning.
#
# Yorgan De Castro vs. Jarjis Danho
# Jarjis Danho has an EV of 255.0 on odds of 255.  They have 100.0 % chance of winning.
#
# Hunter Azure vs. Jack Shore
# Jack Shore has an EV of 4.87 on odds of -185.  They have 68.07 % chance of winning.
#
# Luis Saldana vs. Jordan Griffin
# Luis Saldana has an EV of 4.76 on odds of -145.  They have 62.0 % chance of winning.
#
# Da-Un Jung vs. William Knight
# Da-Un Jung has an EV of 31.39 on odds of -147.  They have 78.2 % chance of winning.
#
# Impa Kasanganay vs. Sasha Palatnikov
# No bets.  EV1:-0.11327569847130192. EV2: -11.177746667671059
# Impa Kasanganay has an EV of -0.11 on odds of -250.  They have 71.35 % chance of winning.
#
# Stipe Miocic vs. Francis Ngannou
# No bets.  EV1:-7.8858118400281185. EV2: -0.4408577278522472
# Stipe Miocic has an EV of -7.89 on odds of 117.  They have 42.45 % chance of winning.
#
# Tyron Woodley vs. Vicente Luque
# Vicente Luque has an EV of 30.54 on odds of -200.  They have 87.02 % chance of winning.
#
# Sean O'Malley vs. Thomas Almeida
# Sean O'Malley has an EV of 12.61 on odds of -370.  They have 88.65 % chance of winning.
#
# Gillian Robertson vs. Miranda Maverick
# Gillian Robertson has an EV of 33.05 on odds of 125.  They have 59.13 % chance of winning.
#
# Jamie Mullarkey vs. Khama Worthy
# Khama Worthy has an EV of 1.79 on odds of -135.  They have 58.48 % chance of winning.
#
# Alonzo Menifield vs. Fabio Cherant
# Alonzo Menifield has an EV of 19.63 on odds of -275.  They have 87.73 % chance of winning.
#
# Jared Gooden vs. Abubakar Nurmagomedov
# Jared Gooden has an EV of 39.69 on odds of 175.  They have 50.8 % chance of winning.
#
# Modestas Bukauskas vs. Michal Oleksiejczuk
# Modestas Bukauskas has an EV of 53.78 on odds of 157.  They have 59.84 % chance of winning.
#
# Shane Young vs. Omar Morales
# Omar Morales has an EV of 1.48 on odds of -200.  They have 67.65 % chance of winning.
#
# Marc-Andre Barriault vs. Abu Azaitar
# Marc-Andre Barriault has an EV of 14.68 on odds of -127.  They have 64.16 % chance of winning.
#
# Derek Brunson vs. Kevin Holland
# No bets.  EV1:-7.393650181019304. EV2: -2.0917202491496774
# Derek Brunson has an EV of -7.39 on odds of 175.  They have 33.68 % chance of winning.
#
# Song Kenan vs. Max Griffin
# No bets.  EV1:-1.0826405127409586. EV2: -4.3416767652540145
# Song Kenan has an EV of -1.08 on odds of 165.  They have 37.33 % chance of winning.
#
# Cheyanne Buys vs. Montserrat Conejo
# Cheyanne Buys has an EV of 9.35 on odds of -260.  They have 78.98 % chance of winning.
#
# Adrian Yanez vs. Gustavo Lopez
# Adrian Yanez has an EV of 0.04 on odds of -215.  They have 68.28 % chance of winning.
#
# Tai Tuivasa vs. Harry Hunsucker
# No bets.  EV1:-0.6498992806435524. EV2: -13.691354200920998
# Tai Tuivasa has an EV of -0.65 on odds of -430.  They have 80.6 % chance of winning.
#
# Marion Reneau vs. Macy Chiasson
# Marion Reneau has an EV of 84.52 on odds of 185.  They have 64.74 % chance of winning.
#
# Leonardo Santos vs. Grant Dawson
# No bets.  EV1:-4.173573584325602. EV2: -2.72459777228152
# Leonardo Santos has an EV of -4.17 on odds of 160.  They have 36.86 % chance of winning.
#
# Trevin Giles vs. Roman Dolidze
# Trevin Giles has an EV of 1.83 on odds of -115.  They have 54.46 % chance of winning.
#
# Montel Jackson vs. Jesse Strader
# Montel Jackson has an EV of 13.77 on odds of -600.  They have 97.52 % chance of winning.
#
# Bruno Silva vs. JP Buys
# Bruno Silva has an EV of 62.51 on odds of 115.  They have 75.59 % chance of winning.
#
# Misha Cirkunov vs. Ryan Spann
# Misha Cirkunov has an EV of 29.25 on odds of -125.  They have 71.8 % chance of winning.
#
# Dan Ige vs. Gavin Tucker
# Gavin Tucker has an EV of 25.56 on odds of 165.  They have 47.38 % chance of winning.
#
# Jonathan Martinez vs. Davey Grant
# Davey Grant has an EV of 74.15 on odds of 250.  They have 49.76 % chance of winning.
#
# Manel Kape vs. Matheus Nicolau
# Manel Kape has an EV of 28.84 on odds of -130.  They have 72.82 % chance of winning.
#
# Angela Hill vs. Ashley Yoder
# Angela Hill has an EV of 9.42 on odds of -330.  They have 83.97 % chance of winning.
#
# Charles Jourdain vs. Marcelo Rojo
# Marcelo Rojo has an EV of 30.51 on odds of 250.  They have 37.29 % chance of winning.
#
# Rani Yahya vs. Ray Rodriguez
# Rani Yahya has an EV of 23.49 on odds of -270.  They have 90.12 % chance of winning.
#
# Nasrat Haqparast vs. Rafa Garcia
# Nasrat Haqparast has an EV of 10.42 on odds of -525.  They have 92.75 % chance of winning.
#
# Cortney Casey vs. JJ Aldrich
# Cortney Casey has an EV of 15.9 on odds of 122.  They have 52.21 % chance of winning.
#
# Gloria de Paula vs. Jinh Yu Frey
# Jinh Yu Frey has an EV of 15.75 on odds of 170.  They have 42.87 % chance of winning.
#
# Matthew Semelsberger vs. Jason Witt
# Matthew Semelsberger has an EV of 24.64 on odds of -130.  They have 70.45 % chance of winning.
#
# Jan Blachowicz vs. Israel Adesanya
# Israel Adesanya has an EV of 36.39 on odds of -245.  They have 96.86 % chance of winning.
#
# Amanda Nunes vs. Megan Anderson
# Amanda Nunes has an EV of 14.12 on odds of -700.  They have 99.86 % chance of winning.
#
# Petr Yan vs. Aljamain Sterling
# Aljamain Sterling has an EV of 9.06 on odds of 102.  They have 53.99 % chance of winning.
#
# Islam Makhachev vs. Drew Dober
# Islam Makhachev has an EV of 8.17 on odds of -460.  They have 88.86 % chance of winning.
#
# Thiago Santos vs. Aleksandar Rakic
# Thiago Santos has an EV of 29.05 on odds of 160.  They have 49.63 % chance of winning.
#
# Dominick Cruz vs. Casey Kenney
# Dominick Cruz has an EV of 110.02 on odds of 120.  They have 95.46 % chance of winning.
#
# Song Yadong vs. Kyler Phillips
# Kyler Phillips has an EV of 27.03 on odds of 180.  They have 45.37 % chance of winning.
#
# Joseph Benavidez vs. Askar Askarov
# Askar Askarov has an EV of 68.97 on odds of -145.  They have 100.0 % chance of winning.
#
# Rogerio Bontorin vs. Kai Kara-France
# Rogerio Bontorin has an EV of 17.46 on odds of 117.  They have 54.13 % chance of winning.
#
# Tim Elliott vs. Jordan Espinosa
# Tim Elliott has an EV of 26.85 on odds of -155.  They have 77.11 % chance of winning.
#
# Kennedy Nzechukwu vs. Carlos Ulberg
# Kennedy Nzechukwu has an EV of 55.81 on odds of 190.  They have 53.73 % chance of winning.
#
# Sean Brady vs. Jake Matthews
# Jake Matthews has an EV of 8.6 on odds of 180.  They have 38.78 % chance of winning.
#
# Livinha Souza vs. Amanda Lemos
# No bets.  EV1:-2.271105583911492. EV2: -4.483089029819226
# Livinha Souza has an EV of -2.27 on odds of 200.  They have 32.58 % chance of winning.
#
# Uros Medic vs. Aalon Cruz
# Uros Medic has an EV of 10.45 on odds of -200.  They have 73.64 % chance of winning.
#
# Mario Bautista vs. Trevin Jones
# No bets.  EV1:-4.57290607376768. EV2: -2.0809047849631526
# Mario Bautista has an EV of -4.57 on odds of -240.  They have 67.36 % chance of winning.
#
# Jairzinho Rozenstruik vs. Ciryl Gane
# Ciryl Gane has an EV of 7.66 on odds of -225.  They have 74.54 % chance of winning.
#
# Nikita Krylov vs. Magomed Ankalaev
# No bets.  EV1:-5.688985341837835. EV2: -2.594672250728614
# Nikita Krylov has an EV of -5.69 on odds of 250.  They have 26.95 % chance of winning.
#
# Pedro Munhoz vs. Jimmie Rivera
# Pedro Munhoz has an EV of 31.32 on odds of 115.  They have 61.08 % chance of winning.
#
# Alex Caceres vs. Kevin Croom
# Kevin Croom has an EV of 94.53 on odds of 130.  They have 84.58 % chance of winning.
#
# Alexander Hernandez vs. Thiago Moises
# Alexander Hernandez has an EV of 6.25 on odds of -220.  They have 73.05 % chance of winning.
#
# Alexis Davis vs. Sabina Mazo
# Sabina Mazo has an EV of 10.55 on odds of -215.  They have 75.45 % chance of winning.
#
# Vince Cachero vs. Ronnie Lawrence
# Ronnie Lawrence has an EV of 44.65 on odds of -185.  They have 93.89 % chance of winning.
#
# Dustin Jacoby vs. Maxim Grishin
# Maxim Grishin has an EV of 13.26 on odds of 137.  They have 47.79 % chance of winning.
#
# Curtis Blaydes vs. Derrick Lewis
# Derrick Lewis has an EV of 29.77 on odds of 300.  They have 32.44 % chance of winning.
#
# Ketlen Vieira vs. Yana Kunitskaya
# Ketlen Vieira has an EV of 0.26 on odds of -278.  They have 73.74 % chance of winning.
#
# Charles Rosa vs. Darrick Minner
# Charles Rosa has an EV of 39.76 on odds of -190.  They have 91.57 % chance of winning.
#
# Aleksei Oleinik vs. Chris Daukaus
# Aleksei Oleinik has an EV of 93.43 on odds of 140.  They have 80.59 % chance of winning.
#
# Phil Hawes vs. Nassourdine Imavov
# Phil Hawes has an EV of 52.88 on odds of -125.  They have 84.93 % chance of winning.
#
# Andrei Arlovski vs. Tom Aspinall
# Andrei Arlovski has an EV of 61.23 on odds of 200.  They have 53.74 % chance of winning.
#
# Jared Gordon vs. Danny Chavez
# Jared Gordon has an EV of 1.36 on odds of 110.  They have 48.27 % chance of winning.
#
# Eddie Wineland vs. John Castaneda
# Eddie Wineland has an EV of 24.78 on odds of 100.  They have 62.39 % chance of winning.
#
# Nate Landwehr vs. Julian Erosa
# Nate Landwehr has an EV of 6.05 on odds of -112.  They have 56.02 % chance of winning.
#
# Shana Dobson vs. Casey O'Neill
# Casey O'Neill has an EV of 4.09 on odds of -155.  They have 63.27 % chance of winning.
#
# Aiemann Zahabi vs. Drako Rodriguez
# Aiemann Zahabi has an EV of 92.58 on odds of 150.  They have 77.03 % chance of winning.
#
# Serghei Spivac vs. Jared Vanderaa
# No bets.  EV1:-3.502064667422733. EV2: -8.334935165074505
# Serghei Spivac has an EV of -3.5 on odds of -250.  They have 68.93 % chance of winning.
#
# Kamaru Usman vs. Gilbert Burns
# Kamaru Usman has an EV of 28.18 on odds of -278.  They have 94.27 % chance of winning.
#
# Maycee Barber vs. Alexa Grasso
# Maycee Barber has an EV of 16.75 on odds of -107.  They have 60.35 % chance of winning.
#
# Kelvin Gastelum vs. Ian Heinisch
# Ian Heinisch has an EV of 141.34 on odds of 174.  They have 88.08 % chance of winning.
#
# Ricky Simon vs. Brian Kelleher
# Brian Kelleher has an EV of 50.72 on odds of 210.  They have 48.62 % chance of winning.
#
# Maki Pitolo vs. Julian Marquez
# Maki Pitolo has an EV of 106.84 on odds of 145.  They have 84.42 % chance of winning.
#
# Rodolfo Vieira vs. Anthony Hernandez
# Rodolfo Vieira has an EV of 8.51 on odds of -487.  They have 90.02 % chance of winning.
#
# Belal Muhammad vs. Dhiego Lima
# Dhiego Lima has an EV of 13.29 on odds of 340.  They have 25.75 % chance of winning.
#
# Polyana Viana vs. Mallory Martin
# Polyana Viana has an EV of 22.97 on odds of 100.  They have 61.48 % chance of winning.
#
# Andre Ewell vs. Chris Gutierrez
# Chris Gutierrez has an EV of 77.52 on odds of -129.  They have 100.0 % chance of winning.
#
# Gabe Green vs. Philip Rowe
# Gabe Green has an EV of 30.48 on odds of -138.  They have 75.65 % chance of winning.
#
# Alistair Overeem vs. Alexander Volkov
# Alistair Overeem has an EV of 139.15 on odds of 150.  They have 95.66 % chance of winning.
#
# Cory Sandhagen vs. Frankie Edgar
# Frankie Edgar has an EV of 300.0 on odds of 300.  They have 100.0 % chance of winning.
#
# Alexandre Pantoja vs. Manel Kape
# Alexandre Pantoja has an EV of 31.21 on odds of -125.  They have 72.89 % chance of winning.
#
# Diego Ferreira vs. Beneil Dariush
# Beneil Dariush has an EV of 105.0 on odds of 105.  They have 100.0 % chance of winning.
#
# Michael Johnson vs. Clay Guida
# Clay Guida has an EV of 9.76 on odds of 175.  They have 39.91 % chance of winning.
#
# Mike Rodriguez vs. Danilo Marques
# Danilo Marques has an EV of 12.23 on odds of 188.  They have 38.97 % chance of winning.
#
# Molly McCann vs. Lara Procopio
# Molly McCann has an EV of 32.38 on odds of -177.  They have 84.59 % chance of winning.
#
# SeungWoo Choi vs. Youssef Zalal
# SeungWoo Choi has an EV of 63.95 on odds of 175.  They have 59.62 % chance of winning.
#
# Dustin Poirier vs. Conor McGregor
# Dustin Poirier has an EV of 101.53 on odds of 250.  They have 57.58 % chance of winning.
#
# Dan Hooker vs. Michael Chandler
# Dan Hooker has an EV of 21.12 on odds of -134.  They have 69.36 % chance of winning.
#
# Jessica Eye vs. Joanne Calderwood
# Joanne Calderwood has an EV of 31.8 on odds of -117.  They have 71.06 % chance of winning.
#
# Andrew Sanchez vs. Makhmud Muradov
# No bets.  EV1:-5.144649573950829. EV2: -5.040982772905998
# Andrew Sanchez has an EV of -5.14 on odds of 115.  They have 44.12 % chance of winning.
#
# Marina Rodriguez vs. Amanda Ribas
# Marina Rodriguez has an EV of 71.13 on odds of 250.  They have 48.9 % chance of winning.
#
# Brad Tavares vs. Antonio Carlos Junior
# Antonio Carlos Junior has an EV of 28.69 on odds of 105.  They have 62.77 % chance of winning.
#
# Julianna Pena vs. Sara McMann
# Sara McMann has an EV of 11.34 on odds of -130.  They have 62.93 % chance of winning.
#
# Khalil Rountree Jr. vs. Marcin Prachnio
# Khalil Rountree Jr. has an EV of 1.41 on odds of -335.  They have 78.1 % chance of winning.
#
# Nik Lentz vs. Movsar Evloev
# Nik Lentz has an EV of 45.11 on odds of 390.  They have 29.61 % chance of winning.
#
# Amir Albazi vs. Zhalgas Zhumagulov
# Amir Albazi has an EV of 74.33 on odds of -106.  They have 89.7 % chance of winning.
#
# Michael Chiesa vs. Neil Magny
# Michael Chiesa has an EV of 31.36 on odds of 120.  They have 59.71 % chance of winning.
#
# Warlley Alves vs. Mounir Lazzez
# Warlley Alves has an EV of 22.11 on odds of 185.  They have 42.85 % chance of winning.
#
# Ike Villanueva vs. Vinicius Moreira
# Ike Villanueva has an EV of 17.59 on odds of -134.  They have 67.34 % chance of winning.
#
# Roxanne Modafferi vs. Viviane Araujo
# Roxanne Modafferi has an EV of 80.33 on odds of 260.  They have 50.09 % chance of winning.
#
# Matt Schnell vs. Tyson Nam
# Matt Schnell has an EV of 6.27 on odds of 105.  They have 51.84 % chance of winning.
#
# Lerone Murphy vs. Douglas Silva de Andrade
# Lerone Murphy has an EV of 15.92 on odds of -305.  They have 87.3 % chance of winning.
#
# Omari Akhmedov vs. Tom Breese
# Omari Akhmedov has an EV of 8.16 on odds of 128.  They have 47.44 % chance of winning.
#
# Ricky Simon vs. Gaetano Pirrello
# No bets.  EV1:-4.00792783494656. EV2: -7.17463092817006
# Ricky Simon has an EV of -4.01 on odds of -400.  They have 76.79 % chance of winning.
#
# Su Mudaerji vs. Zarrukh Adashev
# Su Mudaerji has an EV of 20.32 on odds of -400.  They have 96.25 % chance of winning.
#
# Dalcha Lungiambula vs. Markus Perez
# Dalcha Lungiambula has an EV of 30.79 on odds of -143.  They have 76.97 % chance of winning.
#
# Francisco Figueiredo vs. Jerome Rivera
# Francisco Figueiredo has an EV of 19.64 on odds of -155.  They have 72.72 % chance of winning.
#
# Mike Davis vs. Mason Jones
# Mike Davis has an EV of 16.46 on odds of -175.  They have 74.11 % chance of winning.
#
# Umar Nurmagomedov vs. Sergey Morozov
# Umar Nurmagomedov has an EV of 2.0 on odds of -530.  They have 85.81 % chance of winning.
#
# Victoria Leonardo vs. Manon Fiorot
# Victoria Leonardo has an EV of 43.91 on odds of 170.  They have 53.3 % chance of winning.
#
# Max Holloway vs. Calvin Kattar
# Max Holloway has an EV of 61.18 on odds of -162.  They have 99.66 % chance of winning.
#
# Carlos Condit vs. Matt Brown
# Matt Brown has an EV of 4.43 on odds of 145.  They have 42.62 % chance of winning.
#
# Santiago Ponzinibbio vs. Li Jingliang
# Santiago Ponzinibbio has an EV of 12.69 on odds of -305.  They have 84.86 % chance of winning.
#
# Joaquin Buckley vs. Alessio Di Chirico
# Alessio Di Chirico has an EV of 19.97 on odds of 215.  They have 38.08 % chance of winning.
#
# Punahele Soriano vs. Dusko Todorovic
# Punahele Soriano has an EV of 5.63 on odds of 130.  They have 45.93 % chance of winning.
#
# Wu Yanan vs. Joselyne Edwards
# Wu Yanan has an EV of 21.71 on odds of -110.  They have 63.75 % chance of winning.
#
# Carlos Felipe vs. Justin Tafa
# No bets.  EV1:-4.684204165970932. EV2: -4.243114074438111
# Carlos Felipe has an EV of -4.68 on odds of -190.  They have 62.45 % chance of winning.
#
# David Zawada vs. Ramazan Emeev
# David Zawada has an EV of 109.44 on odds of 210.  They have 67.56 % chance of winning.
#
# Sarah Moras vs. Vanessa Melo
# Sarah Moras has an EV of 13.63 on odds of -230.  They have 79.2 % chance of winning.
#
# Jacob Kilburn vs. Austin Lingo
# Jacob Kilburn has an EV of 16.46 on odds of 180.  They have 41.59 % chance of winning.
#
# Stephen Thompson vs. Geoff Neal
# Stephen Thompson has an EV of 42.97 on odds of -103.  They have 72.54 % chance of winning.
#
# Jose Aldo vs. Marlon Vera
# Jose Aldo has an EV of 71.18 on odds of -140.  They have 99.86 % chance of winning.
#
# Michel Pereira vs. Khaos Williams
# Michel Pereira has an EV of 11.74 on odds of 105.  They have 54.51 % chance of winning.
#
# Marlon Moraes vs. Rob Font
# Marlon Moraes has an EV of 25.07 on odds of -170.  They have 78.75 % chance of winning.
#
# Marcin Tybura vs. Greg Hardy
# Marcin Tybura has an EV of 26.95 on odds of -110.  They have 66.5 % chance of winning.
#
# Anthony Pettis vs. Alex Morono
# Anthony Pettis has an EV of 8.68 on odds of -210.  They have 73.62 % chance of winning.
#
# Sijara Eubanks vs. Pannie Kianzad
# Pannie Kianzad has an EV of 0.92 on odds of 120.  They have 45.87 % chance of winning.
#
# Deron Winn vs. Antonio Arroyo
# Deron Winn has an EV of 100.99 on odds of 160.  They have 77.3 % chance of winning.
#
# Gillian Robertson vs. Taila Santos
# Gillian Robertson has an EV of 31.31 on odds of -145.  They have 77.72 % chance of winning.
#
# Tafon Nchukwi vs. Jamie Pickett
# Jamie Pickett has an EV of 48.73 on odds of 275.  They have 39.66 % chance of winning.
#
# Jimmy Flick vs. Cody Durden
# Cody Durden has an EV of 136.97 on odds of 137.  They have 99.99 % chance of winning.
#
# Christos Giagos vs. Carlton Minus
# Christos Giagos has an EV of 8.58 on odds of -345.  They have 84.18 % chance of winning.
#
# Tony Ferguson vs. Charles Oliveira
# Tony Ferguson has an EV of 34.96 on odds of -185.  They have 87.6 % chance of winning.
#
# Mackenzie Dern vs. Virna Jandiroba
# Virna Jandiroba has an EV of 11.42 on odds of 140.  They have 46.43 % chance of winning.
#
# Kevin Holland vs. Jacare Souza
# Kevin Holland has an EV of 49.11 on odds of -135.  They have 85.66 % chance of winning.
#
# Junior Dos Santos vs. Ciryl Gane
# Junior Dos Santos has an EV of 173.45 on odds of 325.  They have 64.34 % chance of winning.
#
# Cub Swanson vs. Daniel Pineda
# Cub Swanson has an EV of 68.77 on odds of 132.  They have 72.74 % chance of winning.
#
# Renato Moicano vs. Rafael Fiziev
# Rafael Fiziev has an EV of 7.51 on odds of -140.  They have 62.71 % chance of winning.
#
# Gavin Tucker vs. Billy Quarantillo
# Gavin Tucker has an EV of 58.66 on odds of 165.  They have 59.87 % chance of winning.
#
# Tecia Torres vs. Sam Hughes
# Tecia Torres has an EV of 11.86 on odds of -550.  They have 94.65 % chance of winning.
#
# Chase Hooper vs. Peter Barrett
# No bets.  EV1:-1.6972679443791563. EV2: -8.858918602952699
# Chase Hooper has an EV of -1.7 on odds of -310.  They have 74.33 % chance of winning.
#
# Jack Hermansson vs. Marvin Vettori
# Marvin Vettori has an EV of 74.63 on odds of -134.  They have 100.0 % chance of winning.
#
# Ovince Saint Preux vs. Jamahal Hill
# Ovince Saint Preux has an EV of 51.02 on odds of 140.  They have 62.93 % chance of winning.
#
# Gabriel Benitez vs. Justin Jaynes
# Gabriel Benitez has an EV of 9.47 on odds of -215.  They have 74.72 % chance of winning.
#
# Roman Dolidze vs. John Allan
# Roman Dolidze has an EV of 10.55 on odds of -200.  They have 73.7 % chance of winning.
#
# Louis Smolka vs. Jose Quinonez
# Louis Smolka has an EV of 12.41 on odds of -139.  They have 65.37 % chance of winning.
#
# Matt Wiman vs. Jordan Leavitt
# Matt Wiman has an EV of 239.58 on odds of 310.  They have 82.83 % chance of winning.
#
# Ilia Topuria vs. Damon Jackson
# Damon Jackson has an EV of 210.0 on odds of 210.  They have 100.0 % chance of winning.
#
# Gian Villante vs. Jake Collier
# Jake Collier has an EV of 124.23 on odds of 160.  They have 86.24 % chance of winning.
#
# Anthony Smith vs. Devin Clark
# Anthony Smith has an EV of 10.27 on odds of -139.  They have 64.13 % chance of winning.
#
# Miguel Baeza vs. Takashi Sato
# Miguel Baeza has an EV of 20.37 on odds of -175.  They have 76.6 % chance of winning.
#
# Josh Parisian vs. Parker Porter
# Josh Parisian has an EV of 27.58 on odds of -200.  They have 85.05 % chance of winning.
#
# Spike Carlyle vs. Bill Algeo
# No bets.  EV1:-0.058324818573453285. EV2: -13.267955296281293
# Spike Carlyle has an EV of -0.06 on odds of -177.  They have 63.86 % chance of winning.
#
# Ashlee Evans-Smith vs. Norma Dumont
# Norma Dumont has an EV of 1.58 on odds of 110.  They have 48.37 % chance of winning.
#
# Jonathan Pearce vs. Kai Kamaka
# Jonathan Pearce has an EV of 118.73 on odds of 245.  They have 63.4 % chance of winning.
#
# Martin Day vs. Anderson Dos Santos
# Martin Day has an EV of 26.8 on odds of -167.  They have 79.31 % chance of winning.
#
# Gina Mazany vs. Rachael Ostovich
# Gina Mazany has an EV of 36.0 on odds of -200.  They have 90.67 % chance of winning.
#
# Su Mudaerji vs. Malcolm Gordon
# Su Mudaerji has an EV of 2.75 on odds of -335.  They have 79.13 % chance of winning.
#
# Luke Sanders vs. Nate Maness
# Luke Sanders has an EV of 24.07 on odds of -155.  They have 75.41 % chance of winning.
#
# Deiveson Figueiredo vs. Alex Perez
# Deiveson Figueiredo has an EV of 2.79 on odds of -286.  They have 76.16 % chance of winning.
#
# Valentina Shevchenko vs. Jennifer Maia
# Valentina Shevchenko has an EV of 6.0 on odds of -1667.  They have 100.0 % chance of winning.
#
# Mike Perry vs. Tim Means
# Tim Means has an EV of 8.73 on odds of 120.  They have 49.42 % chance of winning.
#
# Katlyn Chookagian vs. Cynthia Calvillo
# Cynthia Calvillo has an EV of 37.74 on odds of -265.  They have 100.0 % chance of winning.
#
# Mauricio Rua vs. Paul Craig
# Paul Craig has an EV of 52.63 on odds of -190.  They have 100.0 % chance of winning.
#
# Brandon Moreno vs. Brandon Royval
# Brandon Moreno has an EV of 33.47 on odds of -190.  They have 87.44 % chance of winning.
#
# Joaquin Buckley vs. Jordan Wright
# Jordan Wright has an EV of 0.41 on odds of 205.  They have 32.92 % chance of winning.
#
# Antonina Shevchenko vs. Ariane Lipski
# Antonina Shevchenko has an EV of 15.89 on odds of -167.  They have 72.49 % chance of winning.
#
# Daniel Rodriguez vs. Nicolas Dalby
# Nicolas Dalby has an EV of 250.0 on odds of 250.  They have 100.0 % chance of winning.
#
# Alan Jouban vs. Jared Gooden
# Alan Jouban has an EV of 31.86 on odds of -150.  They have 79.12 % chance of winning.
#
# Kyle Daukaus vs. Dustin Stoltzfus
# Kyle Daukaus has an EV of 16.65 on odds of -315.  They have 88.54 % chance of winning.
#
# Louis Cosce vs. Sasha Palatnikov
# No bets.  EV1:-4.018227408984842. EV2: -9.422977924099683
# Louis Cosce has an EV of -4.02 on odds of -455.  They have 78.69 % chance of winning.
#
# Paul Felder vs. Rafael Dos Anjos
# Rafael Dos Anjos has an EV of 14.36 on odds of -200.  They have 76.24 % chance of winning.
#
# Abdul Razak Alhassan vs. Khaos Williams
# Abdul Razak Alhassan has an EV of 10.38 on odds of -240.  They have 77.91 % chance of winning.
#
# Kay Hansen vs. Cory McKenna
# Kay Hansen has an EV of 25.19 on odds of -230.  They have 87.26 % chance of winning.
#
# Brendan Allen vs. Sean Strickland
# Brendan Allen has an EV of 19.73 on odds of -118.  They have 64.81 % chance of winning.
#
# Ashley Yoder vs. Miranda Granger
# Ashley Yoder has an EV of 21.53 on odds of 135.  They have 51.71 % chance of winning.
#
# Alex Morono vs. Rhys McKee
# Alex Morono has an EV of 23.33 on odds of -177.  They have 78.81 % chance of winning.
#
# Randa Markos vs. Kanako Murata
# Randa Markos has an EV of 13.05 on odds of 155.  They have 44.33 % chance of winning.
#
# Geraldo de Freitas vs. Tony Gravely
# Geraldo de Freitas has an EV of 28.12 on odds of 117.  They have 59.04 % chance of winning.
#
# Don'Tale Mayes vs. Roque Martinez
# Don'Tale Mayes has an EV of 35.4 on odds of -265.  They have 98.3 % chance of winning.
#
# Thiago Santos vs. Glover Teixeira
# Glover Teixeira has an EV of 35.4 on odds of 190.  They have 46.69 % chance of winning.
#
# Andrei Arlovski vs. Tanner Boser
# Andrei Arlovski has an EV of 126.49 on odds of 235.  They have 67.61 % chance of winning.
#
# Raoni Barcelos vs. Khalid Taha
# Raoni Barcelos has an EV of 13.14 on odds of -400.  They have 90.51 % chance of winning.
#
# Claudia Gadelha vs. Yan Xiaonan
# Yan Xiaonan has an EV of 39.93 on odds of -155.  They have 85.06 % chance of winning.
#
# Trevin Giles vs. Bevon Lewis
# No bets.  EV1:-6.276444614147145. EV2: -4.351199847267196
# Trevin Giles has an EV of -6.28 on odds of 100.  They have 46.86 % chance of winning.
#
# Giga Chikadze vs. Jamey Simmons
# Giga Chikadze has an EV of 11.78 on odds of -835.  They have 99.83 % chance of winning.
#
# Alexandr Romanov vs. Marcos Rogerio de Lima
# Alexandr Romanov has an EV of 11.99 on odds of -455.  They have 91.81 % chance of winning.
#
# Darren Elkins vs. Eduardo Garagorri
# Darren Elkins has an EV of 15.55 on odds of -240.  They have 81.57 % chance of winning.
#
# Max Griffin vs. Ramiz Brahimaj
# Max Griffin has an EV of 33.72 on odds of -143.  They have 78.69 % chance of winning.
#
# Gustavo Lopez vs. Anthony Birchak
# No bets.  EV1:-1.4091077840052364. EV2: -9.432707172828778
# Gustavo Lopez has an EV of -1.41 on odds of -134.  They have 56.46 % chance of winning.
#
# Uriah Hall vs. Anderson Silva
# Uriah Hall has an EV of 43.19 on odds of -230.  They have 99.8 % chance of winning.
#
# Bryce Mitchell vs. Andre Fili
# Bryce Mitchell has an EV of 34.09 on odds of -150.  They have 80.45 % chance of winning.
#
# Maurice Greene vs. Greg Hardy
# Maurice Greene has an EV of 45.62 on odds of 250.  They have 41.61 % chance of winning.
#
# Kevin Holland vs. Charlie Ontiveros
# Kevin Holland has an EV of 5.4 on odds of -770.  They have 93.29 % chance of winning.
#
# Bobby Green vs. Thiago Moises
# Bobby Green has an EV of 22.55 on odds of -335.  They have 94.38 % chance of winning.
#
# Chris Gruetzemacher vs. Alexander Hernandez
# Chris Gruetzemacher has an EV of 68.74 on odds of 315.  They have 40.66 % chance of winning.
#
# Adrian Yanez vs. Victor Rodriguez
# Adrian Yanez has an EV of 11.69 on odds of -500.  They have 93.07 % chance of winning.
#
# Sean Strickland vs. Jack Marshman
# Jack Marshman has an EV of 28.95 on odds of 277.  They have 34.2 % chance of winning.
#
# Cole Williams vs. Jason Witt
# Cole Williams has an EV of 28.97 on odds of 119.  They have 58.89 % chance of winning.
#
# Dustin Jacoby vs. Justin Ledet
# Dustin Jacoby has an EV of 0.12 on odds of -400.  They have 80.1 % chance of winning.
#
# Miles Johns vs. Kevin Natividad
# Miles Johns has an EV of 7.1 on odds of -165.  They have 66.69 % chance of winning.
#
# Khabib Nurmagomedov vs. Justin Gaethje
# Khabib Nurmagomedov has an EV of 29.9 on odds of -315.  They have 98.6 % chance of winning.
#
# Robert Whittaker vs. Jared Cannonier
# Robert Whittaker has an EV of 52.7 on odds of -110.  They have 79.98 % chance of winning.
#
# Alexander Volkov vs. Walt Harris
# No bets.  EV1:-5.280058562325344. EV2: -5.144731665156527
# Alexander Volkov has an EV of -5.28 on odds of -190.  They have 62.06 % chance of winning.
#
# Jacob Malkoun vs. Phillip Hawes
# No bets.  EV1:-5.748858014535358. EV2: -4.729355518525409
# Jacob Malkoun has an EV of -5.75 on odds of 195.  They have 31.95 % chance of winning.
#
# Lauren Murphy vs. Liliya Shakirova
# No bets.  EV1:-4.099958827660398. EV2: -6.730075874740564
# Lauren Murphy has an EV of -4.1 on odds of -215.  They have 65.46 % chance of winning.
#
# Magomed Ankalaev vs. Ion Cutelaba
# No bets.  EV1:-2.6428851142258694. EV2: -12.41659127257627
# Magomed Ankalaev has an EV of -2.64 on odds of -335.  They have 74.98 % chance of winning.
#
# Stefan Struve vs. Tai Tuivasa
# Stefan Struve has an EV of 88.11 on odds of -112.  They have 99.38 % chance of winning.
#
# Nathaniel Wood vs. Casey Kenney
# Nathaniel Wood has an EV of 3.89 on odds of 140.  They have 43.29 % chance of winning.
#
# Alex Oliveira vs. Shavkat Rakhmonov
# Alex Oliveira has an EV of 42.59 on odds of -112.  They have 75.33 % chance of winning.
#
# Liana Jojua vs. Miranda Maverick
# Liana Jojua has an EV of 228.89 on odds of 295.  They have 83.26 % chance of winning.
#
# Joel Alvarez vs. Alexander Yakovlev
# Alexander Yakovlev has an EV of 29.0 on odds of 138.  They have 54.2 % chance of winning.
#
# Brian Ortega vs. Chan Sung Jung
# Brian Ortega has an EV of 35.49 on odds of 160.  They have 52.11 % chance of winning.
#
# Katlyn Chookagian vs. Jessica Andrade
# Katlyn Chookagian has an EV of 102.98 on odds of 130.  They have 88.25 % chance of winning.
#
# Jimmy Crute vs. Modestas Bukauskas
# Jimmy Crute has an EV of 19.52 on odds of -335.  They have 92.04 % chance of winning.
#
# Claudio Silva vs. James Krause
# Claudio Silva has an EV of 26.29 on odds of 120.  They have 57.4 % chance of winning.
#
# Thomas Almeida vs. Jonathan Martinez
# Thomas Almeida has an EV of 12.56 on odds of -139.  They have 65.46 % chance of winning.
#
# Mateusz Gamrot vs. Guram Kutateladze
# No bets.  EV1:-4.197254419043478. EV2: -9.537984379747911
# Mateusz Gamrot has an EV of -4.2 on odds of -335.  They have 73.78 % chance of winning.
#
# Gillian Robertson vs. Poliana Botelho
# Gillian Robertson has an EV of 5.33 on odds of -215.  They have 71.89 % chance of winning.
#
# Junyong Park vs. John Phillips
# John Phillips has an EV of 9.74 on odds of 215.  They have 34.84 % chance of winning.
#
# Jamie Mullarkey vs. Fares Ziam
# Jamie Mullarkey has an EV of 22.44 on odds of -137.  They have 70.78 % chance of winning.
#
# Gadzhimurad Antigulov vs. Maxim Grishin
# Gadzhimurad Antigulov has an EV of 226.9 on odds of 277.  They have 86.71 % chance of winning.
#
# Said Nurmagomedov vs. Mark Striegl
# Mark Striegl has an EV of 1.84 on odds of 317.  They have 24.42 % chance of winning.
#
# Marlon Moraes vs. Cory Sandhagen
# Cory Sandhagen has an EV of 18.08 on odds of -141.  They have 69.08 % chance of winning.
#
# Edson Barboza vs. Makwan Amirkhani
# Edson Barboza has an EV of 0.97 on odds of -286.  They have 74.81 % chance of winning.
#
# Ben Rothwell vs. Marcin Tybura
# Marcin Tybura has an EV of 22.38 on odds of 130.  They have 53.21 % chance of winning.
#
# Markus Perez vs. Dricus Du Plessis
# Markus Perez has an EV of 42.54 on odds of 133.  They have 61.18 % chance of winning.
#
# Tom Aspinall vs. Alan Baudot
# Tom Aspinall has an EV of 7.04 on odds of -560.  They have 90.82 % chance of winning.
#
# Youssef Zalal vs. Ilia Topuria
# Youssef Zalal has an EV of 50.43 on odds of -162.  They have 93.02 % chance of winning.
#
# Tom Breese vs. KB Bhullar
# Tom Breese has an EV of 2.14 on odds of -275.  They have 74.91 % chance of winning.
#
# Chris Daukaus vs. Rodrigo Nascimento
# Chris Daukaus has an EV of 130.58 on odds of 205.  They have 75.6 % chance of winning.
#
# Impa Kasanganay vs. Joaquin Buckley
# No bets.  EV1:-0.6814426315606497. EV2: -16.323981117559633
# Impa Kasanganay has an EV of -0.68 on odds of -265.  They have 72.11 % chance of winning.
#
# Ali AlQaisi vs. Tony Kelley
# Ali AlQaisi has an EV of 42.83 on odds of 190.  They have 49.25 % chance of winning.
#
# Giga Chikadze vs. Omar Morales
# Omar Morales has an EV of 27.4 on odds of -175.  They have 81.08 % chance of winning.
#
# Tracy Cortez vs. Stephanie Egger
# No bets.  EV1:-5.52030469234785. EV2: -5.107139668782729
# Tracy Cortez has an EV of -5.52 on odds of -205.  They have 63.5 % chance of winning.
#
# Bruno Silva vs. Tagir Ulanbekov
# Bruno Silva has an EV of 94.83 on odds of 321.  They have 46.28 % chance of winning.
#
# Holly Holm vs. Irene Aldana
# Holly Holm has an EV of 5.0 on odds of -125.  They have 58.33 % chance of winning.
#
# Yorgan De Castro vs. Carlos Felipe
# Yorgan De Castro has an EV of 3.3 on odds of -265.  They have 75.0 % chance of winning.
#
# Germaine de Randamie vs. Julianna Pena
# Germaine de Randamie has an EV of 12.51 on odds of -150.  They have 67.5 % chance of winning.
#
# Kyler Phillips vs. Cameron Else
# No bets.  EV1:-0.11543236626678066. EV2: -23.370859813324557
# Kyler Phillips has an EV of -0.12 on odds of -480.  They have 82.66 % chance of winning.
#
# Dequan Townsend vs. Dusko Todorovic
# Dequan Townsend has an EV of 130.51 on odds of 245.  They have 66.82 % chance of winning.
#
# Carlos Condit vs. Court McGee
# Carlos Condit has an EV of 8.17 on odds of 111.  They have 51.27 % chance of winning.
#
# Jordan Williams vs. Nassourdine Imavov
# Jordan Williams has an EV of 18.17 on odds of -125.  They have 65.65 % chance of winning.
#
# Loma Lookboonmee vs. Jinh Yu Frey
# Jinh Yu Frey has an EV of 15.75 on odds of 120.  They have 52.61 % chance of winning.
#
# Casey Kenney vs. Heili Alateng
# No bets.  EV1:-0.05634345531015228. EV2: -20.309637473447175
# Casey Kenney has an EV of -0.06 on odds of -335.  They have 76.97 % chance of winning.
#
# Luigi Vendramini vs. Jessin Ayari
# Luigi Vendramini has an EV of 39.23 on odds of -109.  They have 72.61 % chance of winning.
#
# Israel Adesanya vs. Paulo Costa
# Israel Adesanya has an EV of 33.82 on odds of -186.  They have 87.03 % chance of winning.
#
# Dominick Reyes vs. Jan Blachowicz
# Jan Blachowicz has an EV of 56.92 on odds of 215.  They have 49.82 % chance of winning.
#
# Kai Kara-France vs. Brandon Royval
# Kai Kara-France has an EV of 37.12 on odds of -240.  They have 96.79 % chance of winning.
#
# Ketlen Vieira vs. Sijara Eubanks
# Sijara Eubanks has an EV of 41.65 on odds of 150.  They have 56.66 % chance of winning.
#
# Hakeem Dawodu vs. Zubaira Tukhugov
# Zubaira Tukhugov has an EV of 69.93 on odds of -143.  They have 100.0 % chance of winning.
#
# Brad Riddell vs. Alex Da Silva
# Alex Da Silva has an EV of 11.45 on odds of 253.  They have 31.57 % chance of winning.
#
# Diego Sanchez vs. Jake Matthews
# Diego Sanchez has an EV of 59.23 on odds of 470.  They have 27.93 % chance of winning.
#
# Shane Young vs. Ludovit Klein
# Shane Young has an EV of 35.3 on odds of 108.  They have 65.05 % chance of winning.
#
# William Knight vs. Aleksa Camur
# William Knight has an EV of 36.13 on odds of 134.  They have 58.18 % chance of winning.
#
# Juan Espino vs. Jeff Hughes
# Juan Espino has an EV of 32.79 on odds of -305.  They have 100.0 % chance of winning.
#
# Khadis Ibragimov vs. Danilo Marques
# Danilo Marques has an EV of 21.31 on odds of 150.  They have 48.52 % chance of winning.
#
# Colby Covington vs. Tyron Woodley
# Tyron Woodley has an EV of 260.0 on odds of 260.  They have 100.0 % chance of winning.
#
# Khamzat Chimaev vs. Gerald Meerschaert
# Khamzat Chimaev has an EV of 4.07 on odds of -400.  They have 83.25 % chance of winning.
#
# Johnny Walker vs. Ryan Spann
# Ryan Spann has an EV of 3.79 on odds of 100.  They have 51.9 % chance of winning.
#
# Mackenzie Dern vs. Randa Markos
# Randa Markos has an EV of 140.0 on odds of 140.  They have 100.0 % chance of winning.
#
# Kevin Holland vs. Darren Stewart
# Kevin Holland has an EV of 15.2 on odds of -265.  They have 83.64 % chance of winning.
#
# Jordan Espinosa vs. David Dvorak
# Jordan Espinosa has an EV of 30.3 on odds of -112.  They have 68.84 % chance of winning.
#
# Mirsad Bektic vs. Damon Jackson
# Damon Jackson has an EV of 277.0 on odds of 277.  They have 100.0 % chance of winning.
#
# Mayra Bueno Silva vs. Mara Romero Borella
# Mara Romero Borella has an EV of 4.63 on odds of 210.  They have 33.75 % chance of winning.
#
# Jessica-Rose Clark vs. Sarah Alpar
# No bets.  EV1:-1.495846466054008. EV2: -12.232348108669918
# Jessica-Rose Clark has an EV of -1.5 on odds of -230.  They have 68.65 % chance of winning.
#
# Darrick Minner vs. TJ Laramie
# Darrick Minner has an EV of 204.25 on odds of 245.  They have 88.19 % chance of winning.
#
# Journey Newson vs. Randy Costa
# Journey Newson has an EV of 41.18 on odds of -137.  They have 81.61 % chance of winning.
#
# Andre Ewell vs. Irwin Rivera
# Andre Ewell has an EV of 12.55 on odds of -240.  They have 79.45 % chance of winning.
#
# Tyson Nam vs. Jerome Rivera
# Tyson Nam has an EV of 17.7 on odds of -190.  They have 77.12 % chance of winning.
#
# Michelle Waterson vs. Angela Hill
# Michelle Waterson has an EV of 4.72 on odds of 105.  They have 51.08 % chance of winning.
#
# Ottman Azaitar vs. Khama Worthy
# Khama Worthy has an EV of 1.2 on odds of -137.  They have 58.5 % chance of winning.
#
# Roxanne Modafferi vs. Andrea Lee
# Roxanne Modafferi has an EV of 57.52 on odds of 240.  They have 46.33 % chance of winning.
#
# Ed Herman vs. Mike Rodriguez
# Ed Herman has an EV of 90.3 on odds of 195.  They have 64.51 % chance of winning.
#
# Billy Quarantillo vs. Kyle Nelson
# Billy Quarantillo has an EV of 9.23 on odds of -250.  They have 78.02 % chance of winning.
#
# Julia Avila vs. Sijara Eubanks
# ...
#
# Brendan Schaub vs. Gabriel Gonzaga
# Brendan Schaub has an EV of 23.26 on odds of 125.  They have 54.78 % chance of winning.
#
# Court McGee vs. Ryan Jensen
# Court McGee has an EV of 9.8 on odds of -250.  They have 78.43 % chance of winning.
#
# Patrick Cote vs. Tom Lawlor
# Tom Lawlor has an EV of 31.18 on odds of 155.  They have 51.44 % chance of winning.
#
# Mike Guymon vs. Daniel Roberts
# Daniel Roberts has an EV of 6.63 on odds of -145.  They have 63.11 % chance of winning.
#
# Sam Stout vs. Paul Taylor
# No bets.  EV1:-4.4734059433233. EV2: -1.9478693020189581
# Sam Stout has an EV of -4.47 on odds of -200.  They have 63.68 % chance of winning.
#
# Jon Madsen vs. Gilbert Yvel
# Jon Madsen has an EV of 15.34 on odds of -225.  They have 79.85 % chance of winning.
#
# Michael Bisping vs. Yoshihiro Akiyama
# Michael Bisping has an EV of 4.2 on odds of -210.  They have 70.58 % chance of winning.
#
# Dan Hardy vs. Carlos Condit
# Carlos Condit has an EV of 67.32 on odds of 160.  They have 64.36 % chance of winning.
#
# John Hathaway vs. Mike Pyle
# John Hathaway has an EV of 15.48 on odds of -475.  They have 95.39 % chance of winning.
#
# James Wilks vs. Claude Patrick
# James Wilks has an EV of 62.59 on odds of 145.  They have 66.37 % chance of winning.
#
# Cyrille Diabate vs. Alexander Gustafsson
# Alexander Gustafsson has an EV of 22.72 on odds of -155.  They have 74.6 % chance of winning.
#
# Paul Sass vs. Mark Holst
# Paul Sass has an EV of 38.38 on odds of -185.  They have 89.83 % chance of winning.
#
# Frank Mir vs. Mirko Cro Cop
# Frank Mir has an EV of 29.57 on odds of -210.  They have 87.77 % chance of winning.
#
# Rogerio Nogueira vs. Ryan Bader
# Ryan Bader has an EV of 39.68 on odds of -170.  They have 87.95 % chance of winning.
#
# Matt Serra vs. Chris Lytle
# Chris Lytle has an EV of 2.64 on odds of -135.  They have 58.96 % chance of winning.
#
# Sean Sherk vs. Evan Dunham
# Evan Dunham has an EV of 55.22 on odds of -178.  They have 99.39 % chance of winning.
#
# Melvin Guillard vs. Jeremy Stephens
# Jeremy Stephens has an EV of 92.48 on odds of -105.  They have 98.59 % chance of winning.
#
# CB Dollaway vs. Joe Doerksen
# CB Dollaway has an EV of 9.69 on odds of -255.  They have 78.79 % chance of winning.
#
# Matt Mitrione vs. Joey Beltran
# Matt Mitrione has an EV of 24.69 on odds of -174.  They have 79.18 % chance of winning.
#
# Steve Lopez vs. Waylon Lowe
# Steve Lopez has an EV of 87.49 on odds of 140.  They have 78.12 % chance of winning.
#
# TJ Grant vs. Julio Paulino
# TJ Grant has an EV of 4.43 on odds of -220.  They have 71.79 % chance of winning.
#
# Nate Marquardt vs. Rousimar Palhares
# Nate Marquardt has an EV of 12.19 on odds of -235.  They have 78.7 % chance of winning.
#
# Efrain Escudero vs. Charles Oliveira
# Efrain Escudero has an EV of 23.17 on odds of -155.  They have 74.87 % chance of winning.
#
# Jim Miller vs. Gleison Tibau
# Jim Miller has an EV of 2.26 on odds of -125.  They have 56.81 % chance of winning.
#
# Cole Miller vs. Ross Pearson
# Cole Miller has an EV of 139.86 on odds of 190.  They have 82.71 % chance of winning.
#
# Yves Edwards vs. John Gunderson
# Yves Edwards has an EV of 47.24 on odds of 105.  They have 71.82 % chance of winning.
#
# Jared Hamman vs. Kyle Kingsbury
# Kyle Kingsbury has an EV of 1.74 on odds of 160.  They have 39.13 % chance of winning.
#
# Tomasz Drwal vs. David Branch
# Tomasz Drwal has an EV of 13.47 on odds of -155.  They have 68.97 % chance of winning.
#
# Brian Foster vs. Forrest Petz
# Brian Foster has an EV of 2.21 on odds of -240.  They have 72.15 % chance of winning.
#
# Frankie Edgar vs. BJ Penn
# Frankie Edgar has an EV of 88.28 on odds of 248.  They have 54.1 % chance of winning.
#
# Demian Maia vs. Mario Miranda
# Demian Maia has an EV of 13.97 on odds of -210.  They have 77.21 % chance of winning.
#
# Kenny Florian vs. Gray Maynard
# Gray Maynard has an EV of 129.06 on odds of 130.  They have 99.59 % chance of winning.
#
# Nate Diaz vs. Marcus Davis
# Nate Diaz has an EV of 35.36 on odds of -190.  They have 88.68 % chance of winning.
#
# Joe Lauzon vs. Gabe Ruediger
# Joe Lauzon has an EV of 22.0 on odds of -320.  They have 92.95 % chance of winning.
#
# Andre Winner vs. Nik Lentz
# Andre Winner has an EV of 39.83 on odds of -115.  They have 74.79 % chance of winning.
#
# Dan Miller vs. John Salter
# No bets.  EV1:-2.169183104499929. EV2: -7.736832937269
# Dan Miller has an EV of -2.17 on odds of -230.  They have 68.19 % chance of winning.
#
# Nick Osipczak vs. Greg Soto
# Nick Osipczak has an EV of 22.24 on odds of -200.  They have 81.49 % chance of winning.
#
# Anderson Silva vs. Chael Sonnen
# Anderson Silva has an EV of 19.92 on odds of -460.  They have 98.51 % chance of winning.
#
# Jon Fitch vs. Thiago Alves
# Jon Fitch has an EV of 71.63 on odds of 116.  They have 79.46 % chance of winning.
#
# Clay Guida vs. Rafael Dos Anjos
# Rafael Dos Anjos has an EV of 49.45 on odds of -126.  They have 83.32 % chance of winning.
#
# Matt Hughes vs. Ricardo Almeida
# Ricardo Almeida has an EV of 51.81 on odds of -193.  They have 100.0 % chance of winning.
#
# Roy Nelson vs. Junior Dos Santos
# Junior Dos Santos has an EV of 4.31 on odds of -345.  They have 80.87 % chance of winning.
#
# Dustin Hazelett vs. Rick Story
# Dustin Hazelett has an EV of 19.85 on odds of -150.  They have 71.91 % chance of winning.
#
# Rodney Wallace vs. Phil Davis
# Rodney Wallace has an EV of 315.78 on odds of 600.  They have 59.4 % chance of winning.
#
# Johny Hendricks vs. Charlie Brenneman
# Johny Hendricks has an EV of 6.52 on odds of -370.  They have 83.85 % chance of winning.
#
# Todd Brown vs. Tim Boetsch
# Todd Brown has an EV of 18.12 on odds of 290.  They have 30.29 % chance of winning.
#
# Ben Saunders vs. Dennis Hallman
# Ben Saunders has an EV of 26.7 on odds of -300.  They have 95.02 % chance of winning.
#
# Jon Jones vs. Vladimir Matyushenko
# Jon Jones has an EV of 13.06 on odds of -752.  They have 99.79 % chance of winning.
#
# Mark Munoz vs. Yushin Okami
# Yushin Okami has an EV of 6.87 on odds of -200.  They have 71.25 % chance of winning.
#
# John Howard vs. Jake Ellenberger
# Jake Ellenberger has an EV of 11.88 on odds of -196.  They have 74.09 % chance of winning.
#
# Tyson Griffin vs. Takanori Gomi
# Tyson Griffin has an EV of 16.59 on odds of -320.  They have 88.83 % chance of winning.
#
# Paul Kelly vs. Jacob Volkmann
# Paul Kelly has an EV of 26.63 on odds of -105.  They have 64.86 % chance of winning.
#
# DaMarques Johnson vs. Matthew Riddle
# Matthew Riddle has an EV of 14.67 on odds of -220.  They have 78.84 % chance of winning.
#
# James Irvin vs. Igor Pokrajac
# Igor Pokrajac has an EV of 0.41 on odds of 140.  They have 41.84 % chance of winning.
#
# Brian Stann vs. Mike Massenzio
# Brian Stann has an EV of 34.22 on odds of 180.  They have 47.93 % chance of winning.
#
# Rob Kimmons vs. Steve Steinbeiss
# Rob Kimmons has an EV of 17.95 on odds of -195.  They have 77.96 % chance of winning.
#
# Brock Lesnar vs. Shane Carwin
# No bets.  EV1:-1.833288020829535. EV2: -1.5318657424577324
# Brock Lesnar has an EV of -1.83 on odds of -145.  They have 58.1 % chance of winning.
#
# Chris Leben vs. Yoshihiro Akiyama
# Chris Leben has an EV of 41.03 on odds of 177.  They have 50.91 % chance of winning.
#
# Chris Lytle vs. Matt Brown
# Chris Lytle has an EV of 7.55 on odds of -180.  They have 69.14 % chance of winning.
#
# Krzysztof Soszynski vs. Stephan Bonnar
# Stephan Bonnar has an EV of 167.15 on odds of 175.  They have 97.15 % chance of winning.
#
# George Sotiropoulos vs. Kurt Pellegrino
# Kurt Pellegrino has an EV of 0.25 on odds of 148.  They have 40.42 % chance of winning.
#
# Brendan Schaub vs. Chris Tuchscherer
# Brendan Schaub has an EV of 6.78 on odds of -305.  They have 80.41 % chance of winning.
#
# Kendall Grove vs. Goran Reljic
# No bets.  EV1:-0.5064000812393843. EV2: -2.728149007771556
# Kendall Grove has an EV of -0.51 on odds of 130.  They have 43.26 % chance of winning.
#
# Forrest Petz vs. Daniel Roberts
# Forrest Petz has an EV of 14.09 on odds of 170.  They have 42.25 % chance of winning.
#
# Keith Jardine vs. Matt Hamill
# Matt Hamill has an EV of 44.87 on odds of -150.  They have 86.92 % chance of winning.
#
# Chris Leben vs. Aaron Simpson
# Chris Leben has an EV of 34.49 on odds of 280.  They have 35.39 % chance of winning.
#
# Spencer Fisher vs. Dennis Siver
# Dennis Siver has an EV of 156.35 on odds of 165.  They have 96.73 % chance of winning.
#
# Chuck Liddell vs. Rich Franklin
# Rich Franklin has an EV of 103.5 on odds of 109.  They have 97.37 % chance of winning.
#
# Mirko Cro Cop vs. Pat Barry
# Pat Barry has an EV of 55.7 on odds of -173.  They have 98.67 % chance of winning.
#
# Paulo Thiago vs. Martin Kampmann
# Martin Kampmann has an EV of 4.74 on odds of 198.  They have 35.15 % chance of winning.
#
# Ben Rothwell vs. Gilbert Yvel
# Ben Rothwell has an EV of 45.92 on odds of 170.  They have 54.05 % chance of winning.
#
# Carlos Condit vs. Rory MacDonald
# Rory MacDonald has an EV of 10.15 on odds of -128.  They have 61.84 % chance of winning.
#
# Tyson Griffin vs. Evan Dunham
# Evan Dunham has an EV of 6.11 on odds of 168.  They have 39.59 % chance of winning.
#
# Mac Danzig vs. Matt Wiman
# Mac Danzig has an EV of 10.48 on odds of -102.  They have 55.79 % chance of winning.
#
# David Loiseau vs. Mario Miranda
# Mario Miranda has an EV of 40.82 on odds of -245.  They have 100.0 % chance of winning.
#
# James Wilks vs. Peter Sobotta
# James Wilks has an EV of 29.99 on odds of -325.  They have 99.4 % chance of winning.
#
# Mike Pyle vs. Jesse Lennox
# Jesse Lennox has an EV of 0.0 on odds of -130.  They have 56.52 % chance of winning.
#
# Rampage Jackson vs. Rashad Evans
# No bets.  EV1:-2.6130165632936837. EV2: -2.067905638107156
# Rampage Jackson has an EV of -2.61 on odds of -109.  They have 50.79 % chance of winning.
#
# Michael Bisping vs. Dan Miller
# Dan Miller has an EV of 9.63 on odds of 180.  They have 39.15 % chance of winning.
#
# Todd Duffee vs. Mike Russow
# Todd Duffee has an EV of 3.36 on odds of -275.  They have 75.79 % chance of winning.
#
# Jason Brilz vs. Rogerio Nogueira
# Jason Brilz has an EV of 170.0 on odds of 435.  They have 50.47 % chance of winning.
#
# Diego Sanchez vs. John Hathaway
# John Hathaway has an EV of 71.27 on odds of 195.  They have 58.06 % chance of winning.
#
# Amir Sadollah vs. Dong Hyun Kim
# Dong Hyun Kim has an EV of 13.93 on odds of -110.  They have 59.68 % chance of winning.
#
# Efrain Escudero vs. Dan Lauzon
# Efrain Escudero has an EV of 2.35 on odds of -400.  They have 81.88 % chance of winning.
#
# Aaron Riley vs. Joe Brammer
# Aaron Riley has an EV of 3.05 on odds of -200.  They have 68.7 % chance of winning.
#
# Jesse Forbes vs. Ryan Jensen
# Jesse Forbes has an EV of 10.85 on odds of -150.  They have 66.51 % chance of winning.
#
# Lyoto Machida vs. Mauricio Rua
# Lyoto Machida has an EV of 33.32 on odds of -190.  They have 87.35 % chance of winning.
#
# Josh Koscheck vs. Paul Daley
# Josh Koscheck has an EV of 3.26 on odds of -250.  They have 73.76 % chance of winning.
#
# Sam Stout vs. Jeremy Stephens
# Jeremy Stephens has an EV of 20.1 on odds of 175.  They have 43.67 % chance of winning.
#
# Kevin Ferguson vs. Matt Mitrione
# Kevin Ferguson has an EV of 18.85 on odds of -103.  They have 60.3 % chance of winning.
#
# Patrick Cote vs. Alan Belcher
# Alan Belcher has an EV of 19.84 on odds of -117.  They have 64.62 % chance of winning.
#
# Tom Lawlor vs. Joe Doerksen
# Tom Lawlor has an EV of 9.01 on odds of -600.  They have 93.44 % chance of winning.
#
# Marcus Davis vs. Jonathan Goulet
# Marcus Davis has an EV of 3.48 on odds of -440.  They have 84.32 % chance of winning.
#
# TJ Grant vs. Johny Hendricks
# TJ Grant has an EV of 99.88 on odds of 325.  They have 47.03 % chance of winning.
#
# Joey Beltran vs. Tim Hague
# Joey Beltran has an EV of 5.68 on odds of 190.  They have 36.44 % chance of winning.
#
# Yoshiyuki Yoshida vs. Mike Guymon
# No bets.  EV1:-1.532101284042966. EV2: -7.800956742513527
# Yoshiyuki Yoshida has an EV of -1.53 on odds of -255.  They have 70.73 % chance of winning.
#
# Jason MacDonald vs. John Salter
# Jason MacDonald has an EV of 21.21 on odds of -175.  They have 77.14 % chance of winning.
#
# Anderson Silva vs. Demian Maia
# Anderson Silva has an EV of 13.98 on odds of -675.  They have 99.28 % chance of winning.
#
# BJ Penn vs. Frankie Edgar
# Frankie Edgar has an EV of 470.41 on odds of 620.  They have 79.22 % chance of winning.
#
# Terry Etim vs. Rafael Dos Anjos
# Terry Etim has an EV of 32.23 on odds of -135.  They have 75.96 % chance of winning.
#
# Kendall Grove vs. Mark Munoz
# Kendall Grove has an EV of 119.23 on odds of 160.  They have 84.32 % chance of winning.
#
# Alexander Gustafsson vs. Phil Davis
# Alexander Gustafsson has an EV of 44.15 on odds of 350.  They have 32.03 % chance of winning.
#
# Nick Osipczak vs. Rick Story
# Nick Osipczak has an EV of 80.57 on odds of 145.  They have 73.7 % chance of winning.
#
# DaMarques Johnson vs. Brad Blackburn
# DaMarques Johnson has an EV of 43.75 on odds of 140.  They have 59.9 % chance of winning.
#
# Paul Kelly vs. Matt Veach
# Paul Kelly has an EV of 64.14 on odds of 220.  They have 51.29 % chance of winning.
#
# Jon Madsen vs. Mostapha Al-Turk
# Jon Madsen has an EV of 6.02 on odds of -245.  They have 75.29 % chance of winning.
#
# Roy Nelson vs. Stefan Struve
# Roy Nelson has an EV of 28.28 on odds of -350.  They have 99.77 % chance of winning.
#
# Nate Quarry vs. Jorge Rivera
# Jorge Rivera has an EV of 16.25 on odds of 190.  They have 40.09 % chance of winning.
#
# Ross Pearson vs. Dennis Siver
# Dennis Siver has an EV of 165.61 on odds of 180.  They have 94.86 % chance of winning.
#
# Andre Winner vs. Rafaello Oliveira
# Andre Winner has an EV of 3.71 on odds of -190.  They have 67.94 % chance of winning.
#
# Jacob Volkmann vs. Ronys Torres
# Jacob Volkmann has an EV of 1.99 on odds of 190.  They have 35.17 % chance of winning.
#
# Rob Emerson vs. Nik Lentz
# Rob Emerson has an EV of 22.59 on odds of 130.  They have 53.3 % chance of winning.
#
# Caol Uno vs. Gleison Tibau
# No bets.  EV1:-8.706485581394631. EV2: -1.8478388206388843
# Caol Uno has an EV of -8.71 on odds of 270.  They have 24.67 % chance of winning.
#
# Yushin Okami vs. Lucio Linhares
# Yushin Okami has an EV of 12.47 on odds of -650.  They have 97.47 % chance of winning.
#
# Georges St-Pierre vs. Dan Hardy
# Georges St-Pierre has an EV of 6.07 on odds of -650.  They have 91.93 % chance of winning.
#
# Frank Mir vs. Shane Carwin
# Frank Mir has an EV of 14.45 on odds of -150.  They have 68.67 % chance of winning.
#
# Kurt Pellegrino vs. Fabricio Camoes
# Kurt Pellegrino has an EV of 5.5 on odds of -210.  They have 71.47 % chance of winning.
#
# Ben Saunders vs. Jon Fitch
# Ben Saunders has an EV of 96.03 on odds of 295.  They have 49.63 % chance of winning.
#
# Jim Miller vs. Mark Bocek
# No bets.  EV1:-2.351431618371933. EV2: -0.15574604826603888
# Jim Miller has an EV of -2.35 on odds of -320.  They have 74.4 % chance of winning.
# Nate Diaz vs. Rory Markham
# Nate Diaz has an EV of 31.9 on odds of -235.  They have 92.53 % chance of winning.
#
# Ricardo Almeida vs. Matt Brown
# Matt Brown has an EV of 22.53 on odds of 160.  They have 47.13 % chance of winning.
#
# Rousimar Palhares vs. Tomasz Drwal
# Rousimar Palhares has an EV of 8.73 on odds of -220.  They have 74.76 % chance of winning.
#
# Rodney Wallace vs. Jared Hamman
# Rodney Wallace has an EV of 41.25 on odds of -160.  They have 86.92 % chance of winning.
#
# Brandon Vera vs. Jon Jones
# Brandon Vera has an EV of 20.23 on odds of 215.  They have 38.17 % chance of winning.
#
# Junior Dos Santos vs. Gabriel Gonzaga
# Junior Dos Santos has an EV of 3.14 on odds of -250.  They have 73.67 % chance of winning.
#
# Cheick Kongo vs. Paul Buentello
# Paul Buentello has an EV of 261.6 on odds of 315.  They have 87.13 % chance of winning.
#
# Alessio Sakara vs. James Irvin
# Alessio Sakara has an EV of 7.82 on odds of -120.  They have 58.81 % chance of winning.
#
# Clay Guida vs. Shannon Gugerty
# Shannon Gugerty has an EV of 36.32 on odds of 335.  They have 31.34 % chance of winning.
#
# Eliot Marshall vs. Vladimir Matyushenko
# Eliot Marshall has an EV of 27.79 on odds of 145.  They have 52.16 % chance of winning.
#
# Brendan Schaub vs. Chase Gormley
# Chase Gormley has an EV of 0.42 on odds of 220.  They have 31.38 % chance of winning.
#
# Eric Schafer vs. Jason Brilz
# Eric Schafer has an EV of 54.48 on odds of 140.  They have 64.37 % chance of winning.

# %%
output_df
# Out:
#                   t1_name               t2_name       date  t1_odds  t2_odds  \
# 0         Israel Adesanya        Marvin Vettori 2021-06-12     -235      185
# 1     Deiveson Figueiredo        Brandon Moreno 2021-06-12     -195      150
# 2            Leon Edwards             Nate Diaz 2021-06-12     -500      355
# 3             Demian Maia        Belal Muhammad 2021-06-12      170     -220
# 4              Paul Craig          Jamahal Hill 2021-06-12      210     -275
# ...                   ...                   ...        ...      ...      ...
# 3910       Alessio Sakara           James Irvin 2010-03-21     -120      100
# 3911           Clay Guida       Shannon Gugerty 2010-03-21     -420      335
# 3912       Eliot Marshall  Vladimir Matyushenko 2010-03-21      145     -165
# 3913       Brendan Schaub         Chase Gormley 2010-03-21     -260      220
# 3914         Eric Schafer           Jason Brilz 2010-03-21      140     -160
#
#             R_ev        B_ev       t1_prob   t2_prob  winner   bet
# 0      42.553191  185.000000  6.818231e-07  0.999999       0  Blue
# 1      51.282051  150.000000  4.546628e-28  1.000000       1  Blue
# 2      20.000000  355.000000  9.021747e-01  0.097825       0   Red
# 3     170.000000   45.454545  5.559506e-01  0.444049       1   Red
# 4     210.000000   36.363636  5.407258e-01  0.459274       0   Red
# ...          ...         ...           ...       ...     ...   ...
# 3910   83.333333  100.000000  5.881206e-01  0.411879       0   Red
# 3911   23.809524  335.000000  6.866108e-01  0.313389       0  Blue
# 3912  145.000000   60.606061  5.215786e-01  0.478421       1   Red
# 3913   38.461538  220.000000  6.861802e-01  0.313820       0  Blue
# 3914  140.000000   62.500000  6.436861e-01  0.356314       1   Red
#
# [3915 rows x 11 columns]

# %%
def get_profit(bet, R_ev, B_ev, winner): 
    if bet == None:
        return 0
    if bet == 'Red' and winner == 0:
        return R_ev
    if bet == 'Blue' and winner == 1:
        return B_ev
    else:
        return -100

# %%
output_df['net_profit'] = output_df.apply(lambda x: get_profit(x['bet'], x['R_ev'], x['B_ev'], x['winner']), axis=1)

# %%
output_df
# Out:
#                   t1_name               t2_name       date  t1_odds  t2_odds  \
# 0         Israel Adesanya        Marvin Vettori 2021-06-12     -235      185
# 1     Deiveson Figueiredo        Brandon Moreno 2021-06-12     -195      150
# 2            Leon Edwards             Nate Diaz 2021-06-12     -500      355
# 3             Demian Maia        Belal Muhammad 2021-06-12      170     -220
# 4              Paul Craig          Jamahal Hill 2021-06-12      210     -275
# ...                   ...                   ...        ...      ...      ...
# 3910       Alessio Sakara           James Irvin 2010-03-21     -120      100
# 3911           Clay Guida       Shannon Gugerty 2010-03-21     -420      335
# 3912       Eliot Marshall  Vladimir Matyushenko 2010-03-21      145     -165
# 3913       Brendan Schaub         Chase Gormley 2010-03-21     -260      220
# 3914         Eric Schafer           Jason Brilz 2010-03-21      140     -160
#
#             R_ev        B_ev       t1_prob   t2_prob  winner   bet  net_profit
# 0      42.553191  185.000000  6.818231e-07  0.999999       0  Blue -100.000000
# 1      51.282051  150.000000  4.546628e-28  1.000000       1  Blue  150.000000
# 2      20.000000  355.000000  9.021747e-01  0.097825       0   Red   20.000000
# 3     170.000000   45.454545  5.559506e-01  0.444049       1   Red -100.000000
# 4     210.000000   36.363636  5.407258e-01  0.459274       0   Red  210.000000
# ...          ...         ...           ...       ...     ...   ...         ...
# 3910   83.333333  100.000000  5.881206e-01  0.411879       0   Red   83.333333
# 3911   23.809524  335.000000  6.866108e-01  0.313389       0  Blue -100.000000
# 3912  145.000000   60.606061  5.215786e-01  0.478421       1   Red -100.000000
# 3913   38.461538  220.000000  6.861802e-01  0.313820       0  Blue -100.000000
# 3914  140.000000   62.500000  6.436861e-01  0.356314       1   Red -100.000000
#
# [3915 rows x 12 columns]

# %%
output_df.to_csv('bet_result_df.csv')
