# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
import numpy as np
from sklearn.model_selection import KFold
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
df = pd.read_csv("../data/ufc-master.csv")

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5540 entries, 0 to 5539
# Data columns (total 79 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   R_fighter                     4252 non-null   object
#  1   B_fighter                     4252 non-null   object
#  2   R_odds                        4252 non-null   float64
#  3   B_odds                        4252 non-null   float64
#  4   R_ev                          4252 non-null   float64
#  5   B_ev                          4252 non-null   float64
#  6   date                          4252 non-null   object
#  7   location                      4252 non-null   object
#  8   country                       4252 non-null   object
#  9   Winner                        4252 non-null   object
#  10  title_bout                    4252 non-null   object
#  11  weight_class                  4252 non-null   object
#  12  gender                        4252 non-null   object
#  13  no_of_rounds                  4252 non-null   float64
#  14  B_current_lose_streak         4252 non-null   float64
#  15  B_current_win_streak          4252 non-null   float64
#  16  B_draw                        4252 non-null   float64
#  17  B_avg_SIG_STR_landed          3302 non-null   float64
#  18  B_avg_SIG_STR_pct             3470 non-null   float64
#  19  B_avg_SUB_ATT                 3403 non-null   float64
#  20  B_avg_TD_landed               3402 non-null   float64
#  21  B_avg_TD_pct                  3391 non-null   float64
#  22  B_longest_win_streak          4252 non-null   float64
#  23  B_losses                      4252 non-null   float64
#  24  B_total_rounds_fought         4252 non-null   float64
#  25  B_total_title_bouts           4252 non-null   float64
#  26  B_win_by_Decision_Majority    4252 non-null   float64
#  27  B_win_by_Decision_Split       4252 non-null   float64
#  28  B_win_by_Decision_Unanimous   4252 non-null   float64
#  29  B_win_by_KO/TKO               4252 non-null   float64
#  30  B_win_by_Submission           4252 non-null   float64
#  31  B_win_by_TKO_Doctor_Stoppage  4252 non-null   float64
#  32  B_wins                        4252 non-null   float64
#  33  B_Stance                      4252 non-null   object
#  34  B_Height_cms                  4252 non-null   float64
#  35  B_Reach_cms                   4252 non-null   float64
#  36  B_Weight_lbs                  4252 non-null   float64
#  37  R_current_lose_streak         4252 non-null   float64
#  38  R_current_win_streak          4252 non-null   float64
#  39  R_draw                        4252 non-null   float64
#  40  R_avg_SIG_STR_landed          3790 non-null   float64
#  41  R_avg_SIG_STR_pct             3891 non-null   float64
#  42  R_avg_SUB_ATT                 3891 non-null   float64
#  43  R_avg_TD_landed               3891 non-null   float64
#  44  R_avg_TD_pct                  3879 non-null   float64
#  45  R_longest_win_streak          4252 non-null   float64
#  46  R_losses                      4252 non-null   float64
#  47  R_total_rounds_fought         4252 non-null   float64
#  48  R_total_title_bouts           4252 non-null   float64
#  49  R_win_by_Decision_Majority    4252 non-null   float64
#  50  R_win_by_Decision_Split       4252 non-null   float64
#  51  R_win_by_Decision_Unanimous   4252 non-null   float64
#  52  R_win_by_KO/TKO               4252 non-null   float64
#  53  R_win_by_Submission           4252 non-null   float64
#  54  R_win_by_TKO_Doctor_Stoppage  4252 non-null   float64
#  55  R_wins                        4252 non-null   float64
#  56  R_Stance                      4252 non-null   object
#  57  R_Height_cms                  4252 non-null   float64
#  58  R_Reach_cms                   4252 non-null   float64
#  59  R_Weight_lbs                  4252 non-null   float64
#  60  R_age                         4252 non-null   float64
#  61  B_age                         4252 non-null   float64
#  62  lose_streak_dif               4252 non-null   float64
#  63  win_streak_dif                4252 non-null   float64
#  64  longest_win_streak_dif        4252 non-null   float64
#  65  win_dif                       4252 non-null   float64
#  66  loss_dif                      4252 non-null   float64
#  67  total_round_dif               4252 non-null   float64
#  68  total_title_bout_dif          4252 non-null   float64
#  69  ko_dif                        4252 non-null   float64
#  70  sub_dif                       4252 non-null   float64
#  71  height_dif                    4252 non-null   float64
#  72  reach_dif                     4252 non-null   float64
#  73  age_dif                       4252 non-null   float64
#  74  sig_str_dif                   4252 non-null   float64
#  75  avg_sub_att_dif               4252 non-null   float64
#  76  avg_td_dif                    4252 non-null   float64
#  77  empty_arena                   4252 non-null   float64
#  78  constant_1                    4252 non-null   float64
# dtypes: float64(68), object(11)
# memory usage: 3.3+ MB

# %%
#Let's put all the labels in a dataframe
df['label'] = ''
#If the winner is not Red or Blue we can remove it.
mask = df['Winner'] == 'Red'
df['label'][mask] = 0
mask = df['Winner'] == 'Blue'
df['label'][mask] = 1

#df["Winner"] = df["Winner"].astype('category')
df = df[(df['Winner'] == 'Blue') | (df['Winner'] == 'Red')]


#Make sure lable is numeric
df['label'] = pd.to_numeric(df['label'], errors='coerce')
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
display(df[['Winner', 'label']])
df.info(verbose=True)
# Out:
#      Winner  label
# 0       Red      0
# 1       Red      0
# 2       Red      0
# 3       Red      0
# 4       Red      0
# ...     ...    ...
# 4247   Blue      1
# 4248    Red      0
# 4249    Red      0
# 4250    Red      0
# 4251   Blue      1
#
# [4179 rows x 2 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4179 entries, 0 to 4251
# Data columns (total 80 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   R_fighter                     4179 non-null   object
#  1   B_fighter                     4179 non-null   object
#  2   R_odds                        4179 non-null   float64
#  3   B_odds                        4179 non-null   float64
#  4   R_ev                          4179 non-null   float64
#  5   B_ev                          4179 non-null   float64
#  6   date                          4179 non-null   object
#  7   location                      4179 non-null   object
#  8   country                       4179 non-null   object
#  9   Winner                        4179 non-null   object
#  10  title_bout                    4179 non-null   object
#  11  weight_class                  4179 non-null   object
#  12  gender                        4179 non-null   object
#  13  no_of_rounds                  4179 non-null   float64
#  14  B_current_lose_streak         4179 non-null   float64
#  15  B_current_win_streak          4179 non-null   float64
#  16  B_draw                        4179 non-null   float64
#  17  B_avg_SIG_STR_landed          3249 non-null   float64
#  18  B_avg_SIG_STR_pct             3414 non-null   float64
#  19  B_avg_SUB_ATT                 3347 non-null   float64
#  20  B_avg_TD_landed               3346 non-null   float64
#  21  B_avg_TD_pct                  3337 non-null   float64
#  22  B_longest_win_streak          4179 non-null   float64
#  23  B_losses                      4179 non-null   float64
#  24  B_total_rounds_fought         4179 non-null   float64
#  25  B_total_title_bouts           4179 non-null   float64
#  26  B_win_by_Decision_Majority    4179 non-null   float64
#  27  B_win_by_Decision_Split       4179 non-null   float64
#  28  B_win_by_Decision_Unanimous   4179 non-null   float64
#  29  B_win_by_KO/TKO               4179 non-null   float64
#  30  B_win_by_Submission           4179 non-null   float64
#  31  B_win_by_TKO_Doctor_Stoppage  4179 non-null   float64
#  32  B_wins                        4179 non-null   float64
#  33  B_Stance                      4179 non-null   object
#  34  B_Height_cms                  4179 non-null   float64
#  35  B_Reach_cms                   4179 non-null   float64
#  36  B_Weight_lbs                  4179 non-null   float64
#  37  R_current_lose_streak         4179 non-null   float64
#  38  R_current_win_streak          4179 non-null   float64
#  39  R_draw                        4179 non-null   float64
#  40  R_avg_SIG_STR_landed          3724 non-null   float64
#  41  R_avg_SIG_STR_pct             3822 non-null   float64
#  42  R_avg_SUB_ATT                 3822 non-null   float64
#  43  R_avg_TD_landed               3822 non-null   float64
#  44  R_avg_TD_pct                  3812 non-null   float64
#  45  R_longest_win_streak          4179 non-null   float64
#  46  R_losses                      4179 non-null   float64
#  47  R_total_rounds_fought         4179 non-null   float64
#  48  R_total_title_bouts           4179 non-null   float64
#  49  R_win_by_Decision_Majority    4179 non-null   float64
#  50  R_win_by_Decision_Split       4179 non-null   float64
#  51  R_win_by_Decision_Unanimous   4179 non-null   float64
#  52  R_win_by_KO/TKO               4179 non-null   float64
#  53  R_win_by_Submission           4179 non-null   float64
#  54  R_win_by_TKO_Doctor_Stoppage  4179 non-null   float64
#  55  R_wins                        4179 non-null   float64
#  56  R_Stance                      4179 non-null   object
#  57  R_Height_cms                  4179 non-null   float64
#  58  R_Reach_cms                   4179 non-null   float64
#  59  R_Weight_lbs                  4179 non-null   float64
#  60  R_age                         4179 non-null   float64
#  61  B_age                         4179 non-null   float64
#  62  lose_streak_dif               4179 non-null   float64
#  63  win_streak_dif                4179 non-null   float64
#  64  longest_win_streak_dif        4179 non-null   float64
#  65  win_dif                       4179 non-null   float64
#  66  loss_dif                      4179 non-null   float64
#  67  total_round_dif               4179 non-null   float64
#  68  total_title_bout_dif          4179 non-null   float64
#  69  ko_dif                        4179 non-null   float64
#  70  sub_dif                       4179 non-null   float64
#  71  height_dif                    4179 non-null   float64
#  72  reach_dif                     4179 non-null   float64
#  73  age_dif                       4179 non-null   float64
#  74  sig_str_dif                   4179 non-null   float64
#  75  avg_sub_att_dif               4179 non-null   float64
#  76  avg_td_dif                    4179 non-null   float64
#  77  empty_arena                   4179 non-null   float64
#  78  constant_1                    4179 non-null   float64
#  79  label                         4179 non-null   int64
# dtypes: float64(68), int64(1), object(11)
# memory usage: 2.6+ MB

# %%
#Let's fix the date
df['date'] = pd.to_datetime(df['date'])

# %%
#Create a label df:
label_df = df['label']

#Let's create an odds df too:
odds_df = df[['R_odds', 'B_odds']]

# %%
#Split the test set.  We are always(?) going to use the last 200 matches as the test set, so we don't want those around
#as we pick models

df_train = df[200:]
odds_train = odds_df[200:]
label_train = label_df[200:]

df_test = df[:200]
odds_test = odds_df[:200]
label_test = label_df[:200]

print(len(df_test))
print(len(odds_test))
print(len(label_test))

print(len(df_train))
print(len(odds_train))
print(len(label_train))
# Out:
# 200
# 200
# 200
# 3979
# 3979
# 3979

# %%
display(df_train)
display(df_test)

# %%
print(df_train.columns)
# Out:
# Index(['R_fighter', 'B_fighter', 'R_odds', 'B_odds', 'R_ev', 'B_ev', 'date',
#        'location', 'country', 'Winner', 'title_bout', 'weight_class', 'gender',
#        'no_of_rounds', 'B_current_lose_streak', 'B_current_win_streak',
#        'B_draw', 'B_avg_SIG_STR_landed', 'B_avg_SIG_STR_pct', 'B_avg_SUB_ATT',
#        'B_avg_TD_landed', 'B_avg_TD_pct', 'B_longest_win_streak', 'B_losses',
#        'B_total_rounds_fought', 'B_total_title_bouts',
#        'B_win_by_Decision_Majority', 'B_win_by_Decision_Split',
#        'B_win_by_Decision_Unanimous', 'B_win_by_KO/TKO', 'B_win_by_Submission',
#        'B_win_by_TKO_Doctor_Stoppage', 'B_wins', 'B_Stance', 'B_Height_cms',
#        'B_Reach_cms', 'B_Weight_lbs', 'R_current_lose_streak',
#        'R_current_win_streak', 'R_draw', 'R_avg_SIG_STR_landed',
#        'R_avg_SIG_STR_pct', 'R_avg_SUB_ATT', 'R_avg_TD_landed', 'R_avg_TD_pct',
#        'R_longest_win_streak', 'R_losses', 'R_total_rounds_fought',
#        'R_total_title_bouts', 'R_win_by_Decision_Majority',
#        'R_win_by_Decision_Split', 'R_win_by_Decision_Unanimous',
#        'R_win_by_KO/TKO', 'R_win_by_Submission',
#        'R_win_by_TKO_Doctor_Stoppage', 'R_wins', 'R_Stance', 'R_Height_cms',
#        'R_Reach_cms', 'R_Weight_lbs', 'R_age', 'B_age', 'lose_streak_dif',
#        'win_streak_dif', 'longest_win_streak_dif', 'win_dif', 'loss_dif',
#        'total_round_dif', 'total_title_bout_dif', 'ko_dif', 'sub_dif',
#        'height_dif', 'reach_dif', 'age_dif', 'sig_str_dif', 'avg_sub_att_dif',
#        'avg_td_dif', 'empty_arena', 'constant_1', 'label'],
#       dtype='object')

# %%
#Full list of possible features
#Basically inclusive features with the labelm constant_1 and Winner removed
my_pos_features = ['R_fighter', 'B_fighter', 'R_odds', 'B_odds', 'R_ev', 'B_ev',
       'location', 'country', 'title_bout', 'weight_class', 'gender',
       'no_of_rounds', 'B_current_lose_streak', 'B_current_win_streak',
       'B_draw', 'B_avg_SIG_STR_landed', 'B_avg_SIG_STR_pct', 'B_avg_SUB_ATT',
       'B_avg_TD_landed', 'B_avg_TD_pct', 'B_longest_win_streak', 'B_losses',
       'B_total_rounds_fought', 'B_total_title_bouts',
       'B_win_by_Decision_Majority', 'B_win_by_Decision_Split',
       'B_win_by_Decision_Unanimous', 'B_win_by_KO/TKO', 'B_win_by_Submission',
       'B_win_by_TKO_Doctor_Stoppage', 'B_wins', 'B_Stance', 'B_Height_cms',
       'B_Reach_cms', 'B_Weight_lbs', 'R_current_lose_streak',
       'R_current_win_streak', 'R_draw', 'R_avg_SIG_STR_landed',
       'R_avg_SIG_STR_pct', 'R_avg_SUB_ATT', 'R_avg_TD_landed', 'R_avg_TD_pct',
       'R_longest_win_streak', 'R_losses', 'R_total_rounds_fought',
       'R_total_title_bouts', 'R_win_by_Decision_Majority',
       'R_win_by_Decision_Split', 'R_win_by_Decision_Unanimous',
       'R_win_by_KO/TKO', 'R_win_by_Submission',
       'R_win_by_TKO_Doctor_Stoppage', 'R_wins', 'R_Stance', 'R_Height_cms',
       'R_Reach_cms', 'R_Weight_lbs', 'R_age', 'B_age', 'lose_streak_dif',
       'win_streak_dif', 'longest_win_streak_dif', 'win_dif', 'loss_dif',
       'total_round_dif', 'total_title_bout_dif', 'ko_dif', 'sub_dif',
       'height_dif', 'reach_dif', 'age_dif', 'sig_str_dif', 'avg_sub_att_dif',
       'avg_td_dif', 'empty_arena']

# %%
test_model = DecisionTreeClassifier(random_state=75)
test_current_features = []

# %%
#Input: American Odds, and Probability of a Winning Bet
#Output: Bet EV based on a $100 bet
def get_bet_ev(odds, prob):
    if odds>0:
        return ((odds * prob) - (100 * (1-prob)) )
    else:
        return ((100 / abs(odds))*100*prob - (100 * (1-prob)))

# %%
#Input: American Odds
#Output: Profit on a successful bet
def get_bet_return(odds):
    if odds>0:
        return odds
    else:
        return (100 / abs(odds))*100

# %%
def get_ev_from_df(ev_df, print_stats = False, min_ev = 0):
    num_matches = 0
    num_bets = 0
    num_wins = 0
    num_losses= 0
    num_under= 0
    num_under_losses = 0
    num_under_wins = 0
    num_even = 0
    num_even_losses = 0
    num_even_wins = 0
    num_fav = 0
    num_fav_wins = 0
    num_fav_losses = 0
    profit = 0
    profit_per_bet = 0
    profit_per_match = 0    

    for index, row in ev_df.iterrows():
        num_matches = num_matches+1
        t1_bet_ev = get_bet_ev(row['t1_odds'], row['t1_prob'])
        #print(f"ODDS:{row['t1_odds']} PROB: {row['t1_prob']} EV: {t1_bet_ev}")
        t2_bet_ev = get_bet_ev(row['t2_odds'], row['t2_prob'])
        #print(f"ODDS:{row['t2_odds']} PROB: {row['t2_prob']} EV: {t2_bet_ev}")
        #print()
        
        t1_bet_return = get_bet_return(row['t1_odds'])
        t2_bet_return = get_bet_return(row['t2_odds'])
        
        
        if (t1_bet_ev > min_ev or t2_bet_ev > min_ev):
            num_bets = num_bets+1

            
        if t1_bet_ev > min_ev:
            if row['winner'] == 0:
                num_wins += 1
                profit = profit + t1_bet_return
                #print(t1_bet_return)
            elif row['winner'] == 1:
                num_losses += 1
                profit = profit - 100
            if (t1_bet_return > t2_bet_return):
                num_under += 1
                if row['winner'] == 0:
                    num_under_wins += 1
                elif row['winner'] == 1:
                    num_under_losses += 1
            elif (t1_bet_return < t2_bet_return):
                num_fav += 1
                if row['winner'] == 0:
                    num_fav_wins += 1
                elif row['winner'] == 1:
                    num_fav_losses += 1
            else:
                num_even += 1
                if row['winner'] == 0:
                    num_even_wins += 1
                elif row['winner'] == 1:
                    num_even_losses += 1

        if t2_bet_ev > min_ev:
            if row['winner'] == 1:
                num_wins += 1                    
                profit = profit + t2_bet_return
            elif row['winner'] == 0:
                num_losses += 1
                profit = profit - 100
            if (t2_bet_return > t1_bet_return):
                num_under += 1
                if row['winner'] == 1:
                    num_under_wins += 1
                elif row['winner'] == 0:
                    num_under_losses += 1
            elif (t2_bet_return < t1_bet_return):
                num_fav += 1
                if row['winner'] == 1:
                    num_fav_wins += 1
                elif row['winner'] == 0:
                    num_fav_losses += 1
            else:
                num_even += 1
                if row['winner'] == 1:
                    num_even_wins += 1
                elif row['winner'] == 0:
                    num_even_losses += 1
            
    profit_per_bet = profit / num_bets
    profit_per_match = profit / num_matches
        
        
    if print_stats:
        print(f"""
          Number of matches: {num_matches}
          Number of bets: {num_bets}
          Number of winning bets: {num_wins}
          Number of losing bets: {num_losses}
          Number of underdog bets: {num_under}
          Number of underdog wins: {num_under_wins}
          Number of underdog losses: {num_under_losses}
          Number of Favorite bets: {num_fav}
          Number of favorite wins: {num_fav_wins}
          Number of favorite losses: {num_fav_losses}
          Number of even bets: {num_even}
          Number of even wins: {num_even_wins}
          Number of even losses: {num_even_losses}
          Profit: {profit}
          Profit per bet: {profit_per_bet}
          Profit per match: {profit_per_match}
          
          """)
        
    return (profit_per_bet)

# %%
#INPUT: 
#df: The df to be evaluated
#m: The model to use
# labels: The labels
#odds: The odds
#min_ev: The minimum EV to place a bet
def custom_cv_eval(df, m, labels, odds, min_ev=0):
    X = np.array(df)
    y = np.array(labels)
    odds = np.array(odds)
    running_total = 0
    count=1
    kf = KFold(n_splits=5, shuffle=True, random_state=75)
    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        odds_train, odds_test = odds[train_index], odds[test_index]
        #display(y_train)
        m.fit(X_train, y_train)
        probs=m.predict_proba(X_test)
        #print(probs)
        #We need to prep the dataframe to evaluate....
        #X_odds = X_test[['t1_odds', 't2_odds']]
        #print(X_test)
        #print(X_test[:, -1])
        #print(X_test[:, -2])
        X_odds = list(zip(odds_test[:, -2], odds_test[:, -1], probs[:, 0], probs[:, 1], y_test))
        ev_prepped_df = pd.DataFrame(X_odds, columns=['t1_odds', 't2_odds', 't1_prob', 't2_prob', 'winner'])
        #display(ev_prepped_df)
        #display(temp_df)
        #print(f"{count}: {get_ev_from_df(ev_prepped_df, print_stats = False)}")
        count=count+1
        running_total = running_total + get_ev_from_df(ev_prepped_df, print_stats = False, min_ev = min_ev)
        #display(ev_prepped_df)
    
    return running_total

# %%
#custom_cv_eval(df_train[['constant_1']], test_model, label_train, odds_train)
# Out:
# -23.547452012267335

# %%
#print(df_train[['label', 'Winner']])
# Out:
#       label Winner
# 0         0    Red
# 1         0    Red
# 2         0    Red
# 3         0    Red
# 4         0    Red
# ...     ...    ...
# 4045      1   Blue
# 4046      0    Red
# 4048      1   Blue
# 4049      1   Blue
# 4050      1   Blue
#
# [3979 rows x 2 columns]

# %%
#We split off the labels and the odds.  Now we can rewrite the get_best_features function
#INPUT
#pos_features: The list of possible features
#m: The model
#cur_features: The list of current features
#scale: Does the data need to be scaled?  


def get_best_features(pos_features, m, df, cur_features, labels, odds, scale=False):
    best_feature = ''
        
    #If there are no current features...
    if len(cur_features) == 0:
        best_score = -100
    else:
        df_sel = df[cur_features]
        df_sel = df_sel.dropna()
        df_sel = pd.get_dummies(df_sel)
        #OK we need to filter the labels and odds based off of the indices
        labels_sel = labels[labels.index.isin(df_sel.index)]
        odds_sel = odds[odds.index.isin(df_sel.index)]        
        best_score = custom_cv_eval(df_sel, m, labels_sel, odds_sel)
        
    best_feature = ""
    
    print(f"Current best score is: {best_score}")
    #Go thru every feature and test it...
    for f in pos_features:
        #If f is not a current feature
        if f not in cur_features:
            new_features = [f] + cur_features
            df_sel = df[new_features]
            df_sel = df_sel.dropna()
            df_sel = pd.get_dummies(df_sel)
            #display(df_sel)
            #OK we need to filter the labels and odds based off of the indices
            labels_sel = labels[labels.index.isin(df_sel.index)]
            odds_sel = odds[odds.index.isin(df_sel.index)]
            new_score = custom_cv_eval(df_sel, m, labels_sel, odds_sel)
            #print(f"{len(df_sel)} {len(labels_sel)} {len(odds_sel)}")
            print(f"Feature: {f} Score: {new_score}")
            if new_score > best_score:
                best_score = new_score
                best_feature = f
    if best_feature != "":
        print(f"The best feature was {best_feature}.  It scored {best_score}")
        cur_features = [best_feature] + cur_features
        #Keep running until we don't improve
        return(get_best_features(pos_features, m, df, cur_features, labels, odds, scale))
    else:
        print("NO IMPROVEMENT")
        print(f"FINAL BEST SCORE: {best_score}")
        return cur_features                
                
    return []

# %%
(get_best_features(my_pos_features, test_model, df_train, [], label_train, odds_train, True))
# Out:
# Current best score is: -100
# Feature: R_fighter Score: -12.359255573051662
# Feature: B_fighter Score: -9.506234185490857
# Feature: R_odds Score: -30.48964440616377
# Feature: B_odds Score: -23.735402291758316
# Feature: R_ev Score: -30.48964440616377
# Feature: B_ev Score: -23.735402291758316
# Feature: location Score: -18.419847335276092
# Feature: country Score: -18.403005110823894
# Feature: title_bout Score: -27.24151065686665
# Feature: weight_class Score: -27.391509271667292
# Feature: gender Score: -26.054925736138625
# Feature: no_of_rounds Score: -29.51557254815579
# Feature: B_current_lose_streak Score: -24.897844534155606
# Feature: B_current_win_streak Score: -25.247830375022673
# Feature: B_draw Score: -23.052064918509913
# Feature: B_avg_SIG_STR_landed Score: -11.986200607911503
# Feature: B_avg_SIG_STR_pct Score: -28.010063387342992
# Feature: B_avg_SUB_ATT Score: -24.75124763812522
# Feature: B_avg_TD_landed Score: -15.95157696635745
# Feature: B_avg_TD_pct Score: -1.2167213608852645
# Feature: B_longest_win_streak Score: -22.481023583410764
# Feature: B_losses Score: -25.254885615771954
# Feature: B_total_rounds_fought Score: -18.706055776351185
# Feature: B_total_title_bouts Score: -22.357520977537746
# Feature: B_win_by_Decision_Majority Score: -24.30676650643244
# Feature: B_win_by_Decision_Split Score: -21.512370197919104
# Feature: B_win_by_Decision_Unanimous Score: -23.77974335817211
# Feature: B_win_by_KO/TKO Score: -21.601069433525755
# Feature: B_win_by_Submission Score: -23.8943595259806
# Feature: B_win_by_TKO_Doctor_Stoppage Score: -23.385883321530564
# Feature: B_wins Score: -21.107063748408702
# Feature: B_Stance Score: -27.892655281857824
# Feature: B_Height_cms Score: -24.48599844512468
# Feature: B_Reach_cms Score: -27.811422196638034
# Feature: B_Weight_lbs Score: -25.438042626651715
# Feature: R_current_lose_streak Score: -28.326562847457364
# Feature: R_current_win_streak Score: -26.77467010750177
# Feature: R_draw Score: -23.38214266364946
# Feature: R_avg_SIG_STR_landed Score: -25.95873371801891
# Feature: R_avg_SIG_STR_pct Score: -30.685534040187846
# Feature: R_avg_SUB_ATT Score: -24.997753218808555
# Feature: R_avg_TD_landed Score: -16.91185260141281
# Feature: R_avg_TD_pct Score: -9.568062607930852
# Feature: R_longest_win_streak Score: -30.123847456132545
# Feature: R_losses Score: -30.22321188379467
# Feature: R_total_rounds_fought Score: -24.2730168103969
# Feature: R_total_title_bouts Score: -26.43523450655042
# Feature: R_win_by_Decision_Majority Score: -25.6905490845797
# Feature: R_win_by_Decision_Split Score: -25.529078954958226
# Feature: R_win_by_Decision_Unanimous Score: -29.500643683935586
# Feature: R_win_by_KO/TKO Score: -29.17751438473979
# Feature: R_win_by_Submission Score: -26.868959242656683
# Feature: R_win_by_TKO_Doctor_Stoppage Score: -24.250331567911996
# Feature: R_wins Score: -23.39711651095339
# Feature: R_Stance Score: -25.78621592287435
# Feature: R_Height_cms Score: -26.357775538945972
# Feature: R_Reach_cms Score: -26.518846447780156
# Feature: R_Weight_lbs Score: -25.247538307113974
# Feature: R_age Score: -30.742053526477147
# Feature: B_age Score: -21.718845469453772
# Feature: lose_streak_dif Score: -31.04410105296774
# Feature: win_streak_dif Score: -25.207286344661817
# Feature: longest_win_streak_dif Score: -33.587149206577436
# Feature: win_dif Score: -29.910940751670626
# Feature: loss_dif Score: -26.11545638625442
# Feature: total_round_dif Score: -27.329840299551144
# Feature: total_title_bout_dif Score: -20.563951510349035
# Feature: ko_dif Score: -27.723426659504682
# Feature: sub_dif Score: -28.131031381374708
# Feature: height_dif Score: -30.074586637299227
# Feature: reach_dif Score: -18.773791883987624
# Feature: age_dif Score: -19.202492401540226
# Feature: sig_str_dif Score: -11.256123402725766
# Feature: avg_sub_att_dif Score: -30.49006529689552
# Feature: avg_td_dif Score: -12.685660294399769
# Feature: empty_arena Score: -24.49822934523802
# The best feature was B_avg_TD_pct.  It scored -1.2167213608852645
# Current best score is: -1.2167213608852645
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-953d519c7062> in <module>
# ----> 1 (get_best_features(my_pos_features, test_model, df_train, [], label_train, odds_train, True))
#
# <ipython-input-18-1c7552edd0f1> in get_best_features(pos_features, m, df, cur_features, labels, odds, scale)
#      47         cur_features = [best_feature] + cur_features
#      48         #Keep running until we don't improve
# ---> 49         return(get_best_features(pos_features, m, df, cur_features, labels, odds, scale))
#      50     else:
#      51         print("NO IMPROVEMENT")
#
# <ipython-input-18-1c7552edd0f1> in get_best_features(pos_features, m, df, cur_features, labels, odds, scale)
#      32             df_sel = df[new_features]
#      33             df_sel = df_sel.dropna()
# ---> 34             df_sel = pd.get_dummies(df_sel)
#      35             #display(df_sel)
#      36             #OK we need to filter the labels and odds based off of the indices
#
# D:\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     923             )
#     924             with_dummies.append(dummy)
# --> 925         result = concat(with_dummies, axis=1)
#     926     else:
#     927         result = _get_dummies_1d(
#
# D:\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     282     )
#     283
# --> 284     return op.get_result()
#     285
#     286
#
# D:\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in get_result(self)
#     495
#     496             new_data = concatenate_block_managers(
# --> 497                 mgrs_indexers, self.new_axes, concat_axis=self.axis, copy=self.copy
#     498             )
#     499             if not self.copy:
#
# D:\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#    2010             values = b.values
#    2011             if copy:
# -> 2012                 values = values.copy()
#    2013             else:
#    2014                 values = values.view()
#
# KeyboardInterrupt:

# %%
model_1 = LogisticRegression(random_state=75)

# %%
(get_best_features(my_pos_features, model_1, df_train, [], label_train, odds_train, True))
# Out:
# Current best score is: -100
# Feature: R_fighter Score: -27.73529016456652
# Feature: B_fighter Score: -30.874346971243533
# Feature: R_odds Score: -28.532909112616146
# Feature: B_odds Score: -25.623022194215533
# Feature: R_ev Score: -32.45690584722519
# Feature: B_ev Score: 9.989235671762625
# Feature: location Score: -19.54117263713706
# Feature: country Score: -18.440820558392154
# Feature: title_bout Score: -26.66039359930254
# Feature: weight_class Score: -27.252708486822005
# Feature: gender Score: -26.176509738245272
# Feature: no_of_rounds Score: -29.955700861461093
# Feature: B_current_lose_streak Score: -25.118183762666174
# Feature: B_current_win_streak Score: -18.07997775287799
# Feature: B_draw Score: -23.66931154824347
# Feature: B_avg_SIG_STR_landed Score: -15.174827490268731
# Feature: B_avg_SIG_STR_pct Score: -15.860076955399895
# Feature: B_avg_SUB_ATT Score: -16.876934456161614
# Feature: B_avg_TD_landed Score: -17.854398687481208
# Feature: B_avg_TD_pct Score: -15.550316005039228
# Feature: B_longest_win_streak Score: -23.566023066475154
# Feature: B_losses Score: -27.27651076438803
# Feature: B_total_rounds_fought Score: -25.790914089182
# Feature: B_total_title_bouts Score: -22.45758436004241
# Feature: B_win_by_Decision_Majority Score: -24.574775405719834
# Feature: B_win_by_Decision_Split Score: -23.346298847643514
# Feature: B_win_by_Decision_Unanimous Score: -25.067497431164867
# Feature: B_win_by_KO/TKO Score: -24.05901704088806
# Feature: B_win_by_Submission Score: -24.00043133341806
# Feature: B_win_by_TKO_Doctor_Stoppage Score: -23.8425302694099
# Feature: B_wins Score: -24.900709098525326
# Feature: B_Stance Score: -27.892655281857824
# Feature: B_Height_cms Score: -23.91785102598974
# Feature: B_Reach_cms Score: -24.49820583090512
# Feature: B_Weight_lbs Score: -25.24153276996505
# Feature: R_current_lose_streak Score: -28.400096994590882
# Feature: R_current_win_streak Score: -28.5262221691203
# Feature: R_draw Score: -23.44353013837013
# Feature: R_avg_SIG_STR_landed Score: -24.551481706062674
# Feature: R_avg_SIG_STR_pct Score: -24.56261741542887
# Feature: R_avg_SUB_ATT Score: -23.265331417077807
# Feature: R_avg_TD_landed Score: -18.388258873789084
# Feature: R_avg_TD_pct Score: -21.282934710660832
# Feature: R_longest_win_streak Score: -28.316957854791458
# Feature: R_losses Score: -26.782874304343196
# Feature: R_total_rounds_fought Score: -23.13382404123437
# Feature: R_total_title_bouts Score: -28.70335399801807
# Feature: R_win_by_Decision_Majority Score: -26.13869958629704
# Feature: R_win_by_Decision_Split Score: -24.215878142898614
# Feature: R_win_by_Decision_Unanimous Score: -24.172430483924973
# Feature: R_win_by_KO/TKO Score: -23.87746195545482
# Feature: R_win_by_Submission Score: -24.572976039772552
# Feature: R_win_by_TKO_Doctor_Stoppage Score: -25.242014356774444
# Feature: R_wins Score: -23.73754849178514
# Feature: R_Stance Score: -25.880104234944117
# Feature: R_Height_cms Score: -24.62673281361436
# Feature: R_Reach_cms Score: -25.809584657154996
# Feature: R_Weight_lbs Score: -23.767805946070208
# Feature: R_age Score: -25.43703693784549
# Feature: B_age Score: -23.181267886405376
# Feature: lose_streak_dif Score: -29.835210783194338
# Feature: win_streak_dif Score: -23.369772096249648
# Feature: longest_win_streak_dif Score: -26.928249277581564
# Feature: win_dif Score: -22.67280106454482
# Feature: loss_dif Score: -26.788129412802903
# Feature: total_round_dif Score: -23.21684793463625
# Feature: total_title_bout_dif Score: -23.335050669724478
# Feature: ko_dif Score: -22.256952035946085
# Feature: sub_dif Score: -23.95655523515735
# Feature: height_dif Score: -23.77005256728099
# Feature: reach_dif Score: -22.454534506519643
# Feature: age_dif Score: -21.33119716402536
# Feature: sig_str_dif Score: -27.283603394772193
# Feature: avg_sub_att_dif Score: -23.009084489544716
# Feature: avg_td_dif Score: -22.362645434884772
# Feature: empty_arena Score: -24.42129327984901
# The best feature was B_ev.  It scored 9.989235671762625
# Current best score is: 9.989235671762625
# Feature: R_fighter Score: -17.97586505755885
# Feature: B_fighter Score: -14.937285399030875
# Feature: R_odds Score: -6.5409290446059885
# Feature: B_odds Score: -3.402834299067669
# Feature: R_ev Score: 24.088882962028965
# D:\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# D:\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Feature: location Score: 10.798810110499991
# D:\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# D:\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# D:\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# D:\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# D:\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Feature: country Score: -2.450333154524963
# Feature: title_bout Score: 1.7810558333393027
# D:\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Feature: weight_class Score: -10.753273257394769
# Feature: gender Score: 11.181130263267935
# Feature: no_of_rounds Score: 7.116733470895368
# Feature: B_current_lose_streak Score: 0.480887459978695
# Feature: B_current_win_streak Score: 2.014494818788902
# Feature: B_draw Score: 8.465522217438439
# Feature: B_avg_SIG_STR_landed Score: -0.22558484529902145
# Feature: B_avg_SIG_STR_pct Score: 6.637745991183944
# Feature: B_avg_SUB_ATT Score: 5.136381559454265
# Feature: B_avg_TD_landed Score: 11.538110220645851
# Feature: B_avg_TD_pct Score: 9.630378259786344
# Feature: B_longest_win_streak Score: 8.006606588274073
# D:\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Feature: B_current_lose_streak Score: 21.682475048650616
# Feature: B_current_win_streak Score: 15.052789878537624
# Feature: B_avg_SIG_STR_landed Score: 0.43870642956661854
# Feature: B_avg_SIG_STR_pct Score: 3.6069950545522804
# Feature: B_avg_SUB_ATT Score: -5.95652485018739
# Feature: B_avg_TD_landed Score: 5.635733244735776
# Feature: B_avg_TD_pct Score: 5.1548889707569
# D:\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Feature: B_losses Score: 22.42746724636784
# Feature: B_total_rounds_fought Score: 22.88568932396877
# D:\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Feature: B_total_title_bouts Score: 18.85114701046364
# Feature: B_win_by_Decision_Majority Score: 24.90257169329595
# D:\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Feature: B_win_by_Decision_Split Score: 25.772241812155812
# D:\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Feature: B_win_by_Decision_Unanimous Score: 16.44265476272469
# D:\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Feature: B_win_by_KO/TKO Score: 22.457585163390704
# D:\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Feature: B_win_by_Submission Score: 21.967865256891244
# Feature: B_win_by_TKO_Doctor_Stoppage Score: 26.997696563009573
# Feature: B_wins Score: 18.224210245961032
# Feature: B_Stance Score: 20.89808898350013
# Feature: B_Height_cms Score: 25.15647464617809
# Feature: B_Reach_cms Score: 24.373815757855294
# Feature: B_Weight_lbs Score: 22.239335750889893
# D:\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Feature: R_current_lose_streak Score: 23.123802088689672
# Feature: R_current_win_streak Score: 22.1371209898427
# Feature: R_draw Score: 27.757255382562114
# Feature: R_avg_SIG_STR_landed Score: 6.4520677995598525
# Feature: R_avg_SIG_STR_pct Score: 12.600497709870673
# D:\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Feature: R_avg_SUB_ATT Score: 12.040469603632577
# Feature: R_avg_TD_landed Score: 13.722754227259365
# D:\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Feature: R_avg_TD_pct Score: 4.304776419277266
# Feature: R_longest_win_streak Score: 20.410843114286322
# D:\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Feature: R_losses Score: 22.93291715573346
# Feature: R_total_rounds_fought Score: 18.090730360199764
# Feature: R_total_title_bouts Score: 20.680824125712405
# Feature: R_win_by_Decision_Majority Score: 26.659188993159432
# Feature: R_win_by_Decision_Split Score: 20.741837302231858
# Feature: R_win_by_Decision_Unanimous Score: 21.429346622929693
# D:\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Feature: R_win_by_KO/TKO Score: 24.460965916602515
# Feature: R_win_by_Submission Score: 25.910607502120953
# Feature: R_win_by_TKO_Doctor_Stoppage Score: 24.435805166072534
# Feature: R_wins Score: 17.618291811860683
# D:\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Feature: R_Stance Score: 16.489377144787195
# Feature: R_Height_cms Score: 25.13682410081559
# Feature: R_Reach_cms Score: 24.078521628690886
# Feature: R_Weight_lbs Score: 26.391368364320655
# Feature: R_age Score: 21.973999182130456
# Feature: B_age Score: 25.818113620469013
# Feature: lose_streak_dif Score: 18.733986144651045
# Feature: win_streak_dif Score: 18.88208673602712
# Feature: longest_win_streak_dif Score: 20.93261665558426
# Feature: win_dif Score: 21.667067977440386
# Feature: loss_dif Score: 21.211460340767562
# Feature: total_title_bout_dif Score: 17.08959585895667
# Feature: ko_dif Score: 16.963313813023994
# D:\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Feature: sub_dif Score: 19.484529542909705
# Feature: height_dif Score: 22.761250514799112
# Feature: reach_dif Score: 19.95026383488789
# Feature: age_dif Score: 22.64830699691665
# D:\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Feature: sig_str_dif Score: 15.924475681873556
# Feature: avg_sub_att_dif Score: 14.15128894405349
# Feature: avg_td_dif Score: 20.587795179790852
# Feature: empty_arena Score: 30.50034217280308
# NO IMPROVEMENT
# FINAL BEST SCORE: 31.158123326360922
# ['B_draw', 'B_longest_win_streak', 'total_round_dif', 'R_ev', 'B_ev']

# %%
model_2 = DecisionTreeClassifier(random_state=75)
(get_best_features(my_pos_features, model_2, df_train, [], label_train, odds_train, True))
# Out:
# Current best score is: -100
# Feature: R_fighter Score: -12.359255573051662
# Feature: B_fighter Score: -9.506234185490857
# Feature: R_odds Score: -30.48964440616377
# Feature: B_odds Score: -23.735402291758316
# Feature: R_ev Score: -30.48964440616377
# Feature: B_ev Score: -23.735402291758316
# Feature: location Score: -18.419847335276092
# Feature: country Score: -18.403005110823894
# Feature: title_bout Score: -27.24151065686665
# Feature: weight_class Score: -27.391509271667292
# Feature: gender Score: -26.054925736138625
# Feature: no_of_rounds Score: -29.51557254815579
# Feature: B_current_lose_streak Score: -24.897844534155606
# Feature: B_current_win_streak Score: -25.247830375022673
# Feature: B_draw Score: -23.052064918509913
# Feature: B_avg_SIG_STR_landed Score: -11.986200607911503
# Feature: B_avg_SIG_STR_pct Score: -28.010063387342992
# Feature: B_avg_SUB_ATT Score: -24.75124763812522
# Feature: B_avg_TD_landed Score: -15.95157696635745
# Feature: B_avg_TD_pct Score: -1.2167213608852645
# Feature: B_longest_win_streak Score: -22.481023583410764
# Feature: B_losses Score: -25.254885615771954
# Feature: B_total_rounds_fought Score: -18.706055776351185
# Feature: B_total_title_bouts Score: -22.357520977537746
# Feature: B_win_by_Decision_Majority Score: -24.30676650643244
# Feature: B_win_by_Decision_Split Score: -21.512370197919104
# Feature: B_win_by_Decision_Unanimous Score: -23.77974335817211
# Feature: B_win_by_KO/TKO Score: -21.601069433525755
# Feature: B_win_by_Submission Score: -23.8943595259806
# Feature: B_win_by_TKO_Doctor_Stoppage Score: -23.385883321530564
# Feature: B_wins Score: -21.107063748408702
# Feature: B_Stance Score: -27.892655281857824
# Feature: B_Height_cms Score: -24.48599844512468
# Feature: B_Reach_cms Score: -27.811422196638034
# Feature: B_Weight_lbs Score: -25.438042626651715
# Feature: R_current_lose_streak Score: -28.326562847457364
# Feature: R_current_win_streak Score: -26.77467010750177
# Feature: R_draw Score: -23.38214266364946
# Feature: R_avg_SIG_STR_landed Score: -25.95873371801891
# Feature: R_avg_SIG_STR_pct Score: -30.685534040187846
# Feature: R_avg_SUB_ATT Score: -24.997753218808555
# Feature: R_avg_TD_landed Score: -16.91185260141281
# Feature: R_avg_TD_pct Score: -9.568062607930852
# Feature: R_longest_win_streak Score: -30.123847456132545
# Feature: R_losses Score: -30.22321188379467
# Feature: R_total_rounds_fought Score: -24.2730168103969
# Feature: R_total_title_bouts Score: -26.43523450655042
# Feature: R_win_by_Decision_Majority Score: -25.6905490845797
# Feature: R_win_by_Decision_Split Score: -25.529078954958226
# Feature: R_win_by_Decision_Unanimous Score: -29.500643683935586
# Feature: R_win_by_KO/TKO Score: -29.17751438473979
# Feature: R_win_by_Submission Score: -26.868959242656683
# Feature: R_win_by_TKO_Doctor_Stoppage Score: -24.250331567911996
# Feature: R_wins Score: -23.39711651095339
# Feature: R_Stance Score: -25.78621592287435
# Feature: R_Height_cms Score: -26.357775538945972
# Feature: R_Reach_cms Score: -26.518846447780156
# Feature: R_Weight_lbs Score: -25.247538307113974
# Feature: R_age Score: -30.742053526477147
# Feature: B_age Score: -21.718845469453772
# Feature: lose_streak_dif Score: -31.04410105296774
# Feature: win_streak_dif Score: -25.207286344661817
# Feature: longest_win_streak_dif Score: -33.587149206577436
# Feature: win_dif Score: -29.910940751670626
# Feature: loss_dif Score: -26.11545638625442
# Feature: total_round_dif Score: -27.329840299551144
# Feature: total_title_bout_dif Score: -20.563951510349035
# Feature: ko_dif Score: -27.723426659504682
# Feature: sub_dif Score: -28.131031381374708
# Feature: height_dif Score: -30.074586637299227
# Feature: reach_dif Score: -18.773791883987624
# Feature: age_dif Score: -19.202492401540226
# Feature: sig_str_dif Score: -11.256123402725766
# Feature: avg_sub_att_dif Score: -30.49006529689552
# Feature: avg_td_dif Score: -12.685660294399769
# Feature: empty_arena Score: -24.49822934523802
# The best feature was B_avg_TD_pct.  It scored -1.2167213608852645
# Current best score is: -1.2167213608852645
# Feature: R_fighter Score: -20.284887471592317
# Feature: B_fighter Score: 21.701252139422078
# Feature: R_odds Score: -10.354120841804843
# Feature: B_odds Score: -4.81256352073756
# Feature: R_ev Score: -10.18205465086154
# Feature: B_ev Score: -5.4541135302553405
# Feature: location Score: -0.501027452972993
# Feature: country Score: 5.386214520777392
# Feature: title_bout Score: -6.8392896950291275
# Feature: weight_class Score: -14.221164400122182
# Feature: gender Score: -3.8320269741233464
# Feature: no_of_rounds Score: -2.3106592780413653
# Feature: B_current_lose_streak Score: 0.7270277622880806
# Feature: B_current_win_streak Score: -5.5932531992549706
# Feature: B_draw Score: -0.6640057227996214
# Feature: B_avg_SIG_STR_landed Score: -1.9431596553814598
# Feature: B_avg_SIG_STR_pct Score: -9.163941603444805
# Feature: B_avg_SUB_ATT Score: -11.97137607466116
# Feature: B_avg_TD_landed Score: -1.3748702248263474
# Feature: B_longest_win_streak Score: -6.954512416168225
# Feature: B_losses Score: -2.739816671112421
# Feature: B_total_rounds_fought Score: -20.868380015379667
# Feature: B_total_title_bouts Score: 6.656382451002045
# Feature: B_win_by_Decision_Majority Score: -2.4277795092685617
# Feature: B_win_by_Decision_Split Score: 2.8498208383894106
# Feature: B_win_by_Decision_Unanimous Score: -3.968378215783366
# Feature: B_win_by_KO/TKO Score: -1.956315323552766
# Feature: B_win_by_Submission Score: -7.542203332156422
# Feature: B_win_by_TKO_Doctor_Stoppage Score: -1.4317603654908417
# Feature: B_wins Score: -2.1764898444927345
# Feature: B_Stance Score: -8.381827517947265
# Feature: B_Height_cms Score: -9.377828470836434
# Feature: B_Reach_cms Score: -2.7441803715609545
# Feature: B_Weight_lbs Score: -13.661166043999756
# Feature: R_current_lose_streak Score: -11.281172894079674
# Feature: R_current_win_streak Score: -7.516259416105893
# Feature: R_draw Score: 0.468219501213766
# Feature: R_avg_SIG_STR_landed Score: -11.831309424713206
# Feature: R_avg_SIG_STR_pct Score: -4.018364857720665
# Feature: R_avg_SUB_ATT Score: -18.87815997096613
# Feature: R_avg_TD_landed Score: -5.518703304437903
# Feature: R_avg_TD_pct Score: -17.342576088879454
# Feature: R_longest_win_streak Score: 1.28808069821882
# Feature: R_losses Score: -2.5318182919359558
# Feature: R_total_rounds_fought Score: -7.081167762966561
# Feature: R_total_title_bouts Score: -24.46454618144778
# Feature: R_win_by_Decision_Majority Score: -0.43227154963752934
# Feature: R_win_by_Decision_Split Score: -19.026476653762266
# Feature: R_win_by_Decision_Unanimous Score: -5.0278188126483725
# Feature: R_win_by_KO/TKO Score: 1.1904569035586858
# Feature: R_win_by_Submission Score: 4.231871943320778
# Feature: R_win_by_TKO_Doctor_Stoppage Score:
# Feature: B_win_by_TKO_Doctor_Stoppage Score: 21.972639108950016
# Feature: B_wins Score: 3.4361081480286937
# Feature: B_Stance Score: 22.401083822500944
# Feature: B_Height_cms Score: 7.4073616314808595
# Feature: B_Reach_cms Score: 4.518652364076223
# Feature: B_Weight_lbs Score: 10.069549409277858
# Feature: R_current_lose_streak Score: -4.424794299705367
# Feature: R_current_win_streak Score: 4.1491304750008045
# Feature: R_draw Score: 21.031473895520104
# Feature: R_avg_SIG_STR_landed Score: 10.768958906113504
# Feature: R_avg_SIG_STR_pct Score: 12.161903635874635
# Feature: R_avg_SUB_ATT Score: -9.796635065154296
# Feature: R_avg_TD_landed Score: 14.83410917338995
# Feature: R_avg_TD_pct Score: -4.544000328471841
# Feature: R_longest_win_streak Score: 13.38183159825895
# Feature: R_losses Score: 11.753684486822149
# Feature: R_total_rounds_fought Score: -9.713242933072051
# Feature: R_total_title_bouts Score: 1.9503241979923054
# Feature: R_win_by_Decision_Majority Score: 19.473409539457233
# Feature: R_win_by_Decision_Split Score: 2.497414668766413
# Feature: R_win_by_Decision_Unanimous Score: 0.6290899264161469
# Feature: R_win_by_KO/TKO Score: 8.671018144813484
# Feature: R_win_by_Submission Score: 18.306624399166378
# Feature: R_win_by_TKO_Doctor_Stoppage Score: 23.525672967243374
# Feature: R_wins Score: 0.3503506371340521
# Feature: R_Height_cms Score: 6.5200160681798796
# Feature: R_Reach_cms Score: 20.450722547857733
# Feature: R_Weight_lbs Score: 11.095505328177047
# Feature: R_age Score: -0.4806148480245689
# Feature: B_age Score: 10.874484851454483
# Feature: lose_streak_dif Score: 4.019944906219404
# Feature: win_streak_dif Score: 14.832275108639482
# Feature: longest_win_streak_dif Score: -0.512468444415207
# Feature: win_dif Score: 2.575099148743122
# Feature: loss_dif Score: 9.966450155467278
# Feature: total_round_dif Score: -15.195108996457268
# Feature: total_title_bout_dif Score: 5.0314206857910495
# Feature: ko_dif Score: 9.182531901228936
# Feature: sub_dif Score: 9.91049913591971
# Feature: height_dif Score: 12.347796135982048
# Feature: reach_dif Score: 7.752311401333349
# Feature: age_dif Score: 5.415465646549449
# Feature: sig_str_dif Score: -8.1058323071755
# Feature: avg_sub_att_dif Score: -0.5643167228984721
# Feature: avg_td_dif Score: 8.589459766038956
# Feature: empty_arena Score: 20.584251412572517
# NO IMPROVEMENT
# FINAL BEST SCORE: 28.731138996088998
# ['R_Stance', 'B_fighter', 'B_avg_TD_pct']

# %%
model_3 = RandomForestClassifier(random_state=75)
(get_best_features(my_pos_features, model_3, df_train, [], label_train, odds_train, True))
# Out:
# Current best score is: -100
# Feature: R_fighter Score: -31.764793166121848
# Feature: B_fighter Score: 0.7197311658623571
# Feature: R_odds Score: -28.379408874251624
# Feature: B_odds Score: -24.034549233468184
# Feature: R_ev Score: -28.379408874251624
# Feature: B_ev Score: -23.883836699188805
# Feature: location Score: -18.59228748140632
# Feature: country Score: -18.139037231606686
# Feature: title_bout Score: -25.589058200226646
# Feature: weight_class Score: -26.481946432780873
# Feature: gender Score: -26.25545210080947
# Feature: no_of_rounds Score: -30.08455109573676
# Feature: B_current_lose_streak Score: -24.5753198013967
# Feature: B_current_win_streak Score: -25.6196856762303
# Feature: B_draw Score: -22.725890421865618
# Feature: B_avg_SIG_STR_landed Score: -11.995412998298047
# Feature: B_avg_SIG_STR_pct Score: -28.628300191341545
# Feature: B_avg_SUB_ATT Score: -25.973947359506457
# Feature: B_avg_TD_landed Score: -16.088001782832155
# Feature: B_avg_TD_pct Score: -4.250507519902718
# Feature: B_longest_win_streak Score: -22.675009257104985
# Feature: B_losses Score: -25.626453104041936
# Feature: B_total_rounds_fought Score: -18.854195796428144
# Feature: B_total_title_bouts Score: -21.525234815679283
# Feature: B_win_by_Decision_Majority Score: -23.944587127497023
# Feature: B_win_by_Decision_Split Score: -20.242443836687166
# Feature: B_win_by_Decision_Unanimous Score: -23.318720156856568
# Feature: B_win_by_KO/TKO Score: -22.367714656297757
# Feature: B_win_by_Submission Score: -24.19307687457986
# Feature: B_win_by_TKO_Doctor_Stoppage Score: -23.010548200887133
# Feature: B_wins Score: -20.80205140909261
# Feature: B_Stance Score: -27.77461731989583
# Feature: B_Height_cms Score: -25.29465241544509
# Feature: B_Reach_cms Score: -29.16048216770092
# Feature: B_Weight_lbs Score: -25.0169188764643
# Feature: R_current_lose_streak Score: -29.49613658915892
# Feature: R_current_win_streak Score: -27.330986412435557
# Feature: R_draw Score: -23.152152737588374
# Feature: R_avg_SIG_STR_landed Score: -33.03661406529672
# Feature: R_avg_SIG_STR_pct Score: -27.87093375409333
# Feature: R_avg_SUB_ATT Score: -26.058807116388778
# Feature: R_avg_TD_landed Score: -18.4806122007086
# Feature: R_avg_TD_pct Score: -11.572830710000765
# Feature: R_longest_win_streak Score: -30.59095665618137
# Feature: R_losses Score: -30.256204368245943
# Feature: R_total_rounds_fought Score: -23.70938932337672
# Feature: R_total_title_bouts Score: -27.11833989761142
# Feature: R_win_by_Decision_Majority Score: -25.519346127590453
# Feature: R_win_by_Decision_Split Score: -25.52621269641485
# Feature: R_win_by_Decision_Unanimous Score: -29.292704197938
# Feature: R_win_by_KO/TKO Score: -29.4309451273555
# Feature: R_win_by_Submission Score: -27.39851097252308
# Feature: R_win_by_TKO_Doctor_Stoppage Score: -25.31786771021414
# Feature: R_wins Score: -25.443596614859636
# Feature: R_Stance Score: -25.619227407518427
# Feature: R_Height_cms Score: -26.520725709325905
# Feature: R_Reach_cms Score: -27.45567476835579
# Feature: R_Weight_lbs Score: -23.72634191228135
# Feature: R_age Score: -30.732675314143783
# Feature: B_age Score: -21.827489803836134
# Feature: lose_streak_dif Score: -30.8869554442442
# Feature: win_streak_dif Score: -25.433465110192735
# Feature: longest_win_streak_dif Score: -32.710560887365226
# Feature: win_dif Score: -30.142299035527323
# Feature: loss_dif Score: -26.671835840661885
# Feature: total_round_dif Score: -27.847602944466068
# Feature: total_title_bout_dif Score: -20.109343584040303
# Feature: ko_dif Score: -27.966144359722797
# Feature: sub_dif Score: -27.329907602823756
# Feature: height_dif Score: -31.055506532961015
# Feature: reach_dif Score: -19.09142943995287
# Feature: age_dif Score: -19.70686956032841
# Feature: sig_str_dif Score: -16.701702603374525
# Feature: avg_sub_att_dif Score: -33.431899919142815
# Feature: avg_td_dif Score: -16.07275916508658
# Feature: empty_arena Score: -24.64617080384637
# The best feature was B_fighter.  It scored 0.7197311658623571
# Current best score is: 0.7197311658623571
# Feature: R_fighter Score: 13.778426854019926
# Feature: R_odds Score: -2.1165599049927586
# Feature: B_odds Score: -0.2144499216184279
# Feature: R_ev Score: -1.3210908060232347
# Feature: B_ev Score: -0.4669885007325858
# Feature: location Score: 2.4314581881715664
# Feature: country Score: 2.188732842643365
# Feature: title_bout Score: 2.9825804638163658
# Feature: weight_class Score: 3.0188907671221785
# Feature: gender Score: 0.4901022251096707
# Feature: no_of_rounds Score: -1.4903998525949103
# Feature: B_current_lose_streak Score: 8.347504042627396
# Feature: B_current_win_streak Score: 9.929368929289515
# Feature: B_draw Score: -0.0268983289828979
# Feature: B_avg_SIG_STR_landed Score: 12.284409900436913
# Feature: B_avg_SIG_STR_pct Score: 19.942173149094977
# Feature: B_avg_SUB_ATT Score: 6.832437878408436
# Feature: B_avg_TD_landed Score: 1.1933580048893422
# Feature: B_avg_TD_pct Score: 17.135774242443688
# Feature: B_longest_win_streak Score: 3.774119238339316
# Feature: B_losses Score: 4.370025693919829
# Feature: B_total_rounds_fought Score: -4.331217851780185
# Feature: B_total_title_bouts Score: 3.602122240266477
# Feature: B_win_by_Decision_Majority Score: 0.020298976848240002
# Feature: B_win_by_Decision_Split Score: 0.8386795669636871
# Feature: B_win_by_Decision_Unanimous Score: -11.621637719692849
# Feature: B_win_by_KO/TKO Score: 3.452466876281294
# Feature: B_win_by_Submission Score: -0.20954351149002637
# Feature: B_win_by_TKO_Doctor_Stoppage Score: 0.46014427962012316
# Feature: B_wins Score: -9.103562595752551
# Feature: B_Stance Score: 0.34085839193850287
# Feature: B_Height_cms Score: 1.177859575544228
# Feature: B_Reach_cms Score: -1.848078075768632
# Feature: B_Weight_lbs Score: -1.0266562295911
# Feature: R_current_lose_streak Score: 14.774545468815994
# Feature: R_current_win_streak Score: 7.478971641746619
# Feature: R_draw Score: 0.8369694888161119
# Feature: R_avg_SIG_STR_landed Score: 9.281155930926651
# Feature: R_avg_SIG_STR_pct Score: -9.561711199641646
# Feature: R_avg_SUB_ATT Score: -0.19456265232618275
# Feature: R_avg_TD_landed Score: 2.216071782042704
# Feature: R_avg_TD_pct Score: 0.050928860461692205
# Feature: R_longest_win_streak Score: 5.250687152897464
# Feature: R_losses Score: 6.338612089553919
# Feature: R_total_rounds_fought Score: -7.206563159686447
# Feature: R_total_title_bouts Score: 6.721474884503827
# Feature: R_win_by_Decision_Majority Score: -0.03658265181250808
# Feature: R_win_by_Decision_Split Score: -6.188675364934861
# Feature: R_win_by_Decision_Unanimous Score: -6.988586601550448
# Feature: R_win_by_KO/TKO Score: -4.847083753339437
# Feature: R_win_by_Submission Score: 10.513470408021362
# Feature: R_win_by_TKO_Doctor_Stoppage Score:
# Feature: R_total_rounds_fought Score: -3.4015444678271827
# Feature: R_total_title_bouts Score: 16.99419006372542
# Feature: R_win_by_Decision_Majority Score: 16.94463988623757
# Feature: R_win_by_Decision_Split Score: 5.957872903560257
# Feature: R_win_by_Decision_Unanimous Score: 17.59649584688201
# Feature: R_win_by_KO/TKO Score: 5.479378301243748
# Feature: R_win_by_Submission Score: 15.959820262501431
# Feature: R_win_by_TKO_Doctor_Stoppage Score: 21.952096663459727
# Feature: R_wins Score: -0.5748110860745349
# Feature: R_Stance Score: 12.865698841200416
# Feature: R_Height_cms Score: 3.1021807305917273
# Feature: R_Reach_cms Score: 14.670870660606347
# Feature: R_Weight_lbs Score: 14.081798417646743
# Feature: R_age Score: 15.788687517846839
# Feature: B_age Score: 19.211163580551975
# Feature: lose_streak_dif Score: 13.880542415447058
# Feature: win_streak_dif Score: 7.288869438295479
# Feature: longest_win_streak_dif Score: 8.58992773916451
# Feature: win_dif Score: 3.811516244992891
# Feature: loss_dif Score: 5.257370214382007
# Feature: total_round_dif Score: 3.8327681280355144
# Feature: total_title_bout_dif Score: 14.9980003080162
# Feature: ko_dif Score: 17.184972153341945
# Feature: sub_dif Score: 8.7833059314271
# Feature: height_dif Score: 7.785052558184598
# Feature: reach_dif Score: 13.319871633006874
# Feature: age_dif Score: 10.852348212597748
# Feature: sig_str_dif Score: 7.1567215499909
# Feature: avg_sub_att_dif Score: 2.471352111460043
# Feature: avg_td_dif Score: 4.234997954231771
# Feature: empty_arena Score: 16.78664194447493
# The best feature was B_total_title_bouts.  It scored 24.622936979632385
# Current best score is: 24.622936979632385
# Feature: R_fighter Score: 1.1610126358714137
# Feature: R_odds Score: 6.218524298614771
# Feature: B_odds Score: 6.2543059006984425
# Feature: R_ev Score: 7.492861022168118
# Feature: B_ev Score: 6.804681570694818
# Feature: location Score: 19.175266546844377
# Feature: country Score: 7.5884957919496845
# Feature: title_bout Score: 13.876271818405815
# Feature: weight_class Score: 6.257874654685102
# Feature: gender Score: 19.036768162677483
# Feature: no_of_rounds Score: 13.956551529891625
# Feature: B_current_lose_streak Score: 33.11951036936883
# Feature: B_current_win_streak Score: 20.274516863027664
# Feature: B_draw Score: 21.562541720036002
# Feature: B_avg_SIG_STR_landed Score: 3.395314665540581
# Feature: B_avg_SUB_ATT Score: 11.410948316262585
# Feature: B_avg_TD_landed Score: -6.63004123295231
# Feature: B_avg_TD_pct Score: 5.022419837237795
# Feature: B_longest_win_streak Score: 8.30937724032829
# Feature: B_losses Score: 10.462286364562061
# Feature: B_total_rounds_fought Score: 8.975658433411935
# Feature: B_win_by_Decision_Majority Score: 22.370205918952955
# Feature: B_win_by_Decision_Split Score: 21.832306966517372
# Feature: B_win_by_Decision_Unanimous Score: 9.99813016529077
# Feature: B_win_by_KO/TKO Score: 16.23784726279416
# Feature: B_win_by_Submission Score: 13.43023672971639
# Feature: B_win_by_TKO_Doctor_Stoppage Score:
# Feature: B_win_by_TKO_Doctor_Stoppage Score: 27.825328241622593
# Feature: B_wins Score: 12.351431841578503
# Feature: B_Stance Score: 24.744104914076054
# Feature: B_Height_cms Score: 21.616841921332586
# Feature: B_Reach_cms Score: 15.420341624718155
# Feature: B_Weight_lbs Score: 23.907764516394664
# Feature: R_current_lose_streak Score: 17.998093067780808
# Feature: R_current_win_streak Score: 5.414904446967311
# Feature: R_draw Score: 27.486754952740334
# Feature: R_avg_SIG_STR_landed Score: 5.021469765803827
# Feature: R_avg_SIG_STR_pct Score: 2.6128607988645554
# Feature: R_avg_SUB_ATT Score: 16.44708266038666
# Feature: R_avg_TD_landed Score: 7.890183683951859
# Feature: R_avg_TD_pct Score: 9.31722635034292
# Feature: R_longest_win_streak Score: 7.708918466495282
# Feature: R_losses Score: 3.9144106620676906
# Feature: R_total_rounds_fought Score: 3.3842485436478946
# Feature: R_total_title_bouts Score: 21.717302637995704
# Feature: R_win_by_Decision_Majority Score: 26.717331925127834
# Feature: R_win_by_Decision_Split Score: 7.661370726292877
# Feature: R_win_by_Decision_Unanimous Score: 14.929516123803607
# Feature: R_win_by_KO/TKO Score: 15.599431386032752
# Feature: R_win_by_Submission Score: 16.898774281037227
# Feature: R_win_by_TKO_Doctor_Stoppage Score: 31.395347046556253
# Feature: R_wins Score: 7.649237457747627
# Feature: R_Stance Score: 12.014403952804333
# Feature: R_Height_cms Score: 14.736014622974391
# Feature: R_Reach_cms Score: 11.410595282985835
# Feature: R_Weight_lbs Score: 21.70381516811844
# Feature: R_age Score: 22.81872385718099
# Feature: B_age Score: 21.88675133879645
# Feature: lose_streak_dif Score: 21.42627497828019
# Feature: win_streak_dif Score: 10.90750893052365
# Feature: longest_win_streak_dif Score: 19.380217176854554
# Feature: win_dif Score: 10.546197563587237
# Feature: loss_dif Score: 8.72358840904102
# Feature: total_round_dif Score: 8.693132321863473
# Feature: total_title_bout_dif Score: 27.094492282928147
# Feature: ko_dif Score: 20.069548781303844
# Feature: sub_dif Score: 17.177396085244528
# Feature: height_dif Score: 12.298323989730157
# Feature: reach_dif Score: 13.747945276021035
# Feature: age_dif Score: 12.237478033196616
# Feature: sig_str_dif Score: -5.236664488474451
# Feature: avg_sub_att_dif Score: 7.774360417836158
# Feature: avg_td_dif Score: 2.8131712757589327
# Feature: empty_arena Score: 24.490248488671888
# NO IMPROVEMENT
# FINAL BEST SCORE: 33.11951036936883
# ['B_current_lose_streak',
#  'B_total_title_bouts',
#  'B_avg_SIG_STR_pct',
#  'B_fighter']

# %%
model_4 = GradientBoostingClassifier(random_state=75)
(get_best_features(my_pos_features, model_4, df_train, [], label_train, odds_train, True))
# Out:
# Current best score is: -100
# Feature: R_fighter Score: -22.69210856640455
# Feature: B_fighter Score: -27.862451751750516
# Feature: R_odds Score: -6.23681387751417
# Feature: B_odds Score: -13.124031008648391
# Feature: R_ev Score: -6.23681387751417
# Feature: B_ev Score: -13.289289235278567
# Feature: location Score: -22.845285323703806
# Feature: country Score: -19.850012322504163
# Feature: title_bout Score: -27.364581408981095
# Feature: weight_class Score: -26.86910284065578
# Feature: gender Score: -26.176509738245272
# Feature: no_of_rounds Score: -29.871072245531284
# Feature: B_current_lose_streak Score: -24.897844534155606
# Feature: B_current_win_streak Score: -25.379751937128223
# Feature: B_draw Score: -23.052064918509913
# Feature: B_avg_SIG_STR_landed Score: -17.67512479762405
# Feature: B_avg_SIG_STR_pct Score: -21.06110560347184
# Feature: B_avg_SUB_ATT Score: -25.513558366512953
# Feature: B_avg_TD_landed Score: -13.557915554757415
# Feature: B_avg_TD_pct Score: -19.075492036435172
# Feature: B_longest_win_streak Score: -23.109712318745956
# Feature: B_losses Score: -25.206797302395263
# Feature: B_total_rounds_fought Score: -19.54213708124384
# Feature: B_total_title_bouts Score: -22.357520977537746
# Feature: B_win_by_Decision_Majority Score: -24.30676650643244
# Feature: B_win_by_Decision_Split Score: -21.512370197919104
# Feature: B_win_by_Decision_Unanimous Score: -23.78794989155281
# Feature: B_win_by_KO/TKO Score: -21.601069433525755
# Feature: B_win_by_Submission Score: -23.774958274704222
# Feature: B_win_by_TKO_Doctor_Stoppage Score: -23.385883321530564
# Feature: B_wins Score: -20.318609698262872
# Feature: B_Stance Score: -27.892655281857824
# Feature: B_Height_cms Score: -25.440723229167464
# Feature: B_Reach_cms Score: -29.333124547003177
# Feature: B_Weight_lbs Score: -25.151023549408713
# Feature: R_current_lose_streak Score: -28.326562847457364
# Feature: R_current_win_streak Score: -26.533054228627236
# Feature: R_draw Score: -23.38214266364946
# Feature: R_avg_SIG_STR_landed Score: -28.39936157178825
# Feature: R_avg_SIG_STR_pct Score: -25.63698911655193
# Feature: R_avg_SUB_ATT Score: -25.190748301458033
# Feature: R_avg_TD_landed Score: -21.38459808088423
# Feature: R_avg_TD_pct Score: -13.310446887863279
# Feature: R_longest_win_streak Score: -30.000910632000505
# Feature: R_losses Score: -29.74899125689458
# Feature: R_total_rounds_fought Score: -21.033577223453314
# Feature: R_total_title_bouts Score: -26.566180203180647
# Feature: R_win_by_Decision_Majority Score: -25.86624127699633
# Feature: R_win_by_Decision_Split Score: -25.529078954958226
# Feature: R_win_by_Decision_Unanimous Score: -29.500643683935586
# Feature: R_win_by_KO/TKO Score: -29.04764567107533
# Feature: R_win_by_Submission Score: -26.618271492427212
# Feature: R_win_by_TKO_Doctor_Stoppage Score: -24.250331567911996
# Feature: R_wins Score: -22.178457778706495
# Feature: R_Stance Score: -25.78621592287435
# Feature: R_Height_cms Score: -26.331157074826546
# Feature: R_Reach_cms Score: -25.28634366845644
# Feature: R_Weight_lbs Score: -25.802781099094563
# Feature: R_age Score: -30.90551723794496
# Feature: B_age Score: -22.210077821364585
# Feature: lose_streak_dif Score: -30.90220920465169
# Feature: win_streak_dif Score: -25.266093087713422
# Feature: longest_win_streak_dif Score: -33.47526096174806
# Feature: win_dif Score: -28.543214898140793
# Feature: loss_dif Score: -26.17689995330776
# Feature: total_round_dif Score: -24.68094357777875
# Feature: total_title_bout_dif Score: -21.11482741531552
# Feature: ko_dif Score: -27.62700275934884
# Feature: sub_dif Score: -27.479031921583164
# Feature: height_dif Score: -30.469421774827396
# Feature: reach_dif Score: -18.592358216253217
# Feature: age_dif Score: -19.353191396014537
# Feature: sig_str_dif Score: -28.366584533144245
# Feature: avg_sub_att_dif Score: -26.85138621298542
# Feature: avg_td_dif Score: -22.291628259635747
# Feature: empty_arena Score: -24.49822934523802
# The best feature was R_odds.  It scored -6.23681387751417
# Current best score is: -6.23681387751417
# Feature: R_fighter Score: 2.2912480574664817
# Feature: B_fighter Score: 5.475271340886902
# Feature: B_odds Score: -11.09190056475702
# Feature: R_ev Score: -6.23681387751417
# Feature: B_ev Score: -11.09190056475702
# Feature: location Score: 13.788858713279307
# Feature: country Score: -1.6881472513291431
# Feature: title_bout Score: -6.5516282704035245
# Feature: weight_class Score: -3.6108409174447256
# Feature: gender Score: -7.892245823259966
# Feature: no_of_rounds Score: -3.992235784904737
# Feature: B_current_lose_streak Score: -0.9100916360897227
# Feature: B_current_win_streak Score: -2.0615280500741058
# Feature: B_draw Score: -5.888628196540331
# Feature: B_avg_SIG_STR_landed Score: -20.391605867818907
# Feature: B_avg_SIG_STR_pct Score: -3.2835232690933163
# Feature: B_avg_SUB_ATT Score: -23.140785919888895
# Feature: B_avg_TD_landed Score: 7.955656409522614
# Feature: B_avg_TD_pct Score: -15.223082470804147
# Feature: B_longest_win_streak Score: -5.397193782021871
# Feature: B_losses Score: -5.536356938701703
# Feature: B_total_rounds_fought Score: -5.616242499568402
# Feature: B_total_title_bouts Score: -5.931587445743412
# Feature: B_win_by_Decision_Majority Score: -9.247030915270528
# Feature: B_win_by_Decision_Split Score: -6.45757248160294
# Feature: B_win_by_Decision_Unanimous Score: -2.85146462236012
# Feature: B_win_by_KO/TKO Score: 0.4612160242435728
# Feature: B_win_by_Submission Score: -7.104227243672863
# Feature: B_win_by_TKO_Doctor_Stoppage Score: -7.490653328289087
# Feature: B_wins Score: 0.28458734502505356
# Feature: B_Stance Score: -3.9937935168915852
# Feature: B_Height_cms Score: -12.892590021830935
# Feature: B_Reach_cms Score: -9.874985850394816
# Feature: B_Weight_lbs Score: -5.19396206390803
# Feature: R_current_lose_streak Score: -2.37177861101471
# Feature: R_current_win_streak Score: -4.730934793936754
# Feature: R_draw Score: -3.7875888594559757
# Feature: R_avg_SIG_STR_landed Score: -6.54085484740512
# Feature: R_avg_SIG_STR_pct Score: -1.5041492727030672
# Feature: R_avg_SUB_ATT Score: -23.611687643263654
# Feature: R_avg_TD_landed Score: -5.088650360142061
# Feature: R_avg_TD_pct Score: 2.342983008500429
# Feature: R_longest_win_streak Score: -13.120183398038355
# Feature: R_losses Score: -3.8778077510284774
# Feature: R_total_rounds_fought Score: 6.599840782941024
# Feature: R_total_title_bouts Score: -4.476354744618098
# Feature: R_win_by_Decision_Majority Score: -5.658429737536672
# Feature: R_win_by_Decision_Split Score: 6.390849465017018
# Feature: R_win_by_Decision_Unanimous Score: -8.29671515619232
# Feature: R_win_by_KO/TKO Score: -3.4079970631105967
# Feature: R_win_by_Submission Score: -9.651772791479289
# Feature: R_win_by_TKO_Doctor_Stoppage Score: -4.129897986564825
# Feature: R_wins Score: -7.515783200396095
# Feature: R_Stance Score: -3.7029870155897635
# Feature: R_Height_cms Score: -12.1186477272038
# Feature: R_Reach_cms Score: -3.9413110053318587
# Feature: R_Weight_lbs Score: -4.8912672880949355
# Feature: R_age Score: -2.4081225813135023
# Feature: B_age Score: -8.957814113375644
# Feature: lose_streak_dif Score: -4.982873265539053
# Feature: win_streak_dif Score: -14.90115347701716
# Feature: longest_win_streak_dif Score: -11.011579692526645
# Feature: win_dif Score: 2.105334740568861
# Feature: loss_dif Score: 1.2702576977297042
# Feature: total_round_dif Score: 6.098600343132677
# Feature: total_title_bout_dif Score: -2.959796173747675
# Feature: ko_dif Score: -11.50248384639881
# Feature: sub_dif Score: -7.8155231391208035
# Feature: height_dif Score: -12.883037403360506
# Feature: reach_dif Score: -6.069843479239397
# Feature: age_dif Score: -3.496284320531072
# Feature: sig_str_dif Score: 9.228367578041063
# Feature: avg_sub_att_dif Score: -16.25912197468752
# Feature: avg_td_dif Score: 5.185449808556712
# Feature: empty_arena Score: -4.271623789342285
# The best feature was location.  It scored 13.788858713279307
# Current best score is: 13.788858713279307
# Feature: R_fighter Score: 2.5572967193171112
# Feature: B_fighter Score: 12.87268064318356
# Feature: B_odds Score: 6.250737276148179
# Feature: R_ev Score: 8.166213914532412
# Feature: B_ev Score: 5.745907893622326
# Feature: country Score: 12.817838396790325
# Feature: title_bout Score: 8.003453384925212
# Feature: weight_class Score: 5.224692550750504
# Feature: gender Score: 10.990655065683441
# Feature: no_of_rounds Score: 12.802209567157536
# Feature: B_current_lose_streak Score: 6.963589833152463
# Feature: B_current_win_streak Score: 5.732709053253512
# Feature: B_draw Score: 8.098517280318822
# Feature: B_avg_SIG_STR_landed Score: -3.9171190809963203
# Feature: B_avg_SIG_STR_pct Score: 4.436821409912705
# Feature: B_avg_SUB_ATT Score: -9.027939244351582
# Feature: B_avg_TD_landed Score: 16.819776136881597
# Feature: B_avg_TD_pct Score: -5.7473234981813555
# Feature: B_longest_win_streak Score: 15.46437301796006
# Feature: B_losses Score: 11.630008439386447
# Feature: B_total_rounds_fought Score: 15.198748031091187
# Feature: B_total_title_bouts Score: 8.837759984712473
# Feature: B_win_by_Decision_Majority Score: 9.321118112016107
# Feature: B_win_by_Decision_Split Score: 11.615301635295111
# Feature: B_win_by_Decision_Unanimous Score: 14.257015135188277
# Feature: B_win_by_KO/TKO Score: 16.90107212264303
# Feature: B_win_by_Submission Score: 10.656728727258653
# Feature: B_win_by_TKO_Doctor_Stoppage Score: 9.213484685713698
# Feature: B_wins Score: 13.895945420541564
# Feature: B_Stance Score: 6.410755207316244
# Feature: B_Height_cms Score: 11.5353695640324
# Feature: B_Reach_cms Score: 7.939285021758089
# Feature: B_Weight_lbs Score: 4.175924763177665
# Feature: R_current_lose_streak Score: 13.181842786738189
# Feature: R_current_win_streak Score: 13.75450735428931
# Feature: R_draw Score: 9.322788481307139
# Feature: R_avg_SIG_STR_landed Score: -0.934005932646905
# Feature: R_avg_SIG_STR_pct Score: 1.7456908157173
# Feature: R_avg_SUB_ATT Score: -0.38465098757231897
# Feature: R_avg_TD_landed Score: 9.378787329711372
# Feature: R_avg_TD_pct Score: 5.899996332192083
# Feature: R_longest_win_streak Score: 6.823865603487913
# Feature: R_losses Score: 11.34586068723653
# Feature: R_total_rounds_fought Score: 11.136290827432433
# Feature: R_total_title_bouts Score: 7.638751505252876
# Feature: R_win_by_Decision_Majority Score: 8.68713313574519
# Feature: R_win_by_Decision_Split Score: 8.686607096428052
# Feature: R_win_by_Decision_Unanimous Score: 5.185672101389316
# Feature: R_win_by_KO/TKO Score: 10.66123546576381
# Feature: R_win_by_Submission Score: 6.208020876646145
# Feature: R_win_by_TKO_Doctor_Stoppage Score: 7.434185407699971
# Feature: R_wins Score: 7.3860101260279425
# Feature: R_Stance Score: 8.519471736149665
# Feature: R_Height_cms Score: 13.811349012164328
# Feature: R_Reach_cms Score: 9.1911889967045
# Feature: R_Weight_lbs Score: 11.072055027706277
# Feature: R_age Score: 16.004989558428974
# Feature: B_age Score: 16.735580035410607
# Feature: lose_streak_dif Score: 8.23553653614369
# Feature: win_streak_dif Score: 11.266067307905967
# Feature: longest_win_streak_dif Score: 6.962222374153828
# Feature: win_dif Score: 12.808420630301896
# Feature: loss_dif Score: 12.09992360631293
# Feature: total_round_dif Score: 17.905814141639325
# Feature: total_title_bout_dif Score: 16.28987459639447
# Feature: ko_dif Score: 8.40650682381628
# Feature: sub_dif Score: 10.044415794071398
# Feature: height_dif Score: 1.5483441745944457
# Feature: reach_dif Score: 16.622117272597748
# Feature: age_dif Score: 13.772214965037275
# Feature: sig_str_dif Score: 12.726918647247619
# Feature: avg_sub_att_dif Score: 13.672408912390964
# Feature: avg_td_dif Score: 10.848135741045398
# Feature: empty_arena Score: 5.500671449988849
# The best feature was total_round_dif.  It scored 17.905814141639325
# Current best score is: 17.905814141639325
# Feature: R_fighter Score: 7.0690882037027505
# Feature: B_fighter Score: 8.184373757140202
# Feature: B_odds Score: 15.558982388310046
# Feature: R_ev Score: 18.7686204932574
# Feature: B_ev Score: 15.248576094130932
# Feature: country Score: 18.774829717199864
# Feature: title_bout Score: 15.874146890861631
# Feature: weight_class Score: 14.272560883131796
# Feature: gender Score: 22.3854444574768
# Feature: no_of_rounds Score: 18.160440173954917
# Feature: B_current_lose_streak Score: 20.732488276918716
# Feature: B_current_win_streak Score: 18.648544181329186
# Feature: B_draw Score: 17.97230899760205
# Feature: B_avg_SIG_STR_landed Score: 0.35889645977182916
# Feature: B_avg_SIG_STR_pct Score: 18.504962841528883
# Feature: B_avg_SUB_ATT Score: -11.040553428092883
# Feature: B_avg_TD_landed Score: 9.698093173165889
# Feature: B_avg_TD_pct Score: -10.797672689329408
# Feature: B_longest_win_streak Score: 11.319922269872073
# Feature: B_losses Score: 16.416597099007028
# Feature: B_total_rounds_fought Score: 25.57415008340652
# Feature: B_total_title_bouts Score: 10.512965737788532
# Feature: B_win_by_Decision_Majority Score: 16.833096767810467
# Feature: B_win_by_Decision_Split Score: 15.242675540583242
# Feature: B_win_by_Decision_Unanimous Score: 11.997338802493347
# Feature: B_win_by_KO/TKO Score: 16.949871062013777
# Feature: B_win_by_Submission Score: 14.76016096999182
# Feature: B_win_by_TKO_Doctor_Stoppage Score: 17.000775188959523
# Feature: B_wins Score: 17.610655420078746
# Feature: B_Stance Score: 14.685763802863475
# Feature: B_Height_cms Score: 16.4568746654303
# Feature: B_Reach_cms Score: 15.417305606640731
# Feature: B_Weight_lbs Score: 13.469781795351409
# Feature: R_current_lose_streak Score: 17.041607230869857
# Feature: R_current_win_streak Score: 14.22839823470131
# Feature: R_draw Score: 19.224390281767924
# Feature: R_avg_SIG_STR_landed Score: 3.3091744176069366
# Feature: R_avg_SIG_STR_pct Score: 7.092778252506303
# Feature: R_avg_SUB_ATT Score: 4.788634997930897
# Feature: R_avg_TD_landed Score: 8.07107474310526
# Feature: R_avg_TD_pct Score: -5.694498844372829
# Feature: R_longest_win_streak Score: 9.725259969962229
# Feature: R_losses Score: 10.641630431817706
# Feature: R_total_rounds_fought Score: 10.542601086073642
# Feature: R_total_title_bouts Score: 12.861925215415061
# Feature: R_win_by_Decision_Majority Score: 15.368105440788508
# Feature: R_win_by_Decision_Split Score: 23.80314814472559
# Feature: R_win_by_Decision_Unanimous Score: 14.631177250743491
# Feature: R_win_by_KO/TKO Score: 16.483083123596288
# Feature: R_win_by_Submission Score: 14.193304008751046
# Feature: R_win_by_TKO_Doctor_Stoppage Score: 15.278287989696771
# Feature: R_wins Score: 9.029525788893153
# Feature: R_Stance Score: 17.221301583923516
# Feature: R_Height_cms Score: 16.157563923220348
# Feature: R_Reach_cms Score: 13.766781621064363
# Feature: R_Weight_lbs Score: 13.78209735123959
# Feature: R_age Score: 20.56238374307466
# Feature: B_age Score: 23.549248119765142
# Feature: lose_streak_dif Score: 6.672776354554195
# Feature: win_streak_dif Score: 20.35248574074698
# Feature: longest_win_streak_dif Score: 13.194900114587506
# Feature: win_dif Score: 18.50540073134991
# Feature: loss_dif Score: 15.336203046164973
# Feature: total_title_bout_dif Score: 18.485880472673013
# Feature: ko_dif Score: 14.009336596710313
# Feature: sub_dif Score: 12.815605623662599
# Feature: height_dif Score: 8.149425961981619
# Feature: reach_dif Score: 18.40387135159269
# Feature: age_dif Score: 14.303482138725862
# Feature: sig_str_dif Score: 15.954978350397845
# Feature: avg_sub_att_dif Score: 9.789262917567621
# Feature: avg_td_dif Score: 16.78294369514284
# Feature: empty_arena Score: 17.762411754908157
# The best feature was B_total_rounds_fought.  It scored 25.57415008340652
# Current best score is: 25.57415008340652
# Feature: R_fighter Score: 7.306734766448676
# Feature: B_fighter Score: 11.251921661042593
# Feature: B_odds Score: 16.720300916937628
# Feature: R_ev Score: 21.591323615564928
# Feature: B_ev Score: 16.412786606865772
# Feature: country Score: 22.180455649688085
# Feature: title_bout Score: 14.819889602105217
# Feature: weight_class Score: 17.975815172143985
# Feature: gender Score: 16.81431855854209
# Feature: no_of_rounds Score: 19.427909912335082
# Feature: B_current_lose_streak Score: 18.033612820027365
# Feature: B_current_win_streak Score: 18.849380695371288
# Feature: B_draw Score: 19.27873060703182
# Feature: B_avg_SIG_STR_landed Score: 1.4057407920569291
# Feature: B_avg_SIG_STR_pct Score: 12.738112700127367
# Feature: B_avg_SUB_ATT Score: -9.146070761639535
# Feature: B_avg_TD_landed Score: 9.979913483711375
# Feature: B_avg_TD_pct Score: 3.935205528375542
# Feature: B_longest_win_streak Score: 11.238273107081998
# Feature: B_losses Score: 18.77074438441003
# Feature: B_total_title_bouts Score: 17.0612447528
# Feature: B_win_by_Decision_Majority Score: 19.93316804161816
# Feature: B_win_by_Decision_Split Score: 19.582204272833607
# Feature: B_win_by_Decision_Unanimous Score: 22.55823710625762
# Feature: B_win_by_KO/TKO Score: 21.021783424498828
# Feature: B_win_by_Submission Score: 12.528386956090198
# Feature: B_win_by_TKO_Doctor_Stoppage Score: 17.171829957471125
# Feature: B_wins Score: 20.540345472341446
# Feature: B_Stance Score: 19.345162212117327
# Feature: B_Height_cms Score: 17.32807546049016
# Feature: B_Reach_cms Score: 15.510850484752911
# Feature: B_Weight_lbs Score: 13.32117982293897
# Feature: R_current_lose_streak Score: 20.976795611009234
# Feature: R_current_win_streak Score: 17.025937059042572
# Feature: R_draw Score: 21.805066090141406
# Feature: R_avg_SIG_STR_landed Score: 7.517850548821588
# Feature: R_avg_SIG_STR_pct Score: 6.879025040587423
# Feature: R_avg_SUB_ATT Score: 3.4750219366446973
# Feature: R_avg_TD_landed Score: 10.066433558898229
# Feature: R_avg_TD_pct Score: 0.42370439028441487
# Feature: R_longest_win_streak Score: 15.002607278139735
# Feature: R_losses Score: 16.325699019496973
# Feature: R_total_rounds_fought Score: 19.779727707416374
# Feature: R_total_title_bouts Score: 20.248056971522125
# Feature: R_win_by_Decision_Majority Score: 18.290734333509306
# Feature: R_win_by_Decision_Split Score: 24.00217822423675
# Feature: R_win_by_Decision_Unanimous Score: 23.511640958646886
# Feature: R_win_by_KO/TKO Score: 19.090641275334004
# Feature: R_win_by_Submission Score: 15.628248068528636
# Feature: R_win_by_TKO_Doctor_Stoppage Score: 19.34469087451896
# Feature: R_wins Score: 15.72308163003864
# Feature: R_Stance Score: 15.55698737772339
# Feature: R_Height_cms Score: 11.382928433677474
# Feature: R_Reach_cms Score: 15.996192209614573
# Feature: R_Weight_lbs Score: 19.573415273903077
# Feature: R_age Score: 21.198498078188802
# Feature: B_age Score: 24.468925573871587
# Feature: lose_streak_dif Score: 15.719532383810424
# Feature: win_streak_dif Score: 20.72788264210986
# Feature: longest_win_streak_dif Score: 13.669315228602327
# Feature: win_dif Score: 21.31643026996453
# Feature: loss_dif Score: 11.195735494901584
# Feature: total_title_bout_dif Score: 18.160666929246357
# Feature: ko_dif Score: 17.42198340106799
# Feature: sub_dif Score: 16.57433305268309
# Feature: height_dif Score: 15.34281787456939
# Feature: reach_dif Score: 20.682215867382375
# Feature: age_dif Score: 20.317906812311573
# Feature: sig_str_dif Score: 20.459831928406434
# Feature: avg_sub_att_dif Score: 10.200079232043189
# Feature: avg_td_dif Score: 20.431851793879876
# Feature: empty_arena Score: 18.59893815594823
# NO IMPROVEMENT
# FINAL BEST SCORE: 25.57415008340652
# ['B_total_rounds_fought', 'total_round_dif', 'location', 'R_odds']

# %%
model_5 = GaussianNB()
(get_best_features(my_pos_features, model_5, df_train, [], label_train, odds_train, True))
# Out:
# Current best score is: -100
# Feature: R_fighter Score: -7.892941018696922
# Feature: B_fighter Score: -25.895227628351762
# Feature: R_odds Score: -25.60384466243959
# Feature: B_odds Score: -21.99556200828551
# Feature: R_ev Score: -25.827296838862996
# Feature: B_ev Score: -9.466004228965526
# Feature: location Score: -19.98714496868996
# Feature: country Score: -7.973765423487571
# Feature: title_bout Score: -26.755978565349167
# Feature: weight_class Score: -35.15736992211416
# Feature: gender Score: -22.7385583684478
# Feature: no_of_rounds Score: -26.833854664143352
# Feature: B_current_lose_streak Score: -22.63043654715411
# Feature: B_current_win_streak Score: -23.654386497604428
# Feature: B_draw Score: -28.225015174453212
# Feature: B_avg_SIG_STR_landed Score: -16.09517333582492
# Feature: B_avg_SIG_STR_pct Score: -16.622059181271265
# Feature: B_avg_SUB_ATT Score: -15.907678421493351
# Feature: B_avg_TD_landed Score: -19.93565293969655
# Feature: B_avg_TD_pct Score: -16.251015499406535
# Feature: B_longest_win_streak Score: -20.779616634887113
# Feature: B_losses Score: -21.44215006695903
# Feature: B_total_rounds_fought Score: -18.016237263090257
# Feature: B_total_title_bouts Score: -27.212985743515578
# Feature: B_win_by_Decision_Majority Score: -23.041673340074805
# Feature: B_win_by_Decision_Split Score: -17.461252351006824
# Feature: B_win_by_Decision_Unanimous Score: -24.128253773527398
# Feature: B_win_by_KO/TKO Score: -25.922798143059055
# Feature: B_win_by_Submission Score: -24.953629057868923
# Feature: B_win_by_TKO_Doctor_Stoppage Score: -23.464981237778147
# Feature: B_wins Score: -19.872242000740524
# Feature: B_Stance Score: 6.486611632455985
# Feature: B_Height_cms Score: -26.120332461247482
# Feature: B_Reach_cms Score: -23.835086466410882
# Feature: B_Weight_lbs Score: -28.307665332474638
# Feature: R_current_lose_streak Score: -34.65908310048698
# Feature: R_current_win_streak Score: -27.653411904828925
# Feature: R_draw Score: -26.165306044398573
# Feature: R_avg_SIG_STR_landed Score: -22.23184539606241
# Feature: R_avg_SIG_STR_pct Score: -25.28221723455718
# Feature: R_avg_SUB_ATT Score: -20.29817833116295
# Feature: R_avg_TD_landed Score: -12.881113376527399
# Feature: R_avg_TD_pct Score: -22.684457323538098
# Feature: R_longest_win_streak Score: -27.497694418218135
# Feature: R_losses Score: -33.37061313051418
# Feature: R_total_rounds_fought Score: -26.010309682198095
# Feature: R_total_title_bouts Score: -25.86465970335195
# Feature: R_win_by_Decision_Majority Score: -28.95632003134144
# Feature: R_win_by_Decision_Split Score: -27.488276173208952
# Feature: R_win_by_Decision_Unanimous Score: -25.65081873917579
# Feature: R_win_by_KO/TKO Score: -25.15668934576118
# Feature: R_win_by_Submission Score: -27.05779859344338
# Feature: R_win_by_TKO_Doctor_Stoppage Score: -27.481246132257102
# Feature: R_wins Score: -24.100838294697798
# Feature: R_Stance Score: 7.622102265073403
# Feature: R_Height_cms Score: -29.193815681330673
# Feature: R_Reach_cms Score: -28.411771067307868
# Feature: R_Weight_lbs Score: -26.322113850423918
# Feature: R_age Score: -24.878746953291806
# Feature: B_age Score: -20.480528881243444
# Feature: lose_streak_dif Score: -30.939147317494307
# Feature: win_streak_dif Score: -25.727736388762395
# Feature: longest_win_streak_dif Score: -24.87910109632557
# Feature: win_dif Score: -23.196474770983926
# Feature: loss_dif Score: -25.6798292229653
# Feature: total_round_dif Score: -26.03215243994129
# Feature: total_title_bout_dif Score: -22.467834199087726
# Feature: ko_dif Score: -27.653184638051453
# Feature: sub_dif Score: -25.32114860756987
# Feature: height_dif Score: -28.862659087501587
# Feature: reach_dif Score: -22.37821925057003
# Feature: age_dif Score: -22.5514683032059
# Feature: sig_str_dif Score: -26.894349731198254
# Feature: avg_sub_att_dif Score: -26.396742984021095
# Feature: avg_td_dif Score: -24.148935123830626
# Feature: empty_arena Score: -27.07925623688333
# The best feature was R_Stance.  It scored 7.622102265073403
# Current best score is: 7.622102265073403
# Feature: R_fighter Score: -8.67415146013944
# Feature: B_fighter Score: -25.895227628351762
# Feature: R_odds Score: 9.797892622569304
# Feature: B_odds Score: 0.766249540946843
# Feature: R_ev Score: 2.5727114222369307
# Feature: B_ev Score: 9.257097086330642
# Feature: location Score: -13.711207820592236
# Feature: country Score: 6.078488556003235
# Feature: title_bout Score: 6.424923460260092
# Feature: weight_class Score: 6.643555657746957
# Feature: gender Score: 7.482012242930953
# Feature: no_of_rounds Score: 8.065280825188267
# Feature: B_current_lose_streak Score: 8.301114062566398
# Feature: B_current_win_streak Score: 8.532231479925617
# Feature: B_draw Score: 7.843961518331211
# Feature: B_avg_SIG_STR_landed Score: 4.764752843111827
# Feature: B_avg_SIG_STR_pct Score: 2.9913316382576833
# Feature: B_avg_SUB_ATT Score: -3.943957024580476
# Feature: B_avg_TD_landed Score: 6.537580222784053
# Feature: B_avg_TD_pct Score: 3.939981838797137
# Feature: B_longest_win_streak Score: 7.345593417842796
# Feature: B_losses Score: 8.261784795636913
# Feature: B_total_rounds_fought Score: 8.384641458872945
# Feature: B_total_title_bouts Score: 6.9737165858422605
# Feature: B_win_by_Decision_Majority Score: 8.04961190310267
# Feature: B_win_by_Decision_Split Score: 7.037038492262282
# Feature: B_win_by_Decision_Unanimous Score: 7.741948451785644
# Feature: B_win_by_KO/TKO Score: 7.947385480796834
# Feature: B_win_by_Submission Score: 7.270298328658038
# Feature: B_win_by_TKO_Doctor_Stoppage Score: 7.907289261221029
# Feature: B_wins Score: 7.7885630700874895
# Feature: B_Stance Score: 6.486611632455985
# Feature: B_Height_cms Score: 7.08413207433161
# Feature: B_Reach_cms Score: 7.0589561200168545
# Feature: B_Weight_lbs Score: 8.133415380773425
# Feature: R_current_lose_streak Score: 4.8900343846342125
# Feature: R_current_win_streak Score: 6.7737180939654555
# Feature: R_draw Score: 5.563010735257465
# Feature: R_avg_SIG_STR_landed Score: -0.83186112029098
# Feature: R_avg_SIG_STR_pct Score: 1.5521363577439038
# Feature: R_avg_SUB_ATT Score: -0.627559379969659
# Feature: R_avg_TD_landed Score: -0.926641970209551
# Feature: R_avg_TD_pct Score: 1.1796259825625501
# Feature: R_longest_win_streak Score: 6.423674835215135
# Feature: R_losses Score: 4.457680343276833
# Feature: R_total_rounds_fought Score: 7.678647221529626
# Feature: R_total_title_bouts Score: 8.591468665478704
# Feature: R_win_by_Decision_Majority Score: 5.986133547289571
# Feature: R_win_by_Decision_Split Score: 7.125395255618706
# Feature: R_win_by_Decision_Unanimous Score: 8.900566256367338
# Feature: R_win_by_KO/TKO Score: 8.34873340785979
# Feature: R_win_by_Submission Score: 7.95110852947851
# Feature: R_win_by_TKO_Doctor_Stoppage Score: 6.325733077207029
# Feature: R_wins Score: 8.017303633652915
# Feature: R_Height_cms Score: 6.011726099910991
# Feature: R_Reach_cms Score: 5.5924331286263875
# Feature: R_Weight_lbs Score: 7.804171138054942
# Feature: R_age Score: 8.840809584224143
# Feature: B_age Score: 6.174160377678439
# Feature: lose_streak_dif Score: 5.3789494677544925
# Feature: win_streak_dif Score: 6.144649003811123
# Feature: longest_win_streak_dif Score: 7.177390805788006
# Feature: win_dif Score: 7.905808392669243
# Feature: loss_dif Score: 6.52215928691924
# Feature: total_round_dif Score: 7.787728381636928
# Feature: total_title_bout_dif Score: 8.04478967338869
# Feature: ko_dif Score: 7.24573193185892
# Feature: sub_dif Score: 7.798915041721596
# Feature: height_dif Score: 7.111902761066954
# Feature: reach_dif Score: 6.599586615790819
# Feature: age_dif Score: 6.745961679919496
# Feature: sig_str_dif Score: 6.813272414820903
# Feature: avg_sub_att_dif Score: 6.738962628777963
# Feature: avg_td_dif Score: 7.256726084735206
# Feature: empty_arena Score: 7.1566712223645945
# The best feature was R_odds.  It scored 9.797892622569304
# Current best score is: 9.797892622569304
# Feature: R_fighter Score: -30.303745050969138
# Feature: B_fighter Score: -33.02919268689847
# Feature: B_odds Score: 0.36790327795220534
# Feature: R_ev Score: -1.4253102472441546
# Feature: B_ev Score: 3.2552691798489386
# Feature: location Score: -18.71719743655047
# Feature: country Score: 4.0225491068690715
# Feature: title_bout Score: 4.693661102122679
# Feature: weight_class Score: -12.194481817514047
# Feature: gender Score: 5.182995741233359
# Feature: no_of_rounds Score: 7.198015059090304
# Feature: B_current_lose_streak Score: 10.041493153302625
# Feature: B_current_win_streak Score: 14.415473395687862
# Feature: B_draw Score: 10.460635386646857
# Feature: B_avg_SIG_STR_landed Score: -3.105105997581996
# Feature: B_avg_SIG_STR_pct Score: -7.432291487962246
# Feature: B_avg_SUB_ATT Score: -0.04556307442417307
# Feature: B_avg_TD_landed Score: 8.311680771898134
# Feature: B_avg_TD_pct Score: 1.204286383917018
# Feature: B_longest_win_streak Score: 9.915430705474535
# Feature: B_losses Score: 8.942484996889988
# Feature: B_total_rounds_fought Score: 7.186888195561144
# Feature: B_total_title_bouts Score: 3.86415070307095
# Feature: B_win_by_Decision_Majority Score: 4.904653109787041
# Feature: B_win_by_Decision_Split Score: 6.031586348910481
# Feature: B_win_by_Decision_Unanimous Score: 10.111233091847586
# Feature: B_win_by_KO/TKO Score: 9.45927213159975
# Feature: B_win_by_Submission Score: 7.725963868233853
# Feature: B_win_by_TKO_Doctor_Stoppage Score: 5.075494098076158
# Feature: B_wins Score: 8.96573924511833
# Feature: B_Stance Score: 4.624222564013554
# Feature: B_Height_cms Score: 10.502852908134676
# Feature: B_Reach_cms Score: 6.627179950235078
# Feature: B_Weight_lbs Score: 8.728803965873396
# Feature: R_current_lose_streak Score: 4.731130963364035
# Feature: R_current_win_streak Score: 6.149675727529887
# Feature: R_draw Score: 2.917177749705345
# Feature: R_avg_SIG_STR_landed Score: -4.241511472778574
# Feature: R_avg_SIG_STR_pct Score: -0.3419978284718903
# Feature: R_avg_SUB_ATT Score: 2.5641739811187585
# Feature: R_avg_TD_landed Score: -3.4425277657936393
# Feature: R_avg_TD_pct Score: 2.6791357564353984
# Feature: R_longest_win_streak Score: 8.47151411703399
# Feature: R_losses Score: 6.602286869850352
# Feature: R_total_rounds_fought Score: 6.988290923787388
# Feature: R_total_title_bouts Score: 8.134173067410686
# Feature: R_win_by_Decision_Majority Score: 11.344368925340508
# Feature: R_win_by_Decision_Split Score: 12.420501960774558
# Feature: R_win_by_Decision_Unanimous Score: 8.82632994438186
# Feature: R_win_by_KO/TKO Score: 9.370563067990307
# Feature: R_win_by_Submission Score: 8.735944182868941
# Feature: R_win_by_TKO_Doctor_Stoppage Score: 9.580754179082518
# Feature: R_wins Score: 9.655571286228541
# Feature: R_Height_cms Score: 5.71164349456328
# Feature: R_Reach_cms Score: 7.738083623209146
# Feature: R_Weight_lbs Score: 9.649042410216403
# Feature: R_age Score: 8.985316835722362
# Feature: B_age Score: 12.153313591395616
# Feature: lose_streak_dif Score: 6.94338500895135
# Feature: win_streak_dif Score: 6.628262615088401
# Feature: longest_win_streak_dif Score: 9.699611060873183
# Feature: win_dif Score: 8.71256800809537
# Feature: loss_dif Score: 9.099586791755003
# Feature: total_round_dif Score: 9.791962306230037
# Feature: total_title_bout_dif Score: 6.524805332163165
# Feature: ko_dif Score: 10.289699894814337
# Feature: sub_dif Score: 9.06920595575842
# Feature: height_dif Score: 7.420570783397601
# Feature: reach_dif Score: 7.644334452232554
# Feature: age_dif Score: 13.740939073028251
# Feature: sig_str_dif Score: 8.17362524280484
# Feature: avg_sub_att_dif Score: 7.5327460930032375
# Feature: avg_td_dif Score: 8.639139220737322
# Feature: empty_arena Score: 5.7844292358717935
# The best feature was B_current_win_streak.  It scored 14.415473395687862
# Current best score is: 14.415473395687862
# Feature: R_fighter Score: -30.27225164813939
# Feature: B_fighter Score: -33.02919268689847
# Feature: B_odds Score: -0.5244138506113849
# Feature: R_ev Score: 1.5889240374481872
# Feature: B_ev Score: 3.330286057215173
# Feature: location Score: -18.74120628794956
# Feature: country Score: 5.151043983205804
# Feature: title_bout Score: 2.191562108452566
# Feature: weight_class Score: -8.525722237832635
# Feature: gender Score: 13.799057348477374
# Feature: no_of_rounds Score: 12.133394401766324
# Feature: B_current_lose_streak Score: 14.840154013751665
# Feature: B_draw Score: 14.44736022513855
# Feature: B_avg_SIG_STR_landed Score: -1.8744406308551906
# Feature: B_avg_SIG_STR_pct Score: -2.857380574116923
# Feature: B_avg_SUB_ATT Score: 3.598556540094851
# Feature: B_avg_TD_landed Score: 10.00195123770453
# Feature: B_avg_TD_pct Score: 7.675811380290536
# Feature: B_longest_win_streak Score: 14.246858965731015
# Feature: B_losses Score: 14.624602676803388
# Feature: B_total_rounds_fought Score: 13.381949234768394
# Feature: B_total_title_bouts Score: 2.37123392721454
# Feature: B_win_by_Decision_Majority Score: 12.052386258965331
# Feature: B_win_by_Decision_Split Score: 9.052022593214602
# Feature: B_win_by_Decision_Unanimous Score: 15.255771883745357
# Feature: B_win_by_KO/TKO Score: 12.025523391133978
# Feature: B_win_by_Submission Score: 13.830093963622206
# Feature: B_win_by_TKO_Doctor_Stoppage Score: 13.531613464370343
# Feature: B_wins Score: 12.711260185854556
# Feature: B_Stance Score: 6.393584614476666
# Feature: B_Height_cms Score: 15.490661094684787
# Feature: B_Reach_cms Score: 12.854218320263175
# Feature: B_Weight_lbs Score: 14.234312055749072
# Feature: R_current_lose_streak Score: 10.959406575810487
# Feature: R_current_win_streak Score: 10.541195466823527
# Feature: R_draw Score: -1.2940663970632533
# Feature: R_avg_SIG_STR_landed Score: 0.2908569201353276
# Feature: R_avg_SIG_STR_pct Score: 6.899868670044285
# Feature: R_avg_SUB_ATT Score: 7.016544076409306
# Feature: R_avg_TD_landed Score: 0.531778115081508
# Feature: R_avg_TD_pct Score: 4.466890069901531
# Feature: R_longest_win_streak Score: 14.224634370210422
# Feature: R_losses Score: 15.017363506927405
# Feature: R_total_rounds_fought Score: 14.075740210124447
# Feature: R_total_title_bouts Score: 13.810816908853555
# Feature: R_win_by_Decision_Majority Score: 13.649678869957587
# Feature: R_win_by_Decision_Split Score: 17.63253558076603
# Feature: R_win_by_Decision_Unanimous Score: 13.90181265351018
# Feature: R_win_by_KO/TKO Score: 15.321660187465007
# Feature: R_win_by_Submission Score: 12.89384188955823
# Feature: R_win_by_TKO_Doctor_Stoppage Score: 14.801995524277585
# Feature: R_wins Score: 12.039554690780063
# Feature: R_Height_cms Score: 15.079204204399325
# Feature: R_Reach_cms Score: 14.072700512974404
# Feature: R_Weight_lbs Score: 14.7101073956874
# Feature: R_age Score: 15.799258709417783
# Feature: B_age Score: 14.836200489621547
# Feature: lose_streak_dif Score: 10.500463992964308
# Feature: win_streak_dif Score: 14.928592533641414
# Feature: longest_win_streak_dif Score: 14.550997269639256
# Feature: win_dif Score: 12.987745123738096
# Feature: loss_dif Score: 13.075728104204828
# Feature: total_round_dif Score: 10.49093780427095
# Feature: total_title_bout_dif Score: 12.951660811716351
# Feature: ko_dif Score: 13.074084602239633
# Feature: sub_dif Score: 16.30021033820888
# Feature: height_dif Score: 14.355211269692141
# Feature: reach_dif Score: 13.754766392655391
# Feature: age_dif Score: 18.702244548716696
# Feature: sig_str_dif Score: 10.709294781858326
# Feature: avg_sub_att_dif Score: 13.972555318192722
# Feature: avg_td_dif Score: 13.491067560771155
# Feature: empty_arena Score: 13.770432407327021
# The best feature was age_dif.  It scored 18.702244548716696
# Current best score is: 18.702244548716696
# Feature: R_fighter Score: -30.27225164813939
# Feature: B_fighter Score: -33.02919268689847
# Feature: B_odds Score: 3.874047547814075
# Feature: R_ev Score: 7.178304627334264
# Feature: B_ev Score: 8.569508689823655
# Feature: location Score: -18.840287643879627
# Feature: country Score: 4.780827671692352
# Feature: title_bout Score: 9.881398789926632
# Feature: weight_class Score: 3.8891054745029963
# Feature: gender Score: 15.779442119056235
# Feature: no_of_rounds Score: 16.13829911206377
# Feature: B_current_lose_streak Score: 20.13801805492745
# Feature: B_draw Score: 20.497958403856785
# Feature: B_avg_SIG_STR_landed Score: 5.320259707500756
# Feature: B_avg_SIG_STR_pct Score: 4.391387692228708
# Feature: B_avg_SUB_ATT Score: 2.43363765225741
# Feature: B_avg_TD_landed Score: 20.781796850542126
# Feature: B_avg_TD_pct Score: 12.149025617225407
# Feature: B_longest_win_streak Score: 18.262595493157537
# Feature: B_losses Score: 19.6021531185963
# Feature: B_total_rounds_fought Score: 17.937438369094465
# Feature: B_total_title_bouts Score: 12.836228340571736
# Feature: B_win_by_Decision_Majority Score: 16.02504605615372
# Feature: B_win_by_Decision_Split Score: 17.05955049472683
# Feature: B_win_by_Decision_Unanimous Score: 19.671806953521376
# Feature: B_win_by_KO/TKO Score: 18.50139933572391
# Feature: B_win_by_Submission Score: 18.83476272195579
# Feature: B_win_by_TKO_Doctor_Stoppage Score: 16.28393177352652
# Feature: B_wins Score: 17.548059421376706
# Feature: B_Stance Score: 6.786726138718401
# Feature: B_Height_cms Score: 16.60432018376647
# Feature: B_Reach_cms Score: 16.770157954503492
# Feature: B_Weight_lbs Score: 16.540752244669573
# Feature: R_current_lose_streak Score: 17.659385561653178
# Feature: R_current_win_streak Score: 15.977200246128191
# Feature: R_draw Score: 7.120569415122658
# Feature: R_avg_SIG_STR_landed Score: 6.979845831785289
# Feature: R_avg_SIG_STR_pct Score: 7.658635480914026
# Feature: R_avg_SUB_ATT Score: 7.107888321969041
# Feature: R_avg_TD_landed Score: 6.251771765704265
# Feature: R_avg_TD_pct Score: 4.551216205159628
# Feature: R_longest_win_streak Score: 18.08541610007929
# Feature: R_losses Score: 21.35421721856382
# Feature: R_total_rounds_fought Score: 19.27155526128038
# Feature: R_total_title_bouts Score: 17.32779096139448
# Feature: R_win_by_Decision_Majority Score: 20.62730947427603
# Feature: R_win_by_Decision_Split Score: 22.75278263802491
# Feature: R_win_by_Decision_Unanimous Score: 19.254954667779003
# Feature: R_win_by_KO/TKO Score: 18.11937186270322
# Feature: R_win_by_Submission Score: 18.35449172431296
# Feature: R_win_by_TKO_Doctor_Stoppage Score: 22.253167187216555
# Feature: R_wins Score: 18.81939243545538
# Feature: R_Height_cms Score: 17.956328500459463
# Feature: R_Reach_cms Score: 18.413688946988227
# Feature: R_Weight_lbs Score: 19.413901341215833
# Feature: R_age Score: 19.99971672356642
# Feature: B_age Score: 14.300592375589886
# Feature: lose_streak_dif Score: 19.610437520840676
# Feature: win_streak_dif Score: 17.964288469884004
# Feature: longest_win_streak_dif Score: 17.981737163518616
# Feature: win_dif Score: 19.780076534350084
# Feature: loss_dif Score: 22.011477309818428
# Feature: total_round_dif Score: 21.472795086857946
# Feature: total_title_bout_dif Score: 17.558700867156805
# Feature: ko_dif Score: 17.6065612689044
# Feature: sub_dif Score: 19.903737648625224
# Feature: height_dif Score: 19.12794685231583
# Feature: reach_dif Score: 17.41325424175548
# Feature: sig_str_dif Score: 18.316046813129297
# Feature: avg_sub_att_dif Score: 17.976784021321993
# Feature: avg_td_dif Score: 19.289549519464725
# Feature: empty_arena Score: 17.400254003020585
# The best feature was R_win_by_Decision_Split.  It scored 22.75278263802491
# Current best score is: 22.75278263802491
# Feature: R_fighter Score: -29.938918314806063
# Feature: B_fighter Score: -33.02919268689847
# Feature: B_odds Score: 9.812557453658425
# Feature: R_ev Score: 7.4666362185924
# Feature: B_ev Score: 11.693844006882733
# Feature: location Score: -18.89384156649437
# Feature: country Score: 7.690488216658191
# Feature: title_bout Score: 15.380793815813377
# Feature: weight_class Score: 9.296169879251831
# Feature: gender Score: 18.258236525239127
# Feature: no_of_rounds Score: 17.33140324734039
# Feature: B_current_lose_streak Score: 22.283255385479418
# Feature: B_draw Score: 22.84950474814132
# Feature: B_avg_SIG_STR_landed Score: 5.308421395500768
# Feature: B_avg_SIG_STR_pct Score: 9.852485499983938
# Feature: B_avg_SUB_ATT Score: 4.486161314851611
# Feature: B_avg_TD_landed Score: 23.117190528533616
# Feature: B_avg_TD_pct Score: 13.738385180251983
# Feature: B_longest_win_streak Score: 22.88903154497646
# Feature: B_losses Score: 21.06780802247974
# Feature: B_total_rounds_fought Score: 20.495366490017283
# Feature: B_total_title_bouts Score: 20.272819693028467
# Feature: B_win_by_Decision_Majority Score: 20.034148737942047
# Feature: B_win_by_Decision_Split Score: 20.829790711924836
# Feature: B_win_by_Decision_Unanimous Score: 22.564000384361677
# Feature: B_win_by_KO/TKO Score: 20.901035848031665
# Feature: B_win_by_Submission Score: 22.3361336562739
# Feature: B_win_by_TKO_Doctor_Stoppage Score: 19.396091409031175
# Feature: B_wins Score: 20.154935902037842
# Feature: B_Stance Score: 9.344204926289038
# Feature: B_Height_cms Score: 22.89736028097567
# Feature: B_Reach_cms Score: 20.98406945819934
# Feature: B_Weight_lbs Score: 22.323444935084115
# Feature: R_current_lose_streak Score: 20.40011525082312
# Feature: R_current_win_streak Score: 18.58987069105236
# Feature: R_draw Score: 14.762425873111042
# Feature: R_avg_SIG_STR_landed Score: 5.239596279644071
# Feature: R_avg_SIG_STR_pct Score: 7.267010498386554
# Feature: R_avg_SUB_ATT Score: 7.53900033072077
# Feature: R_avg_TD_landed Score: 7.427687335941722
# Feature: R_avg_TD_pct Score: 8.359442607983574
# Feature: R_longest_win_streak Score: 20.675073221091665
# Feature: R_losses Score: 22.009037510561463
# Feature: R_total_rounds_fought Score: 20.10732357764086
# Feature: R_total_title_bouts Score: 20.841661862884074
# Feature: R_win_by_Decision_Majority Score: 22.542795626033723
# Feature: R_win_by_Decision_Unanimous Score: 21.92727113842391
# Feature: R_win_by_KO/TKO Score: 21.186259252553405
# Feature: R_win_by_Submission Score: 21.515946610710273
# Feature: R_win_by_TKO_Doctor_Stoppage Score: 25.03744286818698
# Feature: R_wins Score: 21.748313700010467
# Feature: R_Height_cms Score: 23.745840182865575
# Feature: R_Reach_cms Score: 21.29139673463312
# Feature: R_Weight_lbs Score: 22.56530779993243
# Feature: R_age Score: 22.556815787443092
# Feature: B_age Score: 21.332115432826708
# Feature: lose_streak_dif Score: 20.07305307196796
# Feature: win_streak_dif Score: 21.909716940180214
# Feature: longest_win_streak_dif Score: 20.869251044961494
# Feature: win_dif Score: 21.768031412040884
# Feature: loss_dif Score: 22.26220380862516
# Feature: total_round_dif Score: 19.873819729012318
# Feature: total_title_bout_dif Score: 20.95407825054039
# Feature: ko_dif Score: 21.38732051239392
# Feature: sub_dif Score: 22.329638585226995
# Feature: height_dif Score: 18.945758020264226
# Feature: reach_dif Score: 20.851551578710296
# Feature: sig_str_dif Score: 19.920447651517705
# Feature: avg_sub_att_dif Score: 20.80133074484419
# Feature: avg_td_dif Score: 25.413165537679788
# Feature: empty_arena Score: 20.437792917124806
# The best feature was avg_td_dif.  It scored 25.413165537679788
# Current best score is: 25.413165537679788
# Feature: R_fighter Score: -30.01047409019188
# Feature: B_fighter Score: -33.02919268689847
# Feature: B_odds Score: 11.645688705981012
# Feature: R_ev Score: 8.955740640289935
# Feature: B_ev Score: 11.90886399618476
# Feature: location Score: -18.168884413582884
# Feature: country Score: 7.417739269029099
# Feature: title_bout Score: 9.946372365953884
# Feature: weight_class Score: 7.751069885308489
# Feature: gender Score: 22.24032293366641
# Feature: no_of_rounds Score: 17.50341385262108
# Feature: B_current_lose_streak Score: 23.021415768883376
# Feature: B_draw Score: 25.3456297802162
# Feature: B_avg_SIG_STR_landed Score: 7.648885423080427
# Feature: B_avg_SIG_STR_pct Score: 14.275491829682093
# Feature: B_avg_SUB_ATT Score: 4.105185315855139
# Feature: B_avg_TD_landed Score: 20.85327807599956
# Feature: B_avg_TD_pct Score: 16.12820712943283
# Feature: B_longest_win_streak Score: 23.459027981387692
# Feature: B_losses Score: 23.059922471788877
# Feature: B_total_rounds_fought Score: 23.417335029043507
# Feature: B_total_title_bouts Score: 17.18978567041703
# Feature: B_win_by_Decision_Majority Score: 22.71530807170923
# Feature: B_win_by_Decision_Split Score: 24.047662460555376
# Feature: B_win_by_Decision_Unanimous Score: 25.37189747415097
# Feature: B_win_by_KO/TKO Score: 22.218483019122818
# Feature: B_win_by_Submission Score: 24.505673782632705
# Feature: B_win_by_TKO_Doctor_Stoppage Score: 21.089193690375286
# Feature: B_wins Score: 23.103263855351393
# Feature: B_Stance Score: 8.163372686984898
# Feature: B_Height_cms Score: 23.57174937104775
# Feature: B_Reach_cms Score: 23.950000941203772
# Feature: B_Weight_lbs Score: 24.689787702451554
# Feature: R_current_lose_streak Score: 20.11634867343231
# Feature: R_current_win_streak Score: 18.319731508835268
# Feature: R_draw Score: 12.265696349675395
# Feature: R_avg_SIG_STR_landed Score: 6.135283793534209
# Feature: R_avg_SIG_STR_pct Score: 10.894661402632156
# Feature: R_avg_SUB_ATT Score: 10.219004126965523
# Feature: R_avg_TD_landed Score: 9.035163822371812
# Feature: R_avg_TD_pct Score: 8.468682749599274
# Feature: R_longest_win_streak Score: 21.37101989021435
# Feature: R_losses Score: 21.165993923868868
# Feature: R_total_rounds_fought Score: 21.03361641221926
# Feature: R_total_title_bouts Score: 24.72061365236044
# Feature: R_win_by_Decision_Majority Score: 22.667802667056865
# Feature: R_win_by_Decision_Unanimous Score: 26.548529006243612
# Feature: R_win_by_KO/TKO Score: 23.692917547929024
# Feature: R_win_by_Submission Score: 25.092367275963827
# Feature: R_win_by_TKO_Doctor_Stoppage Score: 24.37210296743246
# Feature: R_wins Score: 24.218650833029344
# Feature: R_Height_cms Score: 24.5658399425445
# Feature: R_Reach_cms Score: 23.47538715836638
# Feature: R_Weight_lbs Score: 24.993783371987995
# Feature: R_age Score: 24.259528562193722
# Feature: B_age Score: 23.50323590162645
# Feature: lose_streak_dif Score: 24.36237562969131
# Feature: win_streak_dif Score: 20.26162440462825
# Feature: longest_win_streak_dif Score: 21.77164127488659
# Feature: win_dif Score: 22.827120138021165
# Feature: loss_dif Score: 21.94824539634373
# Feature: total_round_dif Score: 20.02431657668348
# Feature: total_title_bout_dif Score: 25.399770901040874
# Feature: ko_dif Score: 23.06459882589231
# Feature: sub_dif Score: 24.52644653982044
# Feature: height_dif Score: 22.1338907306478
# Feature: reach_dif Score: 20.68102521217564
# Feature: sig_str_dif Score: 20.881193377682493
# Feature: avg_sub_att_dif Score: 21.089664321148753
# Feature: empty_arena Score: 23.320069421664183
# The best feature was R_win_by_Decision_Unanimous.  It scored 26.548529006243612
# Current best score is: 26.548529006243612
# Feature: R_fighter Score: -30.01047409019188
# Feature: B_fighter Score: -33.02919268689847
# Feature: B_odds Score: 11.201566395132653
# Feature: R_ev Score: 9.550728961713943
# Feature: B_ev Score: 11.21091822928788
# Feature: location Score: -18.227784097282957
# Feature: country Score: 7.7717410614401405
# Feature: title_bout Score: 8.454268273076988
# Feature: weight_class Score: 8.41557972568907
# Feature: gender Score: 20.203625566070073
# Feature: no_of_rounds Score: 18.956319104677583
# Feature: B_current_lose_streak Score: 23.171398100668785
# Feature: B_draw Score: 25.20512279329931
# Feature: B_avg_SIG_STR_landed Score: 7.293628163717922
# Feature: B_avg_SIG_STR_pct Score: 14.056440438037212
# Feature: B_avg_SUB_ATT Score: 3.874305454699714
# Feature: B_avg_TD_landed Score: 20.452634566940002
# Feature: B_avg_TD_pct Score: 15.240140246061634
# Feature: B_longest_win_streak Score: 24.24278564715042
# Feature: B_losses Score: 24.556554587143665
# Feature: B_total_rounds_fought Score: 24.327347477968896
# Feature: B_total_title_bouts Score: 15.81378519403129
# Feature: B_win_by_Decision_Majority Score: 21.52939181291007
# Feature: B_win_by_Decision_Split Score: 22.909779422295586
# Feature: B_win_by_Decision_Unanimous Score: 26.100260990729637
# Feature: B_win_by_KO/TKO Score: 22.337686502846992
# Feature: B_win_by_Submission Score: 23.436874175336065
# Feature: B_win_by_TKO_Doctor_Stoppage Score: 22.899959202456742
# Feature: B_wins Score: 22.477057440420786
# Feature: B_Stance Score: 7.89668762214645
# Feature: B_Height_cms Score: 23.67760121794778
# Feature: B_Reach_cms Score: 23.849518773679332
# Feature: B_Weight_lbs Score: 24.99788947769637
# Feature: R_current_lose_streak Score: 19.529616647194185
# Feature: R_current_win_streak Score: 18.100049661268287
# Feature: R_draw Score: 10.9742502328169
# Feature: R_avg_SIG_STR_landed Score: 5.117587215595976
# Feature: R_avg_SIG_STR_pct Score: 10.263002043646988
# Feature: R_avg_SUB_ATT Score: 9.959550601187361
# Feature: R_avg_TD_landed Score: 8.979674305068041
# Feature: R_avg_TD_pct Score: 6.664468549346365
# Feature: R_longest_win_streak Score: 22.018479407358775
# Feature: R_losses Score: 20.635865871393875
# Feature: R_total_rounds_fought Score: 20.720859831605527
# Feature: R_total_title_bouts Score: 25.602411085201837
# Feature: R_win_by_Decision_Majority Score: 23.139689972927183
# Feature: R_win_by_KO/TKO Score: 22.435982881799333
# Feature: R_win_by_Submission Score: 24.753415486316854
# Feature: R_win_by_TKO_Doctor_Stoppage Score: 24.64391425273652
# Feature: R_wins Score: 22.6561286154851
# Feature: R_Height_cms Score: 23.62590674905517
# Feature: R_Reach_cms Score: 24.222840949125974
# Feature: R_Weight_lbs Score: 24.75641313283934
# Feature: R_age Score: 22.641862001614477
# Feature: B_age Score: 24.96878063351122
# Feature: lose_streak_dif Score: 23.25089732806825
# Feature: win_streak_dif Score: 21.130566999887897
# Feature: longest_win_streak_dif Score: 22.61164427281167
# Feature: win_dif Score: 22.384605389628753
# Feature: loss_dif Score: 22.27628472795679
# Feature: total_round_dif Score: 20.399852947394194
# Feature: total_title_bout_dif Score: 25.000707574185206
# Feature: ko_dif Score: 22.368347840747518
# Feature: sub_dif Score: 25.65617912733689
# Feature: height_dif Score: 21.588016669107102
# Feature: reach_dif Score: 21.671495963251193
# Feature: sig_str_dif Score: 20.824477246565998
# Feature: avg_sub_att_dif Score: 21.859790158315942
# Feature: empty_arena Score: 23.44642531345024
# NO IMPROVEMENT
# FINAL BEST SCORE: 26.548529006243612
# ['R_win_by_Decision_Unanimous',
#  'avg_td_dif',
#  'R_win_by_Decision_Split',
#  'age_dif',
#  'B_current_win_streak',
#  'R_odds',
#  'R_Stance']

# %%
model_6 = LinearDiscriminantAnalysis()
(get_best_features(my_pos_features, model_6, df_train, [], label_train, odds_train, True))
# Out:
# Current best score is: -100
# Feature: R_fighter Score: -26.552919668124563
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-26-dfed28912c37> in <module>
#       1 model_6 = LinearDiscriminantAnalysis()
# ----> 2 (get_best_features(my_pos_features, model_6, df_train, [], label_train, odds_train, True))
#
# <ipython-input-18-1c7552edd0f1> in get_best_features(pos_features, m, df, cur_features, labels, odds, scale)
#      37             labels_sel = labels[labels.index.isin(df_sel.index)]
#      38             odds_sel = odds[odds.index.isin(df_sel.index)]
# ---> 39             new_score = custom_cv_eval(df_sel, m, labels_sel, odds_sel)
#      40             #print(f"{len(df_sel)} {len(labels_sel)} {len(odds_sel)}")
#      41             print(f"Feature: {f} Score: {new_score}")
#
# <ipython-input-15-1736af7cfedb> in custom_cv_eval(df, m, labels, odds, min_ev)
#      17         odds_train, odds_test = odds[train_index], odds[test_index]
#      18         #display(y_train)
# ---> 19         m.fit(X_train, y_train)
#      20         probs=m.predict_proba(X_test)
#      21         #print(probs)
#
# D:\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py in fit(self, X, y)
#     475             if self.shrinkage is not None:
#     476                 raise NotImplementedError('shrinkage not supported')
# --> 477             self._solve_svd(X, y)
#     478         elif self.solver == 'lsqr':
#     479             self._solve_lsqr(X, y, shrinkage=self.shrinkage)
#
# D:\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py in _solve_svd(self, X, y)
#     381         X = np.sqrt(fac) * (Xc / std)
#     382         # SVD of centered (within)scaled data
# --> 383         U, S, V = linalg.svd(X, full_matrices=False)
#     384
#     385         rank = np.sum(S > self.tol)
#
# D:\Anaconda3\lib\site-packages\scipy\linalg\decomp_svd.py in svd(a, full_matrices, compute_uv, overwrite_a, check_finite, lapack_driver)
#     130
#     131     if info > 0:
# --> 132         raise LinAlgError("SVD did not converge")
#     133     if info < 0:
#     134         raise ValueError('illegal value in %d-th argument of internal gesdd'
#
# LinAlgError: SVD did not converge
