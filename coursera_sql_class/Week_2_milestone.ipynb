# %%
import pandas as pd
from scipy.stats import pearsonr

# %%
df = pd.read_csv("../data/kaggle_data/ufc-master.csv")

# %%
df.describe()
# Out:
#             R_odds       B_odds         R_ev         B_ev  no_of_rounds  \
# count  4813.000000  4813.000000  4813.000000  4813.000000   4813.000000
# mean   -117.320798    66.026595    94.908580   167.212741      3.181799
# std     268.737562   247.978768    82.974922   137.003697      0.571185
# min   -1700.000000 -1200.000000     5.882353     8.333333      3.000000
# 25%    -255.000000  -145.000000    39.215686    68.965517      3.000000
# 50%    -150.000000   130.000000    66.666667   130.000000      3.000000
# 75%     129.000000   220.000000   129.000000   220.000000      3.000000
# max     775.000000  1300.000000   775.000000  1300.000000      5.000000
#
#        B_current_lose_streak  B_current_win_streak       B_draw  \
# count            4813.000000           4813.000000  4813.000000
# mean                0.476002              0.873883     0.010181
# std                 0.768033              1.309252     0.106424
# ...
